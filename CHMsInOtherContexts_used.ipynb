# %% [markdown]
# ## CHM in other contexts

# %% [markdown]
# ### Cell state transition

# %% [markdown]
# #### Data process and CHM calling

# %%
# %%bash
# dirPATH=/mnt/Storage/home/yanghui/imprinting/result.2021/Exploring
# pyPATH=/mnt/Storage/home/yanghui/scripts/python
# shPATH=/mnt/Storage/home/yanghui/scripts/shell
# binPATH=/mnt/Storage/home/yanghui/scripts/bin
# rPATH=/mnt/Storage/home/yanghui/scripts/R
# anPATH=/mnt/Storage/home/yanghui/annotations
# dataPATH_retinal=${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse
# dataPATH_PAD=/mnt/Storage/home/yanghui/data.public/sat4C/GSE65618_deLaat_GR/processed
# dataPATH_potentialEnhancer=/mnt/Storage/home/yuzhaowei/projects/imprinting/data_mm10/public/DC_ATAC/mouse_ATAC.bed
#
# mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition
# # collect WGBS and H3K9me3 ChIP-seq data during cell state transition
#
# collectData(){
#     # D: Sep-23-2021 15:48 Thu
#     mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DataCollection;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DataCollection
# #     python ${pyPATH}/getGEOtext.py gds_result_Mouse_WGBS_20210923.txt gds_result_Mouse_WGBS_20210923 # executed in 10m
#     python ${pyPATH}/getGEOtext.py gds_result_Mouse_H3K9me3_ChIPSeq_20210924.txt gds_result_Mouse_H3K9me3_ChIPSeq # executed in 20m 7s, finished 09:41:51 2021-09-24
# }
# # collectData
#
# retinal_development(){
#     # D: Sep-28-2021 22:09 Tue
#     WGBS(){
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320284 PAIRED E14.5.WGBS.rep1 mm10
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320285 PAIRED E17.5.WGBS.rep1 mm10
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320286 PAIRED P0.WGBS.rep1 mm10
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320287 PAIRED P3.WGBS.rep1 mm10
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320288 PAIRED P7.WGBS.rep1 mm10
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320289 PAIRED P10.WGBS.rep1 mm10
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320290 PAIRED P14.WGBS.rep1 mm10
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2320291 PAIRED P21.WGBS.rep1 mm10
#     }
#     # WGBS
#
#     ChIPseq(){
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319491 SINGLE E14.5.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319492 SINGLE E17.5.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319493 SINGLE P0.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319494 SINGLE P3.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319495 SINGLE P7.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319496 SINGLE P10.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319497 SINGLE P14.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse GEO GSM2319498 SINGLE P21.H3K9me3.rep1 mm10
#     }
#     # ChIPseq
#
#     rmDup(){
#         # D: Oct-09-2021 09:29 Sat
#         for sample in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#         do
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.H3K9me3.rep1 && \
#             samtools rmdup ${sample}.H3K9me3.rep1.bam ${sample}.H3K9me3.rep1.rmDup.bam &
#         done # for sample end
#         wait
#     }
#     # rmDup
#
#     callCHM(){
#         # D: Oct-09-2021 09:58 Sat
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/CHMs;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/CHMs
#         for sample in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#         do
#             pcar -m callchm \
#             -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.H3K9me3.rep1/${sample}.H3K9me3.rep1.rmDup.bam \
#             -M ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed \
#             -Z ${anPATH}/mm10/mm10_euch.chrom.sizes \
#             -Q ${anPATH}/mm10/mm10.2bit \
#             -B 200 \
#             -N ${sample}_200bp \
#             -T 8
#         done # for sample end
#     }
#     # callCHM
#
#     prepareSignal(){
#         # D: Feb-17-2022 15:16 Thu
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/Merged
#         K9(){
#             for sample in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#             do
#                 # ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.H3K9me3.rep1/${sample}.H3K9me3.rep1.rmDup.bw ${sample}.H3K9me3.rmDup.bw
#                 # D: Apr-15-2022 12:21 Fri
#                 # macs2 callpeak -g mm -n ${sample}.H3K9me3.rmDup -B -q 0.05 --nomodel --shift=73 --SPMR --broad -t ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.H3K9me3.rep1/${sample}.H3K9me3.rep1.rmDup.bam && \
#                 intersectBed -a ${sample}.H3K9me3.rmDup_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp && \
#                 bedGraphToBigWig ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.rmDup.bw && \
#                 rm ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp &
#             done # for sample end
#         }
#         K9
#
#         methyl(){
#             for sample in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#             do
#                 # ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/RetinalDevelopment/GSE87064_Mouse/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed ${sample}.methyl.sam.G.bed && \
#                 # grep -v "#" ${sample}.methyl.sam.G.bed | cut -f 1-4 | sort -k1,1 -k2,2n > ${sample}.methyl.sam.G.bed.tmp && \
#
#                 bedGraphToBigWig ${sample}.methyl.sam.G.bed.tmp ${anPATH}/mm10/mm10.chrom.sizes ${sample}.methyl.all.bw && \
#                 rm ${sample}.methyl.sam.G.bed.tmp &
#             done # for sample end
#         }
#         # methyl
#     }
#     prepareSignal
# }
# # retinal_development
#
# dc_development_need_to_be_modified(){
#     # D: Nov-09-2021 14:46 Tue
#     # D: Oct-13-2022 18:28 Thu (Need to be modified as the TWGBS data of CDP, cDC, pDC are in DNMT1 deficiency situation, not health condition)
#     DNAMethylation(){
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM2522282 PAIRED HSC.WGBS.rep1 mm10 # GSE95697
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM2373810 SINGLE MPP.WGBS.rep1 mm10 # GSE89492
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM2373811 SINGLE MPP.WGBS.rep2 mm10 # GSE89492
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997070 PAIRED CDP.TWGBS.rep1 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997071 PAIRED CDP.TWGBS.rep2 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997072 PAIRED CDP.TWGBS.rep3 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997073 PAIRED CDP.TWGBS.rep4 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997074 PAIRED pDC.TWGBS.rep1 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997075 PAIRED pDC.TWGBS.rep2 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997076 PAIRED pDC.TWGBS.rep3 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997077 PAIRED cDC_CD11b.TWGBS.rep1 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997078 PAIRED cDC_CD11b.TWGBS.rep2 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997079 PAIRED cDC_CD11b.TWGBS.rep3 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997080 PAIRED cDC_CD8a.TWGBS.rep1 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997081 PAIRED cDC_CD8a.TWGBS.rep2 mm10 # GSE164124
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM4997082 PAIRED cDC_CD8a.TWGBS.rep3 mm10 # GSE164124
#     }
#     # DNAMethylation
#
#     ChIPseq(){
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM3701318 SINGLE HSC.H3K9me3.rep1 mm10 # GSE129157
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1384943 SINGLE MPP.H3K9me3.rep1 mm10 # GSE64767
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1384944 SINGLE CDP.H3K9me3.rep1 mm10 # D: Jan-19-2022 18:48 Wed
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1384945 SINGLE cDC.H3K9me3.rep1 mm10 # GSE64767
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1384946 SINGLE pDC.H3K9me3.rep1 mm10 # GSE64767
#     }
#     # ChIPseq
#
#     sampleCor(){
#         # D: Jan-12-2021 10:12abs Wed
#         # R: Relative good correlation
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/SampleCor;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/SampleCor
#         # python ${pyPATH}/methyl_processing.py \
#             "unit" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/HSC.WGBS.rep1/HSC.WGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/MPP.WGBS.rep1/MPP.WGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/MPP.WGBS.rep2/MPP.WGBS.rep2.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CDP.TWGBS.rep1/CDP.TWGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CDP.TWGBS.rep2/CDP.TWGBS.rep2.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CDP.TWGBS.rep3/CDP.TWGBS.rep3.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CDP.TWGBS.rep4/CDP.TWGBS.rep4.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/pDC.TWGBS.rep1/pDC.TWGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/pDC.TWGBS.rep2/pDC.TWGBS.rep2.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/pDC.TWGBS.rep3/pDC.TWGBS.rep3.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD8a.TWGBS.rep1/cDC_CD8a.TWGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD8a.TWGBS.rep2/cDC_CD8a.TWGBS.rep2.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD8a.TWGBS.rep3/cDC_CD8a.TWGBS.rep3.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD11b.TWGBS.rep1/cDC_CD11b.TWGBS.rep1.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD11b.TWGBS.rep2/cDC_CD11b.TWGBS.rep2.sam.G.bed" \
#             "${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/cDC_CD11b.TWGBS.rep3/cDC_CD11b.TWGBS.rep3.sam.G.bed"
#
#         # grep -v "NA" all.merged.values.txt > rmNA.mergedged.values.txt
#         (head -1 rmNA.merged.values.txt && tail -n +2 rmNA.merged.values.txt | grep -w "^chr[0-9]\{1,2\}") > rmNA_euch.mergedged.values.txt
#
#         # Delete the line with exception in cDC_CD8a.TWGBS.rep2.sam.G.bed : hr4	70396622	70396624	0.839	31chr4	70396328	70396330	1	37	37	B	G	+	18	18	-	19	19	ACCGA
#     }
#     # sampleCor
#
#     prepareBeforeCallCHM(){
#         # D: Jan-19-2022 14:48 Wed
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM
#         mergeSamGbed(){
#             ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/HSC.WGBS.rep1/HSC.WGBS.rep1.sam.G.bed HSC.WGBS.sam.G.bed
#             cat ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/*/MPP*sam.G.bed | grep -v "#chrom" > MPP.WGBS.sam.G.bed
#             cat ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/*/CDP*sam.G.bed | grep -v "#chrom" > CDP.WGBS.sam.G.bed
#             cat ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/*/cDC*sam.G.bed | grep -v "#chrom" > cDC.WGBS.sam.G.bed
#             cat ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/*/pDC*sam.G.bed | grep -v "#chrom" > pDC.WGBS.sam.G.bed
#         }
#         # mergeSamGbed
#
#         rmDup(){
#             # for sample in HSC MPP CDP cDC pDC
#             for sample in CDP # D: Jan-19-2022 18:07 Wed
#             do
#                 samtools rmdup ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/${sample}.H3K9me3.rep1/${sample}.H3K9me3.rep1.bam ${sample}.H3K9me3.rep1.rmDup.bam &
#             done # for sample end
#             wait
#         }
#         # rmDup
#
#         generateBW(){
#             # D: Jan-20-2022 19:31 Thu
#             for sample in HSC MPP CDP cDC pDC
#             do
#                 macs2 callpeak -g mm -n ${sample}.H3K9me3.rep1.rmDup -B -q 0.05 --nomodel --shift=73 --SPMR -t ${sample}.H3K9me3.rep1.rmDup.bam && \
#                 intersectBed -a ${sample}.H3K9me3.rep1.rmDup_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.rep1.rmDup_treat_pileup.bdg.tmp && \
#                 bedGraphToBigWig ${sample}.H3K9me3.rep1.rmDup_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.rep1.rmDup.bw &
#             done # for sample end
#         }
#         generateBW
#     }
#     # prepareBeforeCallCHM
#
#     callCHM(){
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CHMs;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/CHMs
#         # for sample in HSC MPP CDP cDC pDC
#         for sample in CDP cDC pDC
#         do
#             pcar -m callchm \
#                 -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM/${sample}.H3K9me3.rep1.rmDup.bam \
#                 -M ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM/${sample}.WGBS.sam.G.bed \
#                 -Z ${anPATH}/mm10/mm10_euch.chrom.sizes \
#                 -Q ${anPATH}/mm10/mm10.2bit \
#                 -B 200 \
#                 -N ${sample}_200bp \
#                 -T 6
#         done # for sample end
#     }
#     # callCHM
#
#     prepareSignal(){
#         # D: Feb-17-2022 15:12 Thu
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/Merged
#         K9(){
#             for sample in HSC MPP CDP cDC pDC
#             do
#                 ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM/${sample}.H3K9me3.rep1.rmDup.bw ${sample}.H3K9me3.rmDup.bw
#             done # for sample end
#         }
#         # K9
#
#         methyl(){
#             for sample in HSC MPP CDP cDC pDC
#             do
#                 # R: Error as multiple lines as replicates => separately now
#                 # ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/PreparedBeforeCallCHM/${sample}.WGBS.sam.G.bed ${sample}.methyl.sam.G.bed
#                 # grep -v "#" ${sample}.methyl.sam.G.bed | cut -f 1-4 | sort -k1,1 -k2,2n > ${sample}.methyl.sam.G.bed.tmp && \
#                 bedGraphToBigWig ${sample}.methyl.sam.G.bed.tmp ${anPATH}/mm10/mm10.chrom.sizes ${sample}.methyl.all.bw && \
#                 rm ${sample}.methyl.sam.G.bed.tmp &
#             done # for sample end
#         }
#         # methyl
#     }
#     # prepareSignal
#
#     RNASeq(){
#         # D: Apr-21-2022 00:19 Thu
#         # Data resource: GSE73143
#         # D: May-29-2022 09:42 Sun
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1887728 PAIRED MPP.RNASeq.rep1 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1887727 PAIRED CDP.RNASeq.rep1 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1887729 PAIRED cDC.RNASeq.rep1 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment GEO GSM1887730 PAIRED pDC.RNASeq.rep1 mm10
#
#         re_download(){
#             # D: May-27-2022 10:06 Fri
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/DendriticCellDevelopment/MPP.RNASeq.rep1
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR243/008/SRR2435588/SRR2435588_1.fastq.gz" -O MPP.RNASeq.rep1_R1.fq.gz
#         }
#         # re_download
#     }
#     RNASeq
# }
# # dc_development
#
# PGC_development(){
#     # D: Jan-12-2022 09:29 Wed
#     # D: Jan-16-2022 10:31 Sun
#     WGBS(){
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4578139 SINGLE E9.5.WGBS.rep1 mm10 # GSE151446
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM2041731 PAIRED E10.5.WGBS.rep1 mm10 # GSE76973
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM1386026 PAIRED E13.5_female.WGBS.rep1 mm10 # GSE56697
#         # bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM1386027 PAIRED E13.5_male.WGBS.rep1 mm10 # GSE56697
#     }
#     # WGBS
#
#     ChIPseq(){
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM5230780 PAIRED E9.5.H3K9me3.rep1 mm10 # GSE171695
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196612 PAIRED E10.5.H3K9me3.rep1 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196616 PAIRED E10.5.H3K9me3.rep2 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4977595 PAIRED E10.5.H3K9me3.rep3 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196620 PAIRED E13.5_female.H3K9me3.rep1 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196626 PAIRED E13.5_female.H3K9me3.rep2 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4977597 PAIRED E13.5_female.H3K9me3.rep3 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196623 PAIRED E13.5_male.H3K9me3.rep1 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196629 PAIRED E13.5_male.H3K9me3.rep2 mm10 # GSE141182
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4977599 PAIRED E13.5_male.H3K9me3.rep3 mm10 # GSE141182
#     }
#     # ChIPseq
#
#     redownload(){
#         # D: Jan-15-2021 15:27 Sat
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.WGBS.rep1
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/006/SRR1286816/SRR1286816_1.fastq.gz -O E13.5_male.WGBS.rep1_part1_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/006/SRR1286816/SRR1286816_2.fastq.gz -O E13.5_male.WGBS.rep1_part1_R2.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/007/SRR1286817/SRR1286817_1.fastq.gz -O E13.5_male.WGBS.rep1_part2_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/007/SRR1286817/SRR1286817_2.fastq.gz -O E13.5_male.WGBS.rep1_part2_R2.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/008/SRR1286818/SRR1286818_1.fastq.gz -O E13.5_male.WGBS.rep1_part3_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/008/SRR1286818/SRR1286818_2.fastq.gz -O E13.5_male.WGBS.rep1_part3_R2.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/009/SRR1286819/SRR1286819_1.fastq.gz -O E13.5_male.WGBS.rep1_part4_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/009/SRR1286819/SRR1286819_2.fastq.gz -O E13.5_male.WGBS.rep1_part4_R2.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/000/SRR1286820/SRR1286820_1.fastq.gz -O E13.5_male.WGBS.rep1_part5_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/000/SRR1286820/SRR1286820_2.fastq.gz -O E13.5_male.WGBS.rep1_part5_R2.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/001/SRR1286821/SRR1286821_1.fastq.gz -O E13.5_male.WGBS.rep1_part6_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR128/001/SRR1286821/SRR1286821_2.fastq.gz -O E13.5_male.WGBS.rep1_part6_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E9.5.H3K9me3.rep1
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR141/040/SRR14182440/SRR14182440_1.fastq.gz -O E9.5.H3K9me3.rep1_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR141/040/SRR14182440/SRR14182440_2.fastq.gz -O E9.5.H3K9me3.rep1_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E10.5.H3K9me3.rep1
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/000/SRR10560100/SRR10560100_1.fastq.gz -O E10.5.H3K9me3.rep1_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/000/SRR10560100/SRR10560100_2.fastq.gz -O E10.5.H3K9me3.rep1_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E10.5.H3K9me3.rep2
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/004/SRR10560104/SRR10560104_1.fastq.gz -O E10.5.H3K9me3.rep2_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/004/SRR10560104/SRR10560104_2.fastq.gz -O E10.5.H3K9me3.rep2_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E10.5.H3K9me3.rep3
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/072/SRR13296472/SRR13296472_1.fastq.gz -O E10.5.H3K9me3.rep3_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/072/SRR13296472/SRR13296472_2.fastq.gz -O E10.5.H3K9me3.rep3_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_female.H3K9me3.rep1
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/008/SRR10560108/SRR10560108_1.fastq.gz -O E13.5_female.H3K9me3.rep1_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/008/SRR10560108/SRR10560108_2.fastq.gz -O E13.5_female.H3K9me3.rep1_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_female.H3K9me3.rep2
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/014/SRR10560114/SRR10560114_1.fastq.gz -O E13.5_female.H3K9me3.rep2_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/014/SRR10560114/SRR10560114_2.fastq.gz -O E13.5_female.H3K9me3.rep2_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_female.H3K9me3.rep3
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/074/SRR13296474/SRR13296474_1.fastq.gz -O E13.5_female.H3K9me3.rep3_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/074/SRR13296474/SRR13296474_2.fastq.gz -O E13.5_female.H3K9me3.rep3_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.H3K9me3.rep1
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/011/SRR10560111/SRR10560111_1.fastq.gz -O E13.5_male.H3K9me3.rep1_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/011/SRR10560111/SRR10560111_2.fastq.gz -O E13.5_male.H3K9me3.rep1_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.H3K9me3.rep2
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/017/SRR10560117/SRR10560117_1.fastq.gz -O E13.5_male.H3K9me3.rep2_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/017/SRR10560117/SRR10560117_2.fastq.gz -O E13.5_male.H3K9me3.rep2_R2.fq.gz
#
#         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.H3K9me3.rep3
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/076/SRR13296476/SRR13296476_1.fastq.gz -O E13.5_male.H3K9me3.rep3_R1.fq.gz
#         wget -c ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR132/076/SRR13296476/SRR13296476_2.fastq.gz -O E13.5_male.H3K9me3.rep3_R2.fq.gz
#     }
#     # redownload
#
#     sampleCor_K9(){
#         # D: Feb-14-2022 17:07 Mon
#         # T: executed in 9m 32s, finished 17:30:08 2022-02-14
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/SampleCor;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/SampleCor
#         macs2_peak_bw(){
#             for sample in E9.5 E10.5 E13.5_female E13.5_male
#             do
#                 for rep in rep1 rep2 rep3
#                 do
#                     if [ -d ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.H3K9me3.${rep} ]
#                     then
#                         cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.H3K9me3.${rep} && \
#                         macs2 callpeak -g mm -n ${sample}.H3K9me3.${rep} -B -q 0.05 --nomodel --shift=73 --broad --SPMR -t ${sample}.H3K9me3.${rep}.bam && \
#                         intersectBed -a ${sample}.H3K9me3.${rep}_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.${rep}_treat_pileup.bdg.tmp && \
#                         bedGraphToBigWig ${sample}.H3K9me3.${rep}_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.${rep}.bw && \
#                         cut -f 1-3 ${sample}.H3K9me3.${rep}_peaks.broadPeak > ${sample}.H3K9me3.${rep}.macs2_peaks.bed &
#                     fi
#                 done # for rep end
#             done # for sample end
#         }
#         # macs2_peak_bw
#
#         mergePeak(){
#             # D: Feb-14-2022 17:32 Mon
#             # T: executed in 563ms, finished 17:34:24 2022-02-14
#             cat ../*H3K9me3*/*.macs2_peaks.bed | sort -k1,1 -k2,2n | mergeBed -i - > mergedPeaks.bed # 34,704
#         }
#         # mergePeak
#
#         signal(){
#             # D: Feb-14-2022 17:35 Mon
#             # T: executed in 49.8s, finished 17:42:15 2022-02-14
#             echo -ne "#Chrom\tStart\tEnd" > title.txt
#             cat mergedPeaks.bed > mergedPeaks.H3K9me3.txt
#             for sample in E9.5 E10.5 E13.5_female E13.5_male
#             do
#                 for rep in rep1 rep2 rep3
#                 do
#                     if [ -d ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.H3K9me3.${rep} ]
#                     then
#                         echo -ne "\t${sample}.${rep}" >> title.txt
#                         bash ${shPATH}/averageSignalInRegionPrimaryOrder.sh \
#                             mergedPeaks.bed \
#                             ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.H3K9me3.${rep}/${sample}.H3K9me3.${rep}.bw \
#                             1 \
#                             mergedPeaks.H3K9me3_${sample}.${rep}.txt
#
#                         paste mergedPeaks.H3K9me3.txt mergedPeaks.H3K9me3_${sample}.${rep}.txt > tmp && mv tmp mergedPeaks.H3K9me3.txt
#                     fi
#                 done # for rep end
#             done # for sample end
#             echo -ne "\n" >> title.txt
#             cat title.txt mergedPeaks.H3K9me3.txt > tmp && mv tmp mergedPeaks.H3K9me3.txt
#         }
#         # signal
#
#         sampleCor(){
#             # D: Feb-14-2022 18:00 Mon
#             # R: Though relative less correlated as plus rep3, but still use merge one as in paper
#             Rscript sampleCor.r
#         }
#         # sampleCor
#     }
#     # sampleCor_K9
#
#     mergeReps_K9(){
#         # D: Dec-14-2022 20:27 Mon
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged
#         samtools view -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E9.5.H3K9me3.rep1/E9.5.H3K9me3.rep1.bam > header.sam
#         for sample in E9.5 E10.5 E13.5_female E13.5_male
#         do
#             samtools merge -@ 30 -h header.sam ${sample}.H3K9me3.bam ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.H3K9me3.*/${sample}.H3K9me3.*bam
#         done # for sample end
#     }
#     # mergeReps_K9
#
#     rmDup_K9(){
#         # D: Feb-14-2022 20:34 Mon
#         # T: executed in 8m 14s, finished 20:51:14 2022-02-14
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged
#         for sample in E9.5 E10.5 E13.5_female E13.5_male
#         do
#             samtools rmdup ${sample}.H3K9me3.bam ${sample}.H3K9me3.rmDup.bam &
#         done # for sample end
#         wait
#     }
#     # rmDup_K9
#
#     callCHM(){
#         # D: Feb-14-2022 20:43 Mon
#         # T: executed in 39m 15s, finished 21:47:09 2022-02-14
#         # R: Number of CHMs varied significantly:
#         # R: 2,949 E9.5
#         # R: 11,638 E10.5
#         # R: 6,168 E13.5_female
#         # R: 6,603 E13.5_male
#
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/CHMs;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/CHMs
#         for sample in E9.5 E10.5 E13.5_female E13.5_male
#         do
#             pcar -m callchm \
#                 -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged/${sample}.H3K9me3.rmDup.bam \
#                 -M ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed \
#                 -Z ${anPATH}/mm10/mm10_euch.chrom.sizes \
#                 -Q ${anPATH}/mm10/mm10.2bit \
#                 -B 200 \
#                 -N ${sample}_200bp \
#                 -T 6
#         done # for sample end
#     }
#     # callCHM
#
#     generateBW(){
#         # D: Feb-14-2022 21:08 Mon
#         # T: executed in 16m 21s, finished 22:08:55 2022-02-14
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/Merged
#         K9(){
#             for sample in E9.5 E10.5 E13.5_female E13.5_male
#             do
#                 macs2 callpeak -g mm -n ${sample}.H3K9me3.rmDup -B -q 0.05 --nomodel --shift=73 --SPMR --broad -t ${sample}.H3K9me3.rmDup.bam && \
#                 intersectBed -a ${sample}.H3K9me3.rmDup_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp && \
#                 bedGraphToBigWig ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.rmDup.bw && \
#                 rm ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp &
#             done # for sample end
#             wait
#         }
#         # K9
#
#         methyl(){
#             for sample in E9.5 E10.5 E13.5_female E13.5_male
#             do
#                 # # D: Feb-17-2022 15:09 Thu
#                 # ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed ${sample}.methyl.sam.G.bed && \
#                 # grep -v '#' ${sample}.methyl.sam.G.bed | cut -f 1-4 | sort -k1,1 -k2,2n > ${sample}.methyl.sam.G.bed.tmp && \
#                 bedGraphToBigWig ${sample}.methyl.sam.G.bed.tmp ${anPATH}/mm10/mm10.chrom.sizes ${sample}.methyl.all.bw && \
#                 rm ${sample}.methyl.sam.G.bed.tmp &
#             done # for sample end
#             wait
#         }
#         methyl
#     }
#     # generateBW
#
#     RNASeq(){
#         # D: Apr-21-2022 00:37 Thu
#         # Data source: GSE19960
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM2041483 PAIRED E10.5.RNASeq.rep1 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM2041484 PAIRED E10.5.RNASeq.rep2 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196635 PAIRED E13.5_female.RNASeq.rep1 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196636 PAIRED E13.5_female.RNASeq.rep2 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196637 PAIRED E13.5_female.RNASeq.rep3 mm10
#         # bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196638 PAIRED E13.5_male.RNASeq.rep1 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196639 PAIRED E13.5_male.RNASeq.rep2 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196640 PAIRED E13.5_male.RNASeq.rep3 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment GEO GSM4196641 PAIRED E13.5_male.RNASeq.rep4 mm10
#
#         re_download(){
#             # D: May-27-2022 10:09 Fri
#             # E13.5_male.RNASeq.rep2
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.RNASeq.rep2
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/093/SRR10560093/SRR10560093_1.fastq.gz" -O E13.5_male.RNASeq.rep2_part2_R1.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/093/SRR10560093/SRR10560093_2.fastq.gz" -O E13.5_male.RNASeq.rep2_part2_R2.fq.gz
#
#             # E13.5_male.RNASeq.rep3
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.RNASeq.rep3
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/094/SRR10560094/SRR10560094_1.fastq.gz" -O E13.5_male.RNASeq.rep3_part1_R1.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/094/SRR10560094/SRR10560094_2.fastq.gz" -O E13.5_male.RNASeq.rep3_part1_R2.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/095/SRR10560095/SRR10560095_1.fastq.gz" -O E13.5_male.RNASeq.rep3_part2_R1.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/095/SRR10560095/SRR10560095_2.fastq.gz" -O E13.5_male.RNASeq.rep3_part2_R2.fq.gz
#
#             # E13.5_male.RNASeq.rep4
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/PGCsDevelopment/E13.5_male.RNASeq.rep4
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/096/SRR10560096/SRR10560096_2.fastq.gz" -O E13.5_male.RNASeq.rep4_part1_R2.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/097/SRR10560097/SRR10560097_1.fastq.gz" -O E13.5_male.RNASeq.rep4_part2_R1.fq.gz
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR105/097/SRR10560097/SRR10560097_2.fastq.gz" -O E13.5_male.RNASeq.rep4_part2_R2.fq.gz
#         }
#         # re_download
#     }
#     RNASeq
# }
# # PGC_development
#
# spermatogenesis(){
#     # D: Jan-20-2021 15:39 Thu
#     DNAMethylation(){
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086441 PAIRED US.WGBS.rep1 mm10
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086442 PAIRED DS.WGBS.rep1 mm10
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086443 PAIRED PS.WGBS.rep1 mm10
#         bash ${shPATH}/WGBS_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086444 PAIRED RS.WGBS.rep1 mm10
#     }
#     # DNAMethylation
#
#     ChIPseq(){
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086425 PAIRED US.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086426 PAIRED US.H3K9me3.rep2 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086427 PAIRED US.H3K9me3.rep3 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086429 PAIRED DS.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086430 PAIRED DS.H3K9me3.rep2 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086431 PAIRED DS.H3K9me3.rep3 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086433 PAIRED PS.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086434 PAIRED PS.H3K9me3.rep2 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086435 PAIRED PS.H3K9me3.rep3 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086437 PAIRED RS.H3K9me3.rep1 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086438 PAIRED RS.H3K9me3.rep2 mm10
#         bash ${shPATH}/ChIPseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM4086439 PAIRED RS.H3K9me3.rep3 mm10
#     }
#     # ChIPseq
#
#     sampleCor_K9(){
#         # D: Feb-16-2022 20:09 Wed
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/SampleCor;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/SampleCor
#         macs2_peak_bw(){
#             # T: executed in 5m 25s, finished 20:24:53 2022-02-16
#             for sample in US DS PS RS
#             do
#                 for rep in rep1 rep2 rep3
#                 do
#                     cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/${sample}.H3K9me3.${rep} && \
#                     macs2 callpeak -g mm -n ${sample}.H3K9me3.${rep} -B -q 0.05 --nomodel --shift=73 --broad --SPMR -t ${sample}.H3K9me3.${rep}.bam && \
#                     intersectBed -a ${sample}.H3K9me3.${rep}_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.${rep}_treat_pileup.bdg.tmp && \
#                     bedGraphToBigWig ${sample}.H3K9me3.${rep}_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.${rep}.bw && \
#                     cut -f 1-3 ${sample}.H3K9me3.${rep}_peaks.broadPeak > ${sample}.H3K9me3.${rep}.macs2_peaks.bed && \
#                     rm ${sample}.H3K9me3.${rep}_treat_pileup.bdg.tmp &
#                 done # for rep end
#             done # for sample end
#             wait
#         }
#         # macs2_peak_bw
#
#         mergePeak(){
#             # D: Feb-16-2022 20:23 Wed
#             # T: executed in 869ms, finished 20:30:50 2022-02-16
#             cat ../*H3K9me3*/*.macs2_peaks.bed | sort -k1,1 -k2,2n | mergeBed -i - > mergedPeaks.bed # 64,987
#         }
#         # mergePeak
#
#         signal(){
#             # D: Feb-16-2022 20:31 Wed
#             # T: executed in 1m 48.5s, finished 20:36:32 2022-02-16
#             echo -ne "#Chrom\tStart\tEnd" > title.txt
#             cat mergedPeaks.bed > mergedPeaks.H3K9me3.txt
#             for sample in US DS PS RS
#             do
#                 for rep in rep1 rep2 rep3
#                 do
#                     echo -ne "\t${sample}.${rep}" >> title.txt
#                     bash ${shPATH}/averageSignalInRegionPrimaryOrder.sh \
#                         mergedPeaks.bed \
#                         ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/${sample}.H3K9me3.${rep}/${sample}.H3K9me3.${rep}.bw \
#                         1 \
#                         mergedPeaks.H3K9me3_${sample}.${rep}.txt
#
#                     paste mergedPeaks.H3K9me3.txt mergedPeaks.H3K9me3_${sample}.${rep}.txt > tmp && mv tmp mergedPeaks.H3K9me3.txt
#                 done # for rep end
#             done # for sample end
#             echo -ne "\n" >> title.txt
#             cat title.txt mergedPeaks.H3K9me3.txt > tmp && mv tmp mergedPeaks.H3K9me3.txt
#         }
#         # signal
#
#         sampleCor(){
#             # D: Feb-16-2022 20:43 Wed
#             # R: Highly correlated (R >= 0.92)
#             Rscript sampleCor.r
#         }
#         # sampleCor
#     }
#     # sampleCor_K9
#
#     mergeReps_K9(){
#         # D: Feb-16-2022 20:48 Wed
#         T: executed in 9m 41s, finished 21:02:23 2022-02-16
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged
#         samtools view -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/US.H3K9me3.rep1/US.H3K9me3.rep1.bam > header.sam
#         for sample in US DS PS RS
#         do
#             samtools merge -@ 30 -h header.sam ${sample}.H3K9me3.bam ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/${sample}.H3K9me3.*/${sample}.H3K9me3.*bam
#         done # for sample end
#     }
#     # mergeReps_K9
#
#     rmDup_K9(){
#         # D: Feb-16-2022 21:03 Wed
#         # T: executed in 16m 54s, finished 21:21:11 2022-02-16
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged
#         for sample in US DS PS RS
#         do
#             samtools rmdup ${sample}.H3K9me3.bam ${sample}.H3K9me3.rmDup.bam &
#         done # for sample end
#         wait
#     }
#     # rmDup_K9
#
#     callCHM(){
#         # D: Feb-16-2022 21:04 Wed
#         # T: executed in 43m 35s, finished 22:06:18 2022-02-16
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/CHMs;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/CHMs
#         for sample in US DS PS RS
#         do
#             pcar -m callchm \
#                 -H ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged/${sample}.H3K9me3.rmDup.bam \
#                 -M ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed \
#                 -Z ${anPATH}/mm10/mm10_euch.chrom.sizes \
#                 -Q ${anPATH}/mm10/mm10.2bit \
#                 -B 200 \
#                 -N ${sample}_200bp \
#                 -T 6
#         done # for sample end
#     }
#     # callCHM
#
#     prepareSignal(){
#         # D: Feb-17-2022 15:00 Thu
#         mkdir -p ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged;cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/Merged
#         K9(){
#             for sample in US DS PS RS
#             do
#                 macs2 callpeak -g mm -n ${sample}.H3K9me3.rmDup -B -q 0.05 --nomodel --shift=73 --SPMR --broad -t ${sample}.H3K9me3.rmDup.bam && \
#                 intersectBed -a ${sample}.H3K9me3.rmDup_treat_pileup.bdg -b ${anPATH}/mm10/mm10_main.chrom.limits -wa -f 1.00 | sort -k1,1 -k2,2n > ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp && \
#                 bedGraphToBigWig ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp ${anPATH}/mm10/mm10_main.chrom.sizes ${sample}.H3K9me3.rmDup.bw && \
#                 rm ${sample}.H3K9me3.rmDup_treat_pileup.bdg.tmp &
#             done # for sample end
#             wait
#         }
#         # K9
#
#         methyl(){
#             for sample in US DS PS RS
#             do
#                 # ln -s ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/${sample}.WGBS.rep1/${sample}.WGBS.rep1.sam.G.bed ${sample}.methyl.sam.G.bed && \
#                 # grep -v "#" ${sample}.methyl.sam.G.bed | cut -f 1-4 | sort -k1,1 -k2,2n > ${sample}.methyl.sam.G.bed.tmp && \
#                 bedGraphToBigWig ${sample}.methyl.sam.G.bed.tmp ${anPATH}/mm10/mm10.chrom.sizes ${sample}.methyl.all.bw && \
#                 rm ${sample}.methyl.sam.G.bed.tmp &
#             done # for sample end
#             wait
#         }
#         methyl
#     }
#     # prepareSignal
#
#     RNASeq(){
#         # D: Apr-21-2022 00:55 Thu
#         # Data source: GSE55060
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328920 SINGLE GS.RNASeq.rep1 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328921 SINGLE GS.RNASeq.rep2 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328922 SINGLE PS.RNASeq.rep1 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328923 SINGLE PS.RNASeq.rep2 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328926 SINGLE RS.RNASeq.rep1 mm10
#         bash ${shPATH}/RNAseq_processing_publicData.sh ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744 GEO GSM1328927 SINGLE RS.RNASeq.rep2 mm10
#
#         re_download(){
#             # D: May-27-2022 10:23 Fri
#             # GS.RNASeq.rep1
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/GS.RNASeq.rep1
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/007/SRR2005757/SRR2005757.fastq.gz" -O GS.RNASeq.rep1.fq.gz
#
#             # GS.RNASeq.rep2
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/GS.RNASeq.rep2
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/008/SRR2005758/SRR2005758.fastq.gz" -O GS.RNASeq.rep2.fq.gz
#
#             # PS.RNASeq.rep1
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/PS.RNASeq.rep1
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/009/SRR2005759/SRR2005759.fastq.gz" -O PS.RNASeq.rep1.fq.gz
#
#             # PS.RNASeq.rep2
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/PS.RNASeq.rep2
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/000/SRR2005760/SRR2005760.fastq.gz" -O PS.RNASeq.rep2.fq.gz
#
#             # RS.RNASeq.rep1
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/RS.RNASeq.rep1
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/003/SRR2005763/SRR2005763.fastq.gz" -O RS.RNASeq.rep1.fq.gz
#
#             # RS.RNASeq.rep2
#             cd ${dirPATH}/CHMsInOtherContexts/CellStateTransition/Spermatogenesis_GSE137744/RS.RNASeq.rep2
#             wget -c "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR200/004/SRR2005764/SRR2005764.fastq.gz" -O RS.RNASeq.rep2.fq.gz
#         }
#         # re_download
#     }
#     RNASeq
# }
# # spermatogenesis

# %% [markdown]
# #### Correlation between DNA methylation and H3K9me3

# %%
# %%bash
# dirPATH=/mnt/Storage/home/yanghui/imprinting/result.2021/Exploring/CHMsInOtherContexts/CellStateTransition
# shPATH=/mnt/Storage/home/yanghui/scripts/shell
# rPATH=/mnt/Storage/home/yanghui/scripts/R
# anPATH=/mnt/Storage/home/yanghui/annotations
#
# # R: 在不同生物学过程中DNA甲基化和H3K9me3在富含CpG的区域相关性更高，但在视网膜发育过程中相关性相对较低
# prepare(){
#     # D: Apr-14-2022 15:51 Thu
#     # T: executed in 9.95s, finished 15:55:37 2022-04-14
#     mkdir -p ${dirPATH}/Prepare;cd ${dirPATH}/Prepare
#     awk 'BEGIN{FS=OFS="\t"}{if($4<10){print $1, $2, $3;}}' ${anPATH}/mm10/Bins/mm10.b1kb.euchr.CpGnumber > CpGs_low.bed # 1,722,250
#     awk 'BEGIN{FS=OFS="\t"}{if($4>=10 && $4<30){print $1, $2, $3;}}' ${anPATH}/mm10/Bins/mm10.b1kb.euchr.CpGnumber > CpGs_intermediate.bed # 699,059
#     awk 'BEGIN{FS=OFS="\t"}{if($4>=30){print $1, $2, $3;}}' ${anPATH}/mm10/Bins/mm10.b1kb.euchr.CpGnumber > CpGs_high.bed # 41,427
# }
# # prepare
#
# process_cor(){
#     # D: Apr-14-2022 16:10 Thu
#     name=${1} # Spermatogenesis_GSE137744
#     CHM_STAGE=${2} # "US DS PS RS"
#     CHM_STAGE_plot=${3} # "US;DS;PS;RS"
#
#     cd ${dirPATH}/${name}/Merged
#     echo -e "xValue\tyValue\tgroup" > cor.ggplot_basic.txt
#     for group in low intermediate high
#     do
#         for stage in ${CHM_STAGE}
#         do
# #             # DNA methylation level
# #             bash ${shPATH}/averageMethylInRegionMultipleThreads.sh \
# #                 "${dirPATH}/Prepare/CpGs_${group}.bed" \
# #                 "${stage}.methyl.sam.G.bed" \
# #                 "CpGs_${group}.methyl_${stage}.txt" \
# #                 "2"
#
# #             # H3K9me3 signal
# #             bash ${shPATH}/averageSignalInRegionPrimaryOrder.sh \
# #                 "${dirPATH}/Prepare/CpGs_${group}.bed" \
# #                 "${stage}.H3K9me3.rmDup.bw" \
# #                 "1" \
# #                 "CpGs_${group}.H3K9me3_${stage}.txt"
#
#             Rscript ${rPATH}/calculateCor_for_ggplot.r \
#                 "CpGs_${group}.methyl_${stage}.txt" \
#                 "CpGs_${group}.H3K9me3_${stage}.txt" \
#                 "4;1" \
#                 "F" \
#                 "F" \
#                 "${stage}" \
#                 "${group}" \
#                 "cor.ggplot_basic.txt"
#         done # for stage end
#     done # for group end
#
#     Rscript ${rPATH}/ggplot_barplot.r \
#         "cor.ggplot_basic.txt" \
#         "cor.ggplot_barplot.pdf" \
#         "${name}" \
#         "" \
#         "Pearson's correlation coefficient__n(DNA methylation and H3K9me3)" \
#         "-0.2;1;0.2" \
#         "${CHM_STAGE_plot}" \
#         "low;intermediate;high" \
#         "dodge" \
#         "4" \
#         "3.5" \
#         "-007" \
#         "F"
# }
#
# # # T: executed in 3h 3m 41s, finished 19:21:20 2022-04-14
# # process_cor PGCsDevelopment "E9.5 E10.5 E13.5_female E13.5_male" "E9.5;E10.5;E13.5_female;E13.5_male"
# # process_cor Spermatogenesis_GSE137744 "US DS PS RS" "US;DS;PS;RS"
# # process_cor RetinalDevelopment/GSE87064_Mouse "E14.5 E17.5 P0 P3 P7 P10 P14 P21" "E14.5;E17.5;P0;P3;P7;P10;P14;P21"
# # process_cor DendriticCellDevelopment "HSC MPP CDP cDC pDC" "HSC;MPP;CDP;cDC;pDC"
#
# # # D: Apr-18-2022 16:11 Mon
# # process_cor DendriticCellDevelopment "CDP cDC pDC" "CDP;cDC;pDC"
#
# # # D: Apr-18-2022 18:09 Mon
# # # T: executed in 43.8s, finished 18:09:55 2022-04-18
# # process_cor DendriticCellDevelopment "MPP CDP cDC pDC" "MPP;CDP;cDC;pDC"
#
# merge_into_one(){
#     # D: Apr-14-2022 20:57 Thu
#     # D: Apr-18-2022 18:06 Mon
#     mkdir -p ${dirPATH}/Prepare;cd ${dirPATH}/Prepare
#     echo -e "xValue\tyValue\tgroup" > cor.ggplot_basic.txt
#     tail -n +2 ${dirPATH}/PGCsDevelopment/Merged/cor.ggplot_basic.txt >> cor.ggplot_basic.txt
#     tail -n +2 ${dirPATH}/Spermatogenesis_GSE137744/Merged/cor.ggplot_basic.txt >> cor.ggplot_basic.txt
#     tail -n +2 ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/cor.ggplot_basic.txt >> cor.ggplot_basic.txt
#     tail -n +2 ${dirPATH}/DendriticCellDevelopment/Merged/cor.ggplot_basic.txt >> cor.ggplot_basic.txt
#
#     Rscript ${rPATH}/ggplot_barplot.r \
#         "cor.ggplot_basic.txt" \
#         "cor.ggplot_barplot.pdf" \
#         "Biological process" \
#         "" \
#         "Pearson's correlation coefficient__n(DNA methylation and H3K9me3)" \
#         "-0.2;1;0.2" \
#         "E10.5;E13.5_female;E13.5_male;US;DS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#         "low;intermediate;high" \
#         "dodge" \
#         "8" \
#         "3.5" \
#         "-007" \
#         "F"
# }
# # merge_into_one
# Out:
# null device
#           1
# Warning message:
# Removed 1 rows containing missing values (geom_hline).

# %% [markdown]
# #### Features of stable CHMs in different processes

# %%
# %%bash
# dirPATH=/mnt/Storage/home/yanghui/imprinting/result.2021/Exploring/CHMsInOtherContexts/CellStateTransition
# shPATH=/mnt/Storage/home/yanghui/scripts/shell
# rPATH=/mnt/Storage/home/yanghui/scripts/R
# dataPATH_CHM_earlyEmbryo=/mnt/Storage/home/yanghui/imprinting/result.2021/Filtering/CpGrichedHighMethylH3K9me3/Hybrid/ChromHMM/Manage
# anPATH=/mnt/Storage/home/yanghui/annotations
#
# feature_exploration(){
#     # D: Mar-14-2022 22:42 Thu
#     mkdir -p ${dirPATH}/CHMOrganization;cd ${dirPATH}/CHMOrganization
#
#     overlap(){
#         # D: Apr-15-2022 22:52 Fri
#         mkdir -p ${dirPATH}/CHMOrganization/Overlap;cd ${dirPATH}/CHMOrganization/Overlap
#         prepare(){
#             mkdir -p ${dirPATH}/CHMOrganization/EarlyEmbryogenesis;cd ${dirPATH}/CHMOrganization/EarlyEmbryogenesis
#             # ln -s ${dataPATH_CHM_earlyEmbryo}/stable.refined.sorted.filteredBySignal.bed stable.filteredBySignal.bed
#             ln -s ${dataPATH_CHM_earlyEmbryo}/stageSpecific.refined.sorted.filteredBySignal.bed stageSpecific.filteredBySignal.bed # D: Nov-03-2022 11:33 Thu
#             ln -s /mnt/Storage/home/yanghui/imprinting/result.2021/RevisionNCB/RoleOfH3K9me3AtCHMs/Hybrid_nonCHM_CGI/nonCHM_CGIs_HMR.bed nonCHM_CGIs_HMR_euch.bed # D: Nov-03-2022 12:46 Thu
#
#             cd ${dirPATH}/CHMOrganization/Overlap
#             # cat ${dirPATH}/CHMOrganization/*/stable.filteredBySignal.bed | sort -k1,1 -k2,2n | mergeBed -i - -d 2000 > Union.bed # 13,416
#             for process in EarlyEmbryogenesis FemalePGCDevelopment MalePGCDevelopment Spermatogenesis RetinalDevelopment ClassicalDendriticCellDevelopment PlasmacytoidDendriticCellDevelopment
#             do
#                 intersectBed -u -a Union.bed -b ${dirPATH}/CHMOrganization/${process}/stable.filteredBySignal.bed | \
#                     awk 'BEGIN{FS="\t";OFS="_"}{print $1, $2, $3;}' > ${process}.bed
#             done # for process end
#         }
#         prepare
#
#         Rscript UpSetR.r
#     }
#     # overlap
#
#
#     kMeansCluster(){
#         # D: Apr-16-2022 09:41 Sat
#         mkdir -p ${dirPATH}/CHMOrganization/KMeansCluster;cd ${dirPATH}/CHMOrganization/KMeansCluster
#         prepare(){
#             # T: executed in 466ms, finished 09:54:24 2022-04-16
#             cat ${dirPATH}/CHMOrganization/*/stable.filteredBySignal.bed | \
#                 cut -f 1-3 | sort -k1,1 -k2,2n | mergeBed -i - -d 2000 -c 2,3 -o median,median | cut -f 1,4-5 > Union_refined.bed # 13,416
#             echo -ne "#Chrom\tStart\tEnd" > title.txt
#             cat Union_refined.bed > Union_refined.existence.txt
#             for process in EarlyEmbryogenesis FemalePGCDevelopment MalePGCDevelopment Spermatogenesis RetinalDevelopment ClassicalDendriticCellDevelopment PlasmacytoidDendriticCellDevelopment
#             do
#                 echo -ne "\t${process}" >> title.txt
#                 intersectBed -c -a Union_refined.bed -b ${dirPATH}/CHMOrganization/${process}/stable.filteredBySignal.bed | \
#                     cut -f 4 | awk 'BEGIN{FS=OFS="\t"}{if($1==0){print 0;} else{print 1;}}' | \
#                     paste Union_refined.existence.txt - > tmp && mv tmp Union_refined.existence.txt
#             done # for process end
#             echo -ne "\n" >> title.txt
#             cat title.txt Union_refined.existence.txt > tmp && mv tmp Union_refined.existence.txt
#         }
#         # prepare
#     }
#     # kMeansCluster
# }
# # feature_exploration

# %% [markdown]
# #### Universal and process-specific

# %%
# %%bash
# dirPATH=/mnt/Storage/home/yanghui/imprinting/result.2021/Exploring/CHMsInOtherContexts/CellStateTransition
# pyPATH=/mnt/Storage/home/yanghui/scripts/python
# shPATH=/mnt/Storage/home/yanghui/scripts/shell
# binPATH=/mnt/Storage/home/yanghui/scripts/bin
# rPATH=/mnt/Storage/home/yanghui/scripts/R
# anPATH=/mnt/Storage/home/yanghui/annotations
# dataPATH_methyl_hybrid=/mnt/Storage/home/yanghui/data.public/mm10/WGBS/EarlyEmbryos/sam.G.bed
# dataPATH_H3K9me3_hybrid=/mnt/Storage/home/yanghui/data.public/mm10/ChIP-seq/H3K9me3_GSE97778_SNPTraceablePreImplantation_Gao_2018_NCB/Processed
# dataPATH_expr_earlyEmbryo=/mnt/Storage/home/yuzhaowei/projects/imprinting/data_mm10/public/RNA-seq/GSE70605_WCF_RNA-seq
# dataPATH_pad=/mnt/Storage/home/yanghui/data.public/sat4C/GSE65618_deLaat_GR/processed/ESC.PADs_processed.mm10.bed
# dataPATH_enhancer=/mnt/Storage/home/yanghui/annotations/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed
# dataPATH_promoter=/mnt/Storage/home/yanghui/annotations/mm10/mm10.promoter.refGene.bed
#
# mkdir -p ${dirPATH}/CHMOrganization/Universal_specific;cd ${dirPATH}/CHMOrganization/Universal_specific
# group(){
#     # D: Apr-17-2022 16:52 Sun
#     # # T: executed in 441ms, finished 17:02:04 2022-04-17
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==1 && $5==1 && $6==1 && $7==1 && $8==1){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > Universal.bed # 2,424
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==1 && $5==0 && $6==0 && $7==0 && $8==0){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > EarlyEmbryoSpecific.bed # 599
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==0 && $5==1 && $6==0 && $7==0 && $8==0){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > PGCSpecific.bed # 355
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==0 && $5==0 && $6==1 && $7==0 && $8==0){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > SpermSpecific.bed # 744
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==0 && $5==0 && $6==0 && $7==1 && $8==0){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > RetinalSpecific.bed # 701
#     # awk 'BEGIN{FS=OFS="\t"}{if($4==0 && $5==0 && $6==0 && $7==0 && $8==1){print $1, $2, $3;}}' ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt > DCSpecific.bed # 13,287
#
#     # D: Nov-03-2022 11:27 Thu
#     # T: executed in 759ms, finished 11:42:14 2022-11-03
#     # nonCHM_CGIs, potential enhancer, promoter
#     # cat ${dirPATH}/CHMOrganization/*/*.filteredBySignal.bed | intersectBed -v -a ${anPATH}/mm10/mm10.cpgIslandExtUnmasked.bed -b - | \
#     #                 grep -w "^chr[0-9]\{1,2\}" > nonCHM_CGIs.bed # 13,115
#     # ln -s ${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed enhancer.bed # 1,124,888
#     # ln -s ${anPATH}/mm10/mm10.promoter.refGene.bed promoter.bed # 47,382
#
#     # D: Nov-06-2022 20:06 Sun
#     # LTR, LINE, SINE
#     ln -s ${anPATH}/mm10/Repeats/mm10.LTR.bed LTR.bed
#     ln -s ${anPATH}/mm10/Repeats/mm10.LINE.bed LINE.bed
#     ln -s ${anPATH}/mm10/Repeats/mm10.SINE.bed SINE.bed
#
#
#     # D: Nov-03-2022 12:47 Thu
#     # T: executed in 117ms, finished 12:51:39 2022-11-03
#     # nonCHM_CGIs_HMR
#     cat ${dirPATH}/CHMOrganization/*/nonCHM_CGIs_HMR_euch.bed | cut -f 1-3 | sort -k1,1 -k2,2n | mergeBed -i - > nonCHM_CGIs_HMR.bed # 3,250
# }
# # group
#
# signals(){
#     # D: Apr-17-2022 17:08 Sun
#     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Signals;cd ${dirPATH}/CHMOrganization/Universal_specific/Signals
#     prepare(){
#         mkdir -p ${dirPATH}/EarlyEmbryogenesis/Merged;cd ${dirPATH}/EarlyEmbryogenesis/Merged
#         ln -s ${dataPATH_methyl_hybrid}/2cell.sam.G.bed 2cell.methyl.sam.G.bed
#         ln -s ${dataPATH_methyl_hybrid}/8cell.sam.G.bed 8cell.methyl.sam.G.bed
#         ln -s ${dataPATH_methyl_hybrid}/Morula.sam.G.bed Morula.methyl.sam.G.bed
#         ln -s ${dataPATH_methyl_hybrid}/ICM.sam.G.bed ICM.methyl.sam.G.bed
#         ln -s ${dataPATH_H3K9me3_hybrid}/bw.files/2cell.H3K9me3.bw 2cell.H3K9me3.rmDup.bw
#         ln -s ${dataPATH_H3K9me3_hybrid}/bw.files/8cell.H3K9me3.bw 8cell.H3K9me3.rmDup.bw
#         ln -s ${dataPATH_H3K9me3_hybrid}/bw.files/Morula.H3K9me3.bw Morula.H3K9me3.rmDup.bw
#         ln -s ${dataPATH_H3K9me3_hybrid}/bw.files/ICM.H3K9me3.bw ICM.H3K9me3.rmDup.bw
#     }
#     # prepare
#
#     order(){
#         # T: executed in 29ms, finished 17:20:24 2022-04-17
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific;cd ${dirPATH}/CHMOrganization/Universal_specific
#         # cat Universal.bed EarlyEmbryoSpecific.bed PGCSpecific.bed SpermSpecific.bed RetinalSpecific.bed DCSpecific.bed > ordered.bed # 18,110
#
#         # # executed in 147ms, finished 18:32:19 2022-04-17
#         # intersectBed -wao -a ordered.bed -b ${dirPATH}/CHMOrganization/KMeansCluster/Union_refined.existence.txt -f 1.00 -r | \
#         #     cut -f 4-11 > ordered.existence.txt
#
#         # T: executed in 777ms, finished 18:38:32 2022-04-17
#         Rscript ${rPATH}/heatmap_mat_1.r \
#             "ordered.existence" \
#             "3" \
#             "5" \
#             "5;1" \
#             "1" \
#             "0" \
#             "1" \
#             "ordered.existence.txt" \
#             "T" \
#             "$(seq 4 8)" \
#             "EarlyEmbryo;PGC;Sperm;Retina;DCs" \
#             "" \
#             "13287;13988;14732;15087;15686" \
#             "-007" \
#             "pdf" \
#             "#7570B3" \
#             "Reverse"
#     }
#     # order
#
#     prepareFiles(){
#         # T: executed in 84ms, finished 17:28:30 2022-04-17
#         for stage in 2cell 8cell Morula ICM
#         do
#             ln -s ${dirPATH}/EarlyEmbryogenesis/Merged/${stage}.methyl.sam.G.bed ${stage}.methyl.sam.G.bed
#             ln -s ${dirPATH}/EarlyEmbryogenesis/Merged/${stage}.H3K9me3.rmDup.bw ${stage}.H3K9me3.rmDup.bw
#         done # for stage end
#
#         for stage in E10.5 E13.5_female E13.5_male
#         do
#             ln -s ${dirPATH}/PGCsDevelopment/Merged/${stage}.methyl.sam.G.bed ${stage}.methyl.sam.G.bed
#             ln -s ${dirPATH}/PGCsDevelopment/Merged/${stage}.H3K9me3.rmDup.bw ${stage}.H3K9me3.rmDup.bw
#         done # for stage end
#
#         for stage in US DS PS RS
#         do
#             ln -s ${dirPATH}/Spermatogenesis_GSE137744/Merged/${stage}.methyl.sam.G.bed ${stage}.methyl.sam.G.bed
#             ln -s ${dirPATH}/Spermatogenesis_GSE137744/Merged/${stage}.H3K9me3.rmDup.bw ${stage}.H3K9me3.rmDup.bw
#         done # for stage end
#
#         for stage in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#         do
#             ln -s ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/${stage}.methyl.sam.G.bed ${stage}.methyl.sam.G.bed
#             ln -s ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/${stage}.H3K9me3.rmDup.bw ${stage}.H3K9me3.rmDup.bw
#         done # for stage end
#
#         for stage in MPP CDP cDC pDC
#         do
#             ln -s ${dirPATH}/DendriticCellDevelopment/Merged/${stage}.methyl.sam.G.bed ${stage}.methyl.sam.G.bed
#             ln -s ${dirPATH}/DendriticCellDevelopment/Merged/${stage}.H3K9me3.rmDup.bw ${stage}.H3K9me3.rmDup.bw
#         done # for stage end
#     }
#     # prepareFiles
#
#     methyl(){
#         echo -ne "#Chrom\tStart\tEnd" > title.txt
#         sort -k1,1 -k2,2n ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed > ordered.methyl.txt
#         for stage in 2cell 8cell Morula ICM E10.5 E13.5_female E13.5_male US DS PS RS E14.5 E17.5 P0 P3 P7 P10 P14 P21 MPP
#         do
#             echo -ne "\t${stage}" >> title.txt
#             bash ${shPATH}/averageMethylInRegionMultipleThreads.sh \
#                 ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed \
#                 ${stage}.methyl.sam.G.bed \
#                 ordered.methyl_${stage}.txt \
#                 6
#             sort -k1,1 -k2,2n ordered.methyl_${stage}.txt | cut -f 4 | paste ordered.methyl.txt - > tmp && mv tmp ordered.methyl.txt
#         done # for stage end
#
#         for stage in CDP cDC pDC
#         do
#             echo -ne "\t${stage}" >> title.txt
#             bash ${shPATH}/averageMethylInRegionMultipleThreads.sh \
#                 ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed \
#                 ${stage}.methyl.sam.G.bed \
#                 ordered.methyl_${stage}.txt \
#                 2
#             sort -k1,1 -k2,2n ordered.methyl_${stage}.txt | cut -f 4 | paste ordered.methyl.txt - > tmp && mv tmp ordered.methyl.txt
#         done # for stage end
#         echo -ne "\n" >> title.txt
#         intersectBed -wao -a ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed -b ordered.methyl.txt -f 1.00 -r | \
#             cut -f 4-29 >> title.txt
#         mv title.txt ordered.methyl.final.txt
#     }
#     # methyl
#
#     H3K9me3(){
#         echo -ne "#Chrom\tStart\tEnd" > title.txt
#         cat ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed > ordered.H3K9me3.txt
#         for stage in 2cell 8cell Morula ICM E10.5 E13.5_female E13.5_male US DS PS RS E14.5 E17.5 P0 P3 P7 P10 P14 P21 MPP CDP cDC pDC
#         do
#             echo -ne "\t${stage}" >> title.txt
#             bash ${shPATH}/averageSignalInRegionPrimaryOrder.sh \
#                 ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed \
#                 ${stage}.H3K9me3.rmDup.bw \
#                 1 \
#                 ${stage}.H3K9me3_${stage}.txt
#             paste ordered.H3K9me3.txt ${stage}.H3K9me3_${stage}.txt > tmp && mv tmp ordered.H3K9me3.txt
#         done # for stage end
#         echo -ne "\n" >> title.txt
#         cat title.txt ordered.H3K9me3.txt > ordered.H3K9me3.final.txt
#     }
#     # H3K9me3
#
#     heatmap(){
#         # D: Apr-17-2022 18:21 Sun
#         # DNA methylation level
#         Rscript ${rPATH}/heatmap_mat_1.r \
#             "ordered.methyl.final" \
#             "3" \
#             "5" \
#             "5;1" \
#             "1" \
#             "0.4" \
#             "0.6" \
#             "ordered.methyl.final.txt" \
#             "T" \
#             "$(seq 4 26)" \
#             "" \
#             "" \
#             "13287;13988;14732;15087;15686" \
#             "-007" \
#             "pdf" \
#             "#DA404E" \
#             "Reverse"
#
#         # H3K9me3
#         # T: executed in 4.79s, finished 14:27:51 2022-04-18
#         Rscript ${rPATH}/heatmap_mat_1.r \
#             "ordered.H3K9me3.final" \
#             "3" \
#             "5" \
#             "5;1" \
#             "0.3" \
#             "0" \
#             "0.3" \
#             "ordered.H3K9me3.final.txt" \
#             "T" \
#             "$(seq 4 26)" \
#             "" \
#             "" \
#             "13287;13988;14732;15087;15686" \
#             "-007" \
#             "pdf" \
#             "#507f9B" \
#             "Reverse"
#
#         pdftoppm -png -r 300 ordered.methyl.final.pdf ordered.methyl.final
#         pdftoppm -png -r 300 ordered.H3K9me3.final.pdf ordered.H3K9me3.final
#     }
#     # heatmap
#
#     bin_1kb(){
#         # D: Apr-18-2022 18:11 Mon
#         mkdir -p ${dirPATH}/CHMOrganization/1kbBins;cd ${dirPATH}/CHMOrganization/1kbBins
#
#         manage_data(){
#             echo -e "xValue\tyValue\tgroup" > methyl.ggplot_basic.txt
#             echo -e "xValue\tyValue\tgroup" > H3K9me3.ggplot_basic.txt
#             # PGC development
#             for stage in E10.5 E13.5_female E13.5_male
#             do
#                 cat ${dirPATH}/PGCsDevelopment/Merged/CpGs_*.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> methyl.ggplot_basic.txt
#                 cat ${dirPATH}/PGCsDevelopment/Merged/CpGs_*.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # Spermatogenesis_GSE137744
#             for stage in US DS PS RS
#             do
#                 cat ${dirPATH}/Spermatogenesis_GSE137744/Merged/CpGs_*.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> methyl.ggplot_basic.txt
#                 cat ${dirPATH}/Spermatogenesis_GSE137744/Merged/CpGs_*.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # RetinalDevelopment
#             for stage in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#             do
#                 cat ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/CpGs_*.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> methyl.ggplot_basic.txt
#                 cat ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/CpGs_*.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # DendriticCellDevelopment
#             for stage in MPP CDP cDC pDC
#             do
#                 cat ${dirPATH}/DendriticCellDevelopment/Merged/CpGs_*.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> methyl.ggplot_basic.txt
#                 cat ${dirPATH}/DendriticCellDevelopment/Merged/CpGs_*.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> H3K9me3.ggplot_basic.txt
#             done # for stage end
#         }
#         # manage_data
#
#         boxplot(){
#             # # DNA methylation level
#             # Rscript ${rPATH}/ggplot_boxplot.r \
#             #       methyl.ggplot_basic.txt \
#             #       methyl.ggplot_boxplot.pdf \
#             #       "DNA methylation level" \
#             #       "" \
#             #       "DNA methylation level" \
#             #       "0" \
#             #       "1" \
#             #       "0.2" \
#             #       "E10.5;E13.5_female;E13.5_male;US;DS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#             #       "methyl" \
#             #       "6" \
#             #       "4"
#
#             # H3K9me3
#             Rscript ${rPATH}/ggplot_boxplot.r \
#                   H3K9me3.ggplot_basic.txt \
#                   H3K9me3.ggplot_boxplot.pdf \
#                   "H3K9me3" \
#                   "" \
#                   "H3K9me3" \
#                   "0" \
#                   "0.2" \
#                   "0.1" \
#                   "E10.5;E13.5_female;E13.5_male;US;DS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#                   "H3K9me3" \
#                   "6" \
#                   "4"
#         }
#         boxplot
#     }
#     # bin_1kb
#
#     bin_1kb_CpGrich(){
#         # D: May-16-2022 17:32 Mon
#         mkdir -p ${dirPATH}/CHMOrganization/1kbBins;cd ${dirPATH}/CHMOrganization/1kbBins
#
#         manage_data(){
#             echo -e "xValue\tyValue\tgroup" > CpGrich_methyl.ggplot_basic.txt
#             echo -e "xValue\tyValue\tgroup" > CpGrich_H3K9me3.ggplot_basic.txt
#             # PGC development
#             for stage in E10.5 E13.5_female E13.5_male
#             do
#                 cat ${dirPATH}/PGCsDevelopment/Merged/CpGs_high.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> CpGrich_methyl.ggplot_basic.txt
#                 cat ${dirPATH}/PGCsDevelopment/Merged/CpGs_high.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> CpGrich_H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # Spermatogenesis_GSE137744
#             for stage in US DS PS RS
#             do
#                 cat ${dirPATH}/Spermatogenesis_GSE137744/Merged/CpGs_high.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> CpGrich_methyl.ggplot_basic.txt
#                 cat ${dirPATH}/Spermatogenesis_GSE137744/Merged/CpGs_high.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> CpGrich_H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # RetinalDevelopment
#             for stage in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#             do
#                 cat ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/CpGs_high.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> CpGrich_methyl.ggplot_basic.txt
#                 cat ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/Merged/CpGs_high.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> CpGrich_H3K9me3.ggplot_basic.txt
#             done # for stage end
#
#             # DendriticCellDevelopment
#             for stage in MPP CDP cDC pDC
#             do
#                 cat ${dirPATH}/DendriticCellDevelopment/Merged/CpGs_high.methyl_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, "methyl";}' >> CpGrich_methyl.ggplot_basic.txt
#                 cat ${dirPATH}/DendriticCellDevelopment/Merged/CpGs_high.H3K9me3_${stage}.txt | \
#                     awk -v XVALUE=${stage} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, "H3K9me3";}' >> CpGrich_H3K9me3.ggplot_basic.txt
#             done # for stage end
#         }
#         # manage_data
#
#         boxplot(){
#             # # DNA methylation level
#             # Rscript ${rPATH}/ggplot_boxplot.r \
#             #       CpGrich_methyl.ggplot_basic.txt \
#             #       CpGrich_methyl.ggplot_boxplot.pdf \
#             #       "DNA methylation level" \
#             #       "" \
#             #       "DNA methylation level" \
#             #       "0" \
#             #       "1" \
#             #       "0.2" \
#             #       "E10.5;E13.5_female;E13.5_male;US;DS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#             #       "methyl" \
#             #       "6" \
#             #       "4"
#
#             # H3K9me3
#             Rscript ${rPATH}/ggplot_boxplot.r \
#                   CpGrich_H3K9me3.ggplot_basic.txt \
#                   CpGrich_H3K9me3.ggplot_boxplot.pdf \
#                   "H3K9me3" \
#                   "" \
#                   "H3K9me3" \
#                   "0" \
#                   "0.75" \
#                   "0.25" \
#                   "E10.5;E13.5_female;E13.5_male;US;DS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#                   "H3K9me3" \
#                   "6" \
#                   "4"
#         }
#         boxplot
#     }
#     bin_1kb_CpGrich
#
#     H3K9me3_profile_DC(){
#         # D: Apr-24-2022 18:15 Sun
#         for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#         do
#             for stage in MPP CDP cDC pDC
#             do
#                 bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                     10000 \
#                     10000 \
#                     100 \
#                     ${stage}.H3K9me3.rmDup.bw \
#                     ${stage} \
#                     H3K9me3Surrounding${group} \
#                     "-10kb;Center;10kb" \
#                     "0;50.5;100" \
#                     "H3K9me3 signal (RPM)" \
#                     "0" \
#                     "0.3" \
#                     "Dark2"
#             done # for stage end
#         done # for group end
#     }
#     # H3K9me3_profile_DC
# }
# # signals
#
# features(){
#     # D: Apr-17-2022 19:09 Sun
#     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features;cd ${dirPATH}/CHMOrganization/Universal_specific/Features
#     regionEnrichment(){
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment
#         each(){
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#               bash ${shPATH}/regionEnrichment_userDefined.sh \
#                "${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment" \
#                "mm10_euch" \
#                "${anPATH}/mm10/mm10.chrom.sizes" \
#                "${dirPATH}/CHMOrganization/Universal_specific/${group}.bed" \
#                "${anPATH}/mm10/RegionEnrichment/mm10_euch.promoter.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.geneBody.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intergenic.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.exon.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intron.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI_Unmasked.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.SINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LTR.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.PAD.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed;" \
#                "${group}"
#             done # for group end
#         }
#         # each
#
#         merge_and_plot(){
#             # D: Apr-17-2022 19:18 Sun
#             echo -e "xValue\tyValue\tgroup" > overlapRatio.ggplot_basic.txt
#             echo -e "xValue\tyValue\tgroup" > regionEnrich.ggplot_basic.txt
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 tail -n +2 ${group}.overlaped.txt | awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print $1, $3*100, GROUP;}' >> overlapRatio.ggplot_basic.txt
#                 tail -n +2 ${group}.EnrichScore.txt | awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print $1, $2, GROUP;}' >> regionEnrich.ggplot_basic.txt
#             done # for group end
#
#             Rscript ${rPATH}/ggplot_barplot.r \
#                 "overlapRatio.ggplot_basic.txt" \
#                 "overlapRatio.ggplot_barplot.pdf" \
#                 "Overlapped ratio" \
#                 "" \
#                 "Percentage (%)" \
#                 "0;100;20" \
#                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR;PAD;potentialEnhancer" \
#                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                 "dodge" \
#                 "10" \
#                 "3.5" \
#                 "-007" \
#                 "F"
#
#             Rscript ${rPATH}/ggplot_barplot.r \
#                 "regionEnrich.ggplot_basic.txt" \
#                 "regionEnrich.ggplot_barplot.pdf" \
#                 "Enrichment score" \
#                 "" \
#                 "Enrichment score" \
#                 "-6;6;3" \
#                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR;PAD;potentialEnhancer" \
#                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                 "dodge" \
#                 "10" \
#                 "3.5" \
#                 "-1;1" \
#                 "F"
#         }
#         # merge_and_plot
#
#         LINE_F(){
#             # D: Apr-17-2022 22:11 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 bash ${shPATH}/regionEnrichment_LINE_mm10.sh \
#                     ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily \
#                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                     ${group}
#             done # for group end
#         }
#         # LINE_F
#
#         LTR_F(){
#             # D: Apr-17-2022 22:14 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 bash ${shPATH}/regionEnrichment_LTR_mm10.sh \
#                     ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily \
#                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                     ${group}
#             done # for group end
#         }
#         # LTR_F
#
#         LINE_F_sina(){
#             # D: Apr-17-2022 22:58 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily
#             # echo -e "xValue\tyValue\tgroup\tcol\tlabel" > enrichmentScore.ggplot_sina.txt
#             # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             # do
#             #     for fml in CR1 Dong-R4 Jockey L1 L1-Tx1 L2 Penelope RTE-BovB RTE-X
#             #     do
#             #         tail -n +2 ${group}.EnrichScore_LINE_${fml}.txt | \
#             #             awk -v XVALUE=${group} -v COL=${fml} 'BEGIN{FS=OFS="\t"}{\
#             #             if($2=="-inf"){{print XVALUE, "-8", "LINE", COL, "";}} else{\
#             #             if($2>=3){print XVALUE, $2, "LINE", COL, $1;} else{print XVALUE, $2, "LINE", COL, "";}}}' >> enrichmentScore.ggplot_sina.txt
#             #     done # for fml end
#             # done # for group end
#             #
#             # Rscript ${rPATH}/ggplot_sina_colorfull.r \
#             #     enrichmentScore.ggplot_sina.txt \
#             #     enrichmentScore.ggplot_sina.pdf \
#             #     "Enrichment score" \
#             #     "-8;8;2" \
#             #     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#             #     "LINE" \
#             #     "CR1;Dong-R4;Jockey;L1;L1-Tx1;L2;Penelope;RTE-BovB;RTE-X" \
#             #     "#CE0013;#16557A;#C7A609;#87C232;#64C0AB;#A14C94;#8B7E75;#1187CD;#000000" \
#             #     "0.2" \
#             #     "0.75" \
#             #     "1;3" \
#             #     "5" \
#             #     "5"
#
#             echo -e "xValue\tyValue\tgroup\tcol\tlabel" > enrichmentScore.ggplot_sina_details.txt
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 for fml in CR1 Dong-R4 Jockey L1 L1-Tx1 L2 Penelope RTE-BovB RTE-X
#                 do
#                     tail -n +2 ${group}.EnrichScore_LINE_${fml}.txt | \
#                         awk -v XVALUE=${group} -v COL=${fml} 'BEGIN{FS=OFS="\t"}{\
#                         if($2=="-inf"){{print XVALUE, "-8", "LINE", COL, $1;}} else{\
#                         print XVALUE, $2, "LINE", COL, $1;}}' >> enrichmentScore.ggplot_sina_details.txt
#                 done # for fml end
#             done # for group end
#         }
#         # LINE_F_sina
#
#         LTR_F_sina(){
#             # D: Apr-17-2022 23:34 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily
#             # echo -e "xValue\tyValue\tgroup\tcol\tlabel" > enrichmentScore.ggplot_sina.txt
#             # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             # do
#             #     for fml in ERV1 "ERV1?" ERVK "ERVK?" ERVL ERVL-MaLR "ERVL?" Gypsy "Gypsy?"
#             #     do
#             #         tail -n +2 ${group}.EnrichScore_LTR_${fml}.txt | \
#             #             awk -v XVALUE=${group} -v COL=${fml} 'BEGIN{FS=OFS="\t"}{\
#             #             if($2=="-inf"){{print XVALUE, "-8", "LTR", COL, "";}} else{\
#             #             if($2>=-10){print XVALUE, $2, "LTR", COL, $1;} else{print XVALUE, $2, "LINE", COL, "";}}}' >> enrichmentScore.ggplot_sina.txt
#             #     done # for fml end
#             # done # for group end
#
#             # Rscript ${rPATH}/ggplot_sina_colorfull.r \
#             #     enrichmentScore.ggplot_sina.txt \
#             #     enrichmentScore.ggplot_sina.pdf \
#             #     "Enrichment score" \
#             #     "-8;8;2" \
#             #     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#             #     "LTR" \
#             #     "ERV1;ERV1?;ERVK;ERVK?;ERVL;ERVL-MaLR;ERVL?;Gypsy;Gypsy?" \
#             #     "#CE0013;#16557A;#C7A609;#87C232;#64C0AB;#A14C94;#8B7E75;#1187CD;#000000" \
#             #     "0.2" \
#             #     "0.75" \
#             #     "1" \
#             #     "5" \
#             #     "5"
#
#             Rscript ${rPATH}/ggplot_sina_colorfull.r \
#                 enrichmentScore.ggplot_sina.txt \
#                 enrichmentScore_filtered.ggplot_sina.pdf \
#                 "Enrichment score" \
#                 "-8;8;2" \
#                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                 "LTR" \
#                 "ERV1;ERVK;ERVL;ERVL-MaLR;Gypsy" \
#                 "#CE0013;#C7A609;#64C0AB;#A14C94;#1187CD" \
#                 "0.2" \
#                 "0.75" \
#                 "1" \
#                 "5" \
#                 "5"
#         }
#         # LTR_F_sina
#
#         LINE_F_sina_enrich_pie(){
#             # D: Apr-18-2022 10:59 Mon
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 # echo -e "value\tgroup" > ${group}.enriched.basic_pieplot.txt
#                 # for fml in CR1 Dong-R4 Jockey L1 L1-Tx1 L2 Penelope RTE-BovB RTE-X
#                 # do
#                 #     tail -n +2 ${group}.EnrichScore_LINE_${fml}.txt | \
#                 #         awk -v GROUP=${fml} 'BEGIN{FS=OFS="\t";TOTAL=0;}{\
#                 #         if($2>=1){TOTAL+=1;}}END{print TOTAL, GROUP;}' >> ${group}.enriched.basic_pieplot.txt
#                 # done # for fml end
#
#                 Rscript ${rPATH}/ggplot_pie.r \
#                     ${group}.enriched.basic_pieplot.txt \
#                     ${group} \
#                     "CR1;Dong-R4;Jockey;L1;L1-Tx1;L2;Penelope;RTE-BovB;RTE-X" \
#                     "#CE0013;#16557A;#C7A609;#87C232;#64C0AB;#A14C94;#8B7E75;#1187CD;#000000" \
#                     T \
#                     3.5 \
#                     3.5
#             done # for group end
#         }
#         # LINE_F_sina_enrich_pie
#
#         LTR_F_sina_enrich_pie(){
#             # D: Apr-18-2022 11:44 Mon
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 echo -e "value\tgroup" > ${group}.enriched.basic_pieplot.txt
#                 for fml in ERV1 "ERV1?" ERVK "ERVK?" ERVL ERVL-MaLR "ERVL?" Gypsy "Gypsy?"
#                 do
#                     tail -n +2 ${group}.EnrichScore_LTR_${fml}.txt | \
#                         awk -v GROUP=${fml} 'BEGIN{FS=OFS="\t";TOTAL=0;}{\
#                         if($2>=1){TOTAL+=1;}}END{print TOTAL, GROUP;}' >> ${group}.enriched.basic_pieplot.txt
#                 done # for fml end
#
#                 Rscript ${rPATH}/ggplot_pie.r \
#                     ${group}.enriched.basic_pieplot.txt \
#                     ${group} \
#                     "ERV1;ERV1?;ERVK;ERVK?;ERVL;ERVL-MaLR;ERVL?;Gypsy;Gypsy?" \
#                     "#CE0013;#16557A;#C7A609;#87C232;#64C0AB;#A14C94;#8B7E75;#1187CD;#000000" \
#                     T \
#                     3.5 \
#                     3.5
#             done # for group end
#         }
#         # LTR_F_sina_enrich_pie
#
#         LINE_F_sina_enrich_group(){
#             # D: Apr-18-2022 12:22 Mon
#             # T: executed in 81ms, finished 12:36:47 2022-04-18
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LINE/SubFamily
#             # cat *.EnrichScore_*.txt | grep -v "EnrichScore" | \
#             #     awk 'BEGIN{FS=OFS="\t";}{if($2!="-inf" && $2>=1){print $1;}}' | sort -u > subfml_enriched.txt # 40
#             #
#             # cat *.EnrichScore_*.txt | grep -v "EnrichScore" | \
#             #     awk 'BEGIN{FS=OFS="\t";}{if($2=="-inf" || $2<1){print $1;}}' | sort -u | grep -wvf subfml_enriched.txt - > subfml_nonenriched.txt # 201
#             #
#             # # T: executed in 334ms, finished 12:44:11 2022-04-18
#             # for subfml in $(cut -f 1 subfml_enriched.txt)
#             # do
#             #     cat ${anPATH}/mm10/Repeats/LINE/*/mm10.${subfml}.bed | cut -f 1-3 >> subfml_enriched.bed #
#             # done # for subfml
#
#             # for subfml in $(cut -f 1 subfml_nonenriched.txt)
#             # do
#             #     cat ${anPATH}/mm10/Repeats/LINE/*/mm10.${subfml}.bed | cut -f 1-3 >> subfml_nonenriched.bed #
#             # done # for subfml
#
#             enriched_manage_for_table(){
#                 # D: Apr-19-2022 21:12 Tue
#                 # T: executed in 525ms, finished 21:18:13 2022-04-19
#                 echo -e "Process\tFamily\tSubfamily" > enriched.LINE.txt
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                     for fml in CR1 Dong-R4 Jockey L1 L1-Tx1 L2 Penelope RTE-BovB RTE-X
#                     do
#                         tail -n +2 ${group}.EnrichScore_LINE_${fml}.txt | \
#                             awk -v PROCESS=${group} -v FAMILY=${fml} 'BEGIN{FS=OFS="\t"}{\
#                             if($2!="-inf" && $2>=1){print PROCESS, FAMILY, $1;}}' >> enriched.LINE.txt
#                     done # for fml end
#                 done # for group end
#             }
#             # enriched_manage_for_table
#
#             enriched_overlap(){
#                 # D: Apr-19-2022 21:57 Tue
#                 Rscript UpSetR.r
#
#             }
#             # enriched_overlap
#
#             phastCons60wayPlacental(){
#                 # D: Apr-18-2022 12:51 Mon
#                 echo -e "xValue\tyValue\tgroup" > phastCons60wayPlacental.ggplot_basic.txt
#                 for group in enriched nonenriched
#                 do
#                     bash ${shPATH}/averageSignalInRegion.sh \
#                         subfml_${group}.bed \
#                         ${anPATH}/mm10/Conservation/mm10.60way.phastCons60wayPlacental.bw \
#                         1 \
#                         ${group}.phastConsPlacental.txt
#                     awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print "LINE", $4, GROUP;}' \
#                         ${group}.phastConsPlacental.txt >> phastCons60wayPlacental.ggplot_basic.txt
#                 done # for group end
#
#                 # Violin plot
#                 Rscript ${rPATH}/ggplot_violin.r \
#                     phastCons60wayPlacental.ggplot_basic.txt \
#                     phastCons60wayPlacental.ggplot_violin.pdf \
#                     LINE \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.6 \
#                     0.2 \
#                     "LINE" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#
#                 # box plot
#                 Rscript ${rPATH}/ggplot_boxplot.r \
#                     phastCons60wayPlacental.ggplot_basic.txt \
#                     phastCons60wayPlacental.ggplot_boxplot.pdf \
#                     LINE \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.4 \
#                     0.2 \
#                     "LINE" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#             }
#             phastCons60wayPlacental
#
#             significance_log(){
#                 echo -e "
#                     [1] wilcox.test of LINE
#                     # A tibble: 1 × 8
#                       .y.    group1   group2          p p.adj p.format p.signif method
#                       <chr>  <chr>    <chr>       <dbl> <dbl> <chr>    <chr>    <chr>
#                     1 yValue enriched nonenriched     0     0 <2e-16   ****     Wilcoxon"
#             }
#
#             phastCons(){
#                 # D: Apr-18-2022 13:26 Mon
#                 echo -e "xValue\tyValue\tgroup" > phastCons.ggplot_basic.txt
#                 for group in enriched nonenriched
#                 do
#                     bash ${shPATH}/averageSignalInRegion.sh \
#                         subfml_${group}.bed \
#                         ${anPATH}/mm10/Conservation/mm10.60way.phastCons.bw \
#                         1 \
#                         ${group}.phastConsPlacental.txt
#                     awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print "LINE", $4, GROUP;}' \
#                         ${group}.phastConsPlacental.txt >> phastCons.ggplot_basic.txt
#                 done # for group end
#
#                 # Violin plot
#                 Rscript ${rPATH}/ggplot_violin.r \
#                     phastCons.ggplot_basic.txt \
#                     phastCons.ggplot_violin.pdf \
#                     LINE \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.4 \
#                     0.2 \
#                     "LINE" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#
#                 # box plot
#                 Rscript ${rPATH}/ggplot_boxplot.r \
#                     phastCons.ggplot_basic.txt \
#                     phastCons.ggplot_boxplot.pdf \
#                     LINE \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.4 \
#                     0.2 \
#                     "LINE" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#             }
#             # phastCons
#         }
#         # LINE_F_sina_enrich_group
#
#         LTR_F_sina_enrich_group(){
#             # # D: Apr-18-2022 13:15 Mon
#             # # T:
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily
#             # cat *.EnrichScore_*.txt | grep -v "EnrichScore" | \
#             #     awk 'BEGIN{FS=OFS="\t";}{if($2!="-inf" && $2>=1){print $1;}}' | sort -u > subfml_enriched.txt #
#             #
#             # cat *.EnrichScore_*.txt | grep -v "EnrichScore" | \
#             #     awk 'BEGIN{FS=OFS="\t";}{if($2=="-inf" || $2<1){print $1;}}' | sort -u | grep -wvf subfml_enriched.txt - > subfml_nonenriched.txt #
#             #
#             # # T:
#             # for subfml in $(cut -f 1 subfml_enriched.txt)
#             # do
#             #     cat ${anPATH}/mm10/Repeats/LTR/*/mm10.${subfml}.bed | cut -f 1-3 >> subfml_enriched.bed # 238
#             # done # for subfml
#             #
#             # for subfml in $(cut -f 1 subfml_nonenriched.txt)
#             # do
#             #     cat ${anPATH}/mm10/Repeats/LTR/*/mm10.${subfml}.bed | cut -f 1-3 >> subfml_nonenriched.bed # 413
#             # done # for subfml
#
#             enriched_manage_for_table(){
#                 # D: Apr-20-2022 00:23 Wed
#                 # T: executed in 269ms, finished 00:25:00 2022-04-20
#                 echo -e "Process\tFamily\tSubfamily" > enriched.LTR.txt
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                     for fml in ERV1 "ERV1?" ERVK "ERVK?" ERVL ERVL-MaLR "ERVL?" Gypsy "Gypsy?"
#                     do
#                         tail -n +2 ${group}.EnrichScore_LTR_${fml}.txt | \
#                             awk -v PROCESS=${group} -v FAMILY=${fml} 'BEGIN{FS=OFS="\t"}{\
#                             if($2!="-inf" && $2>=1){print PROCESS, FAMILY, $1;}}' >> enriched.LTR.txt
#                     done # for fml end
#                 done # for group end
#             }
#             # enriched_manage_for_table
#
#             enriched_overlap(){
#                 # D: Apr-20-2022 00:25 Wed
#                 Rscript UpSetR.r
#
#             }
#             # enriched_overlap
#
#             phastConsPlacental(){
#                 # D:
#                 echo -e "xValue\tyValue\tgroup" > phastCons60wayPlacental.ggplot_basic.txt
#                 for group in enriched nonenriched
#                 do
#                     bash ${shPATH}/averageSignalInRegion.sh \
#                         subfml_${group}.bed \
#                         ${anPATH}/mm10/Conservation/mm10.60way.phastCons60wayPlacental.bw \
#                         1 \
#                         ${group}.phastConsPlacental.txt
#                     awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print "LTR", $4, GROUP;}' \
#                         ${group}.phastConsPlacental.txt >> phastCons60wayPlacental.ggplot_basic.txt
#                 done # for group end
#
#                 # Violin plot
#                 Rscript ${rPATH}/ggplot_violin.r \
#                     phastCons60wayPlacental.ggplot_basic.txt \
#                     phastCons60wayPlacental.ggplot_violin.pdf \
#                     LTR \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.6 \
#                     0.2 \
#                     "LTR" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#
#                 # box plot
#                 Rscript ${rPATH}/ggplot_boxplot.r \
#                     phastCons60wayPlacental.ggplot_basic.txt \
#                     phastCons60wayPlacental.ggplot_boxplot.pdf \
#                     LTR \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.4 \
#                     0.2 \
#                     "LTR" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#             }
#             # phastConsPlacental
#
#             phastCons(){
#                 # D:
#                 echo -e "xValue\tyValue\tgroup" > phastCons.ggplot_basic.txt
#                 for group in enriched nonenriched
#                 do
#                     bash ${shPATH}/averageSignalInRegion.sh \
#                         subfml_${group}.bed \
#                         ${anPATH}/mm10/Conservation/mm10.60way.phastCons.bw \
#                         1 \
#                         ${group}.phastConsPlacental.txt
#                     awk -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print "LTR", $4, GROUP;}' \
#                         ${group}.phastConsPlacental.txt >> phastCons.ggplot_basic.txt
#                 done # for group end
#
#                 # Violin plot
#                 Rscript ${rPATH}/ggplot_violin.r \
#                     phastCons.ggplot_basic.txt \
#                     phastCons.ggplot_violin.pdf \
#                     LTR \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.6 \
#                     0.2 \
#                     "LTR" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#
#                 # box plot
#                 Rscript ${rPATH}/ggplot_boxplot.r \
#                     phastCons.ggplot_basic.txt \
#                     phastCons.ggplot_boxplot.pdf \
#                     LTR \
#                     "" \
#                     "Conservation score" \
#                     0 \
#                     0.4 \
#                     0.2 \
#                     "LTR" \
#                     "enriched;nonenriched" \
#                     4 \
#                     3
#             }
#             # phastCons
#         }
#         # LTR_F_sina_enrich_group
#
#         LTR_F_sina_enrich_pie_filtered(){
#             # D: May-02-2022 19:37 Mon
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/RegionEnrichment/LTR/SubFamily
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 echo -e "value\tgroup" > ${group}.enriched.basic_pieplot_filtered.txt
#                 for fml in ERV1 ERVK ERVL ERVL-MaLR Gypsy
#                 do
#                     tail -n +2 ${group}.EnrichScore_LTR_${fml}.txt | \
#                         awk -v GROUP=${fml} 'BEGIN{FS=OFS="\t";TOTAL=0;}{\
#                         if($2>=1){TOTAL+=1;}}END{print TOTAL, GROUP;}' >> ${group}.enriched.basic_pieplot_filtered.txt
#                 done # for fml end
#
#                 Rscript ${rPATH}/ggplot_pie.r \
#                     ${group}.enriched.basic_pieplot_filtered.txt \
#                     ${group}_filtered \
#                     "ERV1;ERVK;ERVL;ERVL-MaLR;Gypsy" \
#                     "#CE0013;#C7A609;#64C0AB;#A14C94;#1187CD" \
#                     T \
#                     3.5 \
#                     3.5
#             done # for group end
#         }
#         # LTR_F_sina_enrich_pie_filtered
#     }
#     # regionEnrichment
#
#     length(){
#         # D: Apr-19-2022 11:58 Tue
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/Length;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/Length
#         manage_length(){
#             echo -e "xValue\tyValue\tgroup" > length.ggplot_basic.txt
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 awk -v XVALUE=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, $3-$2, "Length";}' ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed >> length.ggplot_basic.txt
#             done # for group end
#         }
#         # manage_length
#
#         boxplot(){
#             Rscript ${rPATH}/ggplot_boxplot.r \
#                 length.ggplot_basic.txt \
#                 length.ggplot_boxplot.pdf \
#                 Length \
#                 "" \
#                 "Length of stable CHMs" \
#                 0 \
#                 12000 \
#                 2000 \
#                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                 Length \
#                 3.5 \
#                 3.5
#         }
#         # boxplot
#
#         violinplot(){
#             Rscript ${rPATH}/ggplot_violin.r \
#                 length.ggplot_basic.txt \
#                 length.ggplot_violinplot.pdf \
#                 Length \
#                 "" \
#                 "Length of stable CHMs" \
#                 0 \
#                 12000 \
#                 2000 \
#                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                 Length \
#                 4.5 \
#                 3.5
#         }
#         violinplot
#     }
#     # length
#
#     targetGenes(){
#         # D: Apr-20-2022 12:27 Wed
#         # N: Genes within 2kb of stable CHMs
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes
#         genesWithin2kb(){
#             # T: executed in 1.43s, finished 12:37:11 2022-04-20
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb
#             manage(){
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                      windowBed -w 2000 -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed | \
#                          cut -f 8 | sort -u > ${group}.targetGenes.txt # 477, 158, 85, 117, 333, 6694
#                 done # for group end
#
#                 sort -R DCSpecific.targetGenes.txt | head -3000 > DCSpecific.targetGenes_rand1.txt
#                 sort -R DCSpecific.targetGenes.txt | head -3000 > DCSpecific.targetGenes_rand2.txt
#                 sort -R DCSpecific.targetGenes.txt | head -3000 > DCSpecific.targetGenes_rand3.txt
#             }
#             # manage
#
#             DAVID_2021(){
#                 prepare(){
#                     # BP_ALL
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650429689442.txt" -O Universal.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430110573.txt" -O EarlyEmbryoSpecific.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430255416.txt" -O PGCSpecific.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430412492.txt" -O SpermSpecific.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430733111.txt" -O RetinalSpecific.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650431134297.txt" -O DCSpecific_rand1.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433251835.txt" -O DCSpecific_rand2.BP_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433433267.txt" -O DCSpecific_rand3.BP_ALL.txt
#
#                     # CC_ALL
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650429894357.txt" -O Universal.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430135432.txt" -O EarlyEmbryoSpecific.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430284696.txt" -O PGCSpecific.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430437186.txt" -O SpermSpecific.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430760375.txt" -O RetinalSpecific.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650431234916.txt" -O DCSpecific_rand1.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433292623.txt" -O DCSpecific_rand2.CC_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433458403.txt" -O DCSpecific_rand3.CC_ALL.txt
#
#                     # MF_ALL
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650429964292.txt" -O Universal.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430160923.txt" -O EarlyEmbryoSpecific.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/tr211E66E8CC5961650430319114.txt" -O PGCSpecific.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430465227.txt" -O SpermSpecific.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430784349.txt" -O RetinalSpecific.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650431268625.txt" -O DCSpecific_rand1.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433318768.txt" -O DCSpecific_rand2.MF_ALL.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433478106.txt" -O DCSpecific_rand3.MF_ALL.txt
#
#                     # KEGG
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650429988439.txt" -O Universal.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430183836.txt" -O EarlyEmbryoSpecific.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/tr211E66E8CC5961650430498930.txt" -O SpermSpecific.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430806571.txt" -O RetinalSpecific.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433010184.txt" -O DCSpecific_rand1.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433341879.txt" -O DCSpecific_rand2.KEGG.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433497196.txt" -O DCSpecific_rand3.KEGG.txt
#
#                     # BIOGRID_INTERACTION
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430019286.txt" -O Universal.BIOGRID_INTERACTION.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430213512.txt" -O EarlyEmbryoSpecific.BIOGRID_INTERACTION.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_11E66E8CC5961650430833732.txt" -O RetinalSpecific.BIOGRID_INTERACTION.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433038448.txt" -O DCSpecific_rand1.BIOGRID_INTERACTION.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433374195.txt" -O DCSpecific_rand2.BIOGRID_INTERACTION.txt
#                     wget -c "https://david.ncifcrf.gov/data/download/t2t_69CB942DB5841650433519683.txt" -O DCSpecific_rand3.BIOGRID_INTERACTION.txt
#                 }
#                 # prepare
#
#                 plot(){
#                     # D: Apr-20-2022 13:48 Wed
#                     # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific DCSpecific_rand1 DCSpecific_rand2 DCSpecific_rand3
#                     for group in DCSpecific_rand1 DCSpecific_rand2 DCSpecific_rand3
#                     do
#                         for type in BP_ALL CC_ALL MF_ALL KEGG BIOGRID_INTERACTION
#                         do
#                             if [ -f ${group}.${type}.txt ]
#                             then
#                                 python ${binPATH}/GO.py ${group}.${type}.txt
#                                 Rscript ${rPATH}/GO.r ${group}.${type}.plot.txt ${group}.${type}.plot.pdf ${group} 6 3
#                             fi
#                         done # for type end
#                     done # for group end
#                 }
#                 # plot
#
#                 special_KEGG(){
#                     wget -c "https://david.ncifcrf.gov/data/download/tr2C2BD5B1F15B71650452360159.txt" -O RetinalSpecific.KEGG.txt
#                 }
#                 # special_KEGG
#
#                 enriched_GO_Term_genome_enrichment(){
#                     # D: May-16-2022 22:55 Mon
#                     GO_0007155_cell_adhesion(){
#                         # cut -f 2 GO_0007155_cell_adhesion.txt | sort -u > GO_0007155_cell_adhesion.genes.txt # 1,488
#                         # python ${pyPATH}/ExtractSubset.py ExtractSubset GO_0007155_cell_adhesion.genes.txt ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed 4 GO_0007155_cell_adhesion.genes.bed # 3,028
#                         # cut -f 1-3 GO_0007155_cell_adhesion.genes.bed | sort -u | sort -k1,1 -k2,2n | mergeBed -i - > GO_0007155_cell_adhesion.genes.merged.bed # 1,453
#
#                         bash ${shPATH}/regionEnrichment_userDefined.sh \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb" \
#                            "mm10_euch" \
#                            "${anPATH}/mm10/mm10.chrom.sizes" \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/GO_0007155_cell_adhesion.genes.merged.bed" \
#                            "${anPATH}/mm10/RegionEnrichment/mm10_euch.promoter.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.geneBody.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intergenic.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.exon.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intron.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI_Unmasked.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.SINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LTR.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.PAD.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed;" \
#                            "GO_0007155_cell_adhesion.genes"
#                     }
#                     GO_0007155_cell_adhesion
#
#                     GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules(){
#                         # D: May-16-2022 23:39 Mon
#                         cut -f 2 GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.txt | sort -u > GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.txt # 216
#                         python ${pyPATH}/ExtractSubset.py ExtractSubset GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.txt ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed 4 GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.bed # 467
#                         cut -f 1-3 GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.bed | sort -u | sort -k1,1 -k2,2n | mergeBed -i - > GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.merged.bed # 209
#
#                         bash ${shPATH}/regionEnrichment_userDefined.sh \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb" \
#                            "mm10_euch" \
#                            "${anPATH}/mm10/mm10.chrom.sizes" \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes.merged.bed" \
#                            "${anPATH}/mm10/RegionEnrichment/mm10_euch.promoter.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.geneBody.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intergenic.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.exon.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intron.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI_Unmasked.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.SINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LTR.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.PAD.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed;" \
#                            "GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules.genes"
#                     }
#                     # GO_0098742_cell-cell_adhesion_via_plasma-membrane_adhesion_molecules
#
#                     GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules(){
#                         # D: May-16-2022 23:46 Mon
#                         cut -f 2 GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.txt | sort -u > GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.txt # 117
#                         python ${pyPATH}/ExtractSubset.py ExtractSubset GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.txt ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed 4 GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.bed # 212
#                         cut -f 1-3 GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.bed | sort -u | sort -k1,1 -k2,2n | mergeBed -i - > GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.merged.bed # 111
#
#                         bash ${shPATH}/regionEnrichment_userDefined.sh \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb" \
#                            "mm10_euch" \
#                            "${anPATH}/mm10/mm10.chrom.sizes" \
#                            "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes.merged.bed" \
#                            "${anPATH}/mm10/RegionEnrichment/mm10_euch.promoter.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.geneBody.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intergenic.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.exon.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intron.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI_Unmasked.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.SINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LTR.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.PAD.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed;" \
#                            "GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules.genes"
#                     }
#                     # GO_0007156_homophilic_cell_adhesion_via_plasma_membrane_adhesion_molecules
#
#                     all_enriched_GO_terms(){
#                         # D: May-17-2022 09:56 Tue
#                         cat *.BP_ALL.plot.txt *.MF_ALL.plot.txt *.CC_ALL.plot.txt | \
#                             awk -F '[~\t]' 'BEGIN{OFS="\t"}{if($3>=1.30103){print $1;}}' | \
#                             sort -u > all_enriched_GO_terms.txt # 711 => too much => only showed
#                     }
#                     # all_enriched_GO_terms
#
#                     showed_enriched_GO_terms(){
#                         # # D: May-17-2022 10:27 Tue
#                         # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific
#                         # do
#                         #     for category in BP MF CC
#                         #     do
#                         #         sort -u ${group}.${category}_ALL.plot.txt | \
#                         #             awk -F '[~\t]' 'BEGIN{OFS="\t"}{if($3>=1.30103){print $1;}}' | \
#                         #             sort -t$'\t' -k3,3nr | head -10 | cut -f 1 >> showed_enriched_GO_terms.txt
#                         #     done # for category end
#                         # done # for group end
#                         #
#                         # # DCSpecific
#                         # for category in BP MF CC
#                         # do
#                         #     sort -u DCSpecific_rand1.${category}_ALL.plot.txt | \
#                         #         awk -F '[~\t]' 'BEGIN{OFS="\t"}{if($3>=1.30103){print $1;}}' | \
#                         #         sort -t$'\t' -k3,3nr | head -10 | cut -f 1 >> showed_enriched_GO_terms.txt
#                         # done # for category end
#                         #
#                         # sort -u showed_enriched_GO_terms.txt > showed_enriched_GO_terms.txt.tmp && mv showed_enriched_GO_terms.txt.tmp showed_enriched_GO_terms.txt # 103
#
#                         # # GO term enrichment
#                         # echo -e "xValue\tyValue\tgroup\tcol\tlabel" > showed_enriched_GO_terms_used.ggplot_sina.txt
#                         # for GOTerm in $(cat showed_enriched_GO_terms_used.txt)
#                         # do
#                         #     cut -f 2 ${GOTerm}.txt | sort -u > ${GOTerm}.genes.txt
#                         #     python ${pyPATH}/ExtractSubset.py ExtractSubset ${GOTerm}.genes.txt ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed 4 ${GOTerm}.genes.bed
#                         #     cut -f 1-3 ${GOTerm}.genes.bed | sort -u | sort -k1,1 -k2,2n | mergeBed -i - > ${GOTerm}.genes.merged.bed
#                         #     bash ${shPATH}/regionEnrichment_userDefined.sh \
#                         #        "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb" \
#                         #        "mm10_euch" \
#                         #        "${anPATH}/mm10/mm10.chrom.sizes" \
#                         #        "${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/${GOTerm}.genes.merged.bed" \
#                         #        "${anPATH}/mm10/RegionEnrichment/mm10_euch.promoter.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.geneBody.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intergenic.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.exon.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.intron.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.CGI_Unmasked.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.SINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LINE.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.LTR.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.PAD.merged.bed;${anPATH}/mm10/RegionEnrichment/mm10_euch.potentialEnhancer.merged.bed;" \
#                         #        "${GOTerm}.genes"
#                         #
#                         #     # Prepare for Sina plot
#                         #
#                         #     tail -n +2 ${GOTerm}.genes.EnrichScore.txt | \
#                         #         awk 'BEGIN{FS=OFS="\t"}{if($2!="-inf"){print $1, $2, "All", "All", "All";}}' >> showed_enriched_GO_terms_used.ggplot_sina.txt
#                         # done # for GOTerm end
#
#                         Sina_plot(){
#                             Rscript ${rPATH}/ggplot_sina_colorfull.r \
#                                 "showed_enriched_GO_terms_used.ggplot_sina.txt" \
#                                 "showed_enriched_GO_terms_used.ggplot_sina.pdf" \
#                                 "Enrichment score" \
#                                 "-8;8;2" \
#                                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR" \
#                                 "All" \
#                                 "All" \
#                                 "Black" \
#                                 "0.2" \
#                                 "0.75" \
#                                 "1;3" \
#                                 "5" \
#                                 "5"
#                         }
#                         # Sina_plot
#
#                         violin_plot(){
#                             # D: May-17-2022 12:04 Tue
#                             echo -e "xValue\tyValue\tgroup" > showed_enriched_GO_terms_used.ggplot_violin.txt
#                             for GOTerm in $(cat showed_enriched_GO_terms_used.txt)
#                             do
#                                 tail -n +2 ${GOTerm}.genes.EnrichScore.txt | \
#                                     awk 'BEGIN{FS=OFS="\t"}{if($2!="-inf"){print $1, $2, "All";}}' >> showed_enriched_GO_terms_used.ggplot_violin.txt
#                             done # for GOTerm
#
#                             Rscript ${rPATH}/ggplot_violin.r \
#                                 "showed_enriched_GO_terms_used.ggplot_violin.txt" \
#                                 "showed_enriched_GO_terms_used.ggplot_violin.pdf" \
#                                 "" \
#                                 "" \
#                                 "Enrichment score" \
#                                 "-3" \
#                                 "3" \
#                                 "1" \
#                                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR" \
#                                 "All" \
#                                 "5" \
#                                 "5"
#                         }
#                         # violin_plot
#
#                         jitter_plot(){
#                             # D: May-17-2022 12:11 Tue
#                             Rscript ${rPATH}/ggplot_jitter.r \
#                                 "showed_enriched_GO_terms_used.ggplot_violin.txt" \
#                                 "showed_enriched_GO_terms_used.ggplot_jitter.pdf" \
#                                 "" \
#                                 "" \
#                                 "Enrichment score" \
#                                 "-2" \
#                                 "3" \
#                                 "1" \
#                                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR" \
#                                 "All" \
#                                 "6" \
#                                 "4" \
#                                 "1"
#                         }
#                         jitter_plot
#
#                         boxplot_plot(){
#                             # D: May-17-2022 13:26 Tue
#                             Rscript ${rPATH}/ggplot_boxplot.r \
#                                 "showed_enriched_GO_terms_used.ggplot_violin.txt" \
#                                 "showed_enriched_GO_terms_used.ggplot_boxplot.pdf" \
#                                 "" \
#                                 "" \
#                                 "Enrichment score" \
#                                 "-2" \
#                                 "3" \
#                                 "1" \
#                                 "promoter;geneBody;intergenic;exon;intron;CGI_Unmasked;SINE;LINE;LTR" \
#                                 "All" \
#                                 "6" \
#                                 "4" \
#                                 "1"
#                         }
#                         # boxplot_plot
#                     }
#                     # showed_enriched_GO_terms
#                 }
#                 # enriched_GO_Term_genome_enrichment
#             }
#             # DAVID_2021
#
#             expr(){
#                 # D: May-31-2022 14:41 Tue
#                 mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/Expression;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/TargetGenes/Within_2kb/Expression
#                 prepare_expr(){
#                     echo -e "xValue\tyValue\tgroup" > targetGenes.expr.ggplot_basic.txt
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         windowBed -w 2000 -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${anPATH}/mm10/mm10.refGene.withGeneSymbol.bed | \
#                             cut -f 7 | sort -u > ${group}.targetGenes_RefSeq.txt #
#
#                         # Early embryos
#                         for stage in 2-cell 8-cell Morula ICM
#                         do
#                             for rep in 1 2 3 4 5 6
#                             do
#                                 if [ -d ${dataPATH_expr_earlyEmbryo}/${stage}_${rep} ]
#                                 then
#                                     python ${pyPATH}/ExtractSubset.py ExtractSubset ${group}.targetGenes_RefSeq.txt ${dataPATH_expr_earlyEmbryo}/${stage}_${rep}/t_data.ctab 5 ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt
#                                     awk -v XVALUE=${stage} -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, log($12+1)/log(2), GROUP;}' ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt >> targetGenes.expr.ggplot_basic.txt
#                                 fi
#                             done # for rep end
#                         done # for stage end
#
#                         # PGC development
#                         for stage in E10.5 E13.5_female E13.5_male
#                         do
#                             for rep in 1 2 3 4
#                             do
#                                 if [ -d ${dirPATH}/PGCsDevelopment/${stage}.RNASeq.rep${rep} ]
#                                 then
#                                     python ${pyPATH}/ExtractSubset.py ExtractSubset ${group}.targetGenes_RefSeq.txt ${dirPATH}/PGCsDevelopment/${stage}.RNASeq.rep${rep}/${stage}.RNASeq.rep${rep}.t_data.ctab 5 ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt
#                                     awk -v XVALUE=${stage} -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, log($12+1)/log(2), GROUP;}' ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt >> targetGenes.expr.ggplot_basic.txt
#                                 fi
#                             done # for rep end
#                         done # for stage end
#
#                         # Spermatogenesis
#                         for stage in GS PS RS
#                         do
#                             for rep in 1 2
#                             do
#                                 if [ -d ${dirPATH}/Spermatogenesis_GSE137744/${stage}.RNASeq.rep${rep} ]
#                                 then
#                                     python ${pyPATH}/ExtractSubset.py ExtractSubset ${group}.targetGenes_RefSeq.txt ${dirPATH}/Spermatogenesis_GSE137744/${stage}.RNASeq.rep${rep}/${stage}.RNASeq.rep${rep}.t_data.ctab 5 ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt
#                                     awk -v XVALUE=${stage} -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, log($12+1)/log(2), GROUP;}' ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt >> targetGenes.expr.ggplot_basic.txt
#                                 fi
#                             done # for rep end
#                         done # for stage end
#
#                         # Retinal development
#                         for stage in E14.5 E17.5 P0 P3 P7 P10 P14 P21
#                         do
#                             for rep in 1 2
#                             do
#                                 if [ -d ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/${stage}.RNASeq.rep${rep} ]
#                                 then
#                                     python ${pyPATH}/ExtractSubset.py ExtractSubset ${group}.targetGenes_RefSeq.txt ${dirPATH}/RetinalDevelopment/GSE87064_Mouse/${stage}.RNASeq.rep${rep}/${stage}.RNASeq.rep${rep}.t_data.ctab 5 ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt
#                                     awk -v XVALUE=${stage} -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, log($12+1)/log(2), GROUP;}' ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt >> targetGenes.expr.ggplot_basic.txt
#                                 fi
#                             done # for rep end
#                         done # for stage end
#
#                         # DC differentiation
#                         for stage in MPP CDP cDC pDC
#                         do
#                             for rep in 1
#                             do
#                                 if [ -d ${dirPATH}/DendriticCellDevelopment/${stage}.RNASeq.rep${rep} ]
#                                 then
#                                     python ${pyPATH}/ExtractSubset.py ExtractSubset ${group}.targetGenes_RefSeq.txt ${dirPATH}/DendriticCellDevelopment/${stage}.RNASeq.rep${rep}/${stage}.RNASeq.rep${rep}.t_data.ctab 5 ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt
#                                     awk -v XVALUE=${stage} -v GROUP=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, log($12+1)/log(2), GROUP;}' ${group}.targetGenes_RefSeq.expr_${stage}.${rep}.txt >> targetGenes.expr.ggplot_basic.txt
#                                 fi
#                             done # for rep end
#                         done # for stage end
#                     done # for group end
#                 }
#                 # prepare_expr
#
#                 ggplot_boxplot(){
#                     # D: May-31-2022 15:41 Tue
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         Rscript ${rPATH}/ggplot_boxplot.r \
#                             targetGenes.expr.ggplot_basic.txt \
#                             targetGenes_${group}.expr.ggplot_boxplot.pdf \
#                             ${group} \
#                             "" \
#                             "log2(FPKM+1)" \
#                             "0" \
#                             "6" \
#                             "2" \
#                             "2-cell;8-cell;Morula;ICM;E10.5;E13.5_female;E13.5_male;GS;PS;RS;E14.5;E17.5;P0;P3;P7;P10;P14;P21;MPP;CDP;cDC;pDC" \
#                             ${group} \
#                             "6" \
#                             "4" \
#                             "2"
#                     done # for group end
#                 }
#                 ggplot_boxplot
#             }
#             expr
#         }
#         genesWithin2kb
#     }
#     # targetGenes
#
#     motifFinding(){
#         # D: Apr-19-2022 00:23 Tue
#         # Run in py2 environment
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/MotifFinding;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/MotifFinding
#         MDSeqPosF(){
#             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             do
#                 MDSeqPos.py -d -m cistrome.xml -O MDSeqPos_cistrome_${group} ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed mm10 && \
#                 MDSeqPos.py -d -m transfac.xml -O MDSeqPos_transfac_${group} ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed mm10 &
#             done # for group end
#         }
#         # MDSeqPosF
#
#         Manage_cistrome(){
#             # D: Apr-20-2022 22:02 Wed
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/MotifFinding/Manage_cistrome;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/MotifFinding/Manage_cistrome
#             format(){
#                 # T: executed in 207ms, finished 22:13:09 2022-04-20
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                     awk 'BEGIN{FS=OFS="\t"}{if(NF==10){print $2, $3, $4, $5, $6, $7, $8, $9, $10} else{print $0;}}' ${group}.txt > ${group}.formated.txt #
#                 done # for group end
#             }
#             # format
#
#             DNABindingDomain(){
#                 # D: Apr-20-2022 22:14 Wed
#                 prepare(){
#                     # T: executed in 134ms, finished 22:24:12 2022-04-20
#                     echo -e "xValue\tyValue\tgroup" > DNABindingDomain.ggplot_basic.txt
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         tail -n +2 ${group}.formated.txt | cut -f 3 | sort | \
#                             uniq -c | sed -e 's/^ *//;s/ /\t/' | \
#                             awk -v XVALUE=${group} 'BEGIN{FS=OFS="\t"}{print XVALUE, $1, $2;}' >> DNABindingDomain.ggplot_basic.txt
#                     done # for group end
#                 }
#                 # prepare
#
#                 barplot(){
#                     Rscript ${rPATH}/ggplot_barplot_percentage.r \
#                         "DNABindingDomain.ggplot_basic.txt" \
#                         "DNABindingDomain" \
#                         "" \
#                         "Percentage" \
#                         "Arid Domain Family;AT-hook Domain Family;BED-type-zinc finger Family;BetaBetaAlpha-zinc finger Family;BetaBetaAlpha-zinc finger Family,AT-hook Domain Family;BetaBetaAlpha-zinc finger Family (zf-C2H2);CENP-B box binding Family;CP2 Transcription Factor Domain Family;DMRT Domain Family;DNA binding homeobox and Different Transcription Factors (DDT) Domain Family;DNA-binding LAG-1-like Domain Family;Ets Domain Family;Forkhead Domain Family;GATA Domain Family;Glial Cells Missing (GCM) Domain Family;Grainyhead;GTF2I Domain Family;Helix-Loop-Helix Family;High Mobility Group (Box) Family;Homeobox and leucine zippe Family;Homeodomain Family;Hormone-nuclear Receptor Family;Interferon Regulatory Factor;Leucine zipper Family;Leucine Zipper Family;Loop-Sheet-Helix Family;MADS Box Family;MH1 Domain Family;Myb Domain Family;NF-Y CCAAT-Binding Protein Family;None;Nuclear Factor I-CCAAT-binding Transcription Factor (NFI-CTF) Family;PROX;Rel Homology Region Family;RFX Domain Family;Ring finger domain family;Runt Domain Family;Sand Domain Family;Stat Protein Family;TATA box-binding Family;Transcription Factor Family;Transcription Factor T-Domain" \
#                         "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                         "F" \
#                         "16" \
#                         "8" \
#                         0 \
#                         100 \
#                         20
#                 }
#                 # barplot
#
#                 pieplot(){
#                     # D: Apr-21-2022 15:18 Thu
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         # echo -e "value\tgroup" > DNABindingDomain_${group}.ggplot_twoColumns.txt
#                         # tail -n +2 ${group}.formated.txt | awk 'BEGIN{FS=OFS="\t"}{print $3;}' | \
#                         #     awk 'BEGIN{FS="\t"}{print "\""$1"\""}' | sort | uniq -c | \
#                         #     sed -e 's/^ *//;s/ /\t/' | sort -k1,1n >> DNABindingDomain_${group}.ggplot_twoColumns.txt
#
#                         Rscript ${rPATH}/ggplot_pie_sortByPercent.r \
#                             DNABindingDomain_${group}.ggplot_twoColumns.txt \
#                             DNABindingDomain_${group} \
#                             T \
#                             12 \
#                             12
#                     done # for group end
#                 }
#                 # pieplot
#             }
#             # DNABindingDomain
#
#             enrichedFactors(){
#                 # D: Apr-21-2022 14:03 Thu
#                 prepare(){
#                     # T: executed in 108ms, finished 14:41:20 2022-04-21
#                     cat *.formated.txt | grep -v "collapsed_id" | awk 'BEGIN{FS=OFS="\t"}{print $2}' | \
#                         sed -e 's/::/\n/g;s/\b\([[:alpha:][:alnum:]]\)\([[:alpha:][:alnum:]]*\)\b/\u\1\L\2/g' | sort -u > enriched.factors.txt # 484
#                 }
#                 # prepare
#
#                 existence(){
#                     # # D: Apr-21-2022 14:46 Thu
#                     # for factor in $(cut -f 1 enriched.factors.txt)
#                     # do
#                     #     echo -e "${factor}" >> enriched.factors.ordered.txt
#                     #     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     #     do
#                     #         grep -wi "${factor}" ${group}.formated.txt | awk 'END{if(NR>0){print 1;} else{print 0;}}' >> enriched.factors.existence_${group}.txt
#                     #     done # for group end
#                     # done # for factor end
#
#                     # T: executed in 76ms, finished 16:43:16 2022-04-21
#                     paste enriched.factors.ordered.txt enriched.factors.existence_Universal.txt enriched.factors.existence_EarlyEmbryoSpecific.txt enriched.factors.existence_PGCSpecific.txt enriched.factors.existence_SpermSpecific.txt enriched.factors.existence_RetinalSpecific.txt enriched.factors.existence_DCSpecific.txt > enriched.factors.existence.txt
#                 }
#                 # existence
#
#                 overlap(){
#                     # T: executed in 129ms, finished 16:25:19 2022-04-21
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         cat ${group}.formated.txt | grep -v "collapsed_id" | awk 'BEGIN{FS=OFS="\t"}{print $2}' | \
#                             sed -e 's/::/\n/g;s/\b\([[:alpha:][:alnum:]]\)\([[:alpha:][:alnum:]]*\)\b/\u\1\L\2/g' | sort -u > enriched_${group}.factors.txt #
#                     done # for group end
#
#                     Rscript UpSetR.r
#                 }
#                 # overlap
#
#                 existence_zs_n_15(){
#                     # D: Apr-21-2022 16:50 Thu
#                     # T: executed in 119ms, finished 16:53:16 2022-04-21
#                     # cat *.formated.txt | grep -v "collapsed_id" | awk 'BEGIN{FS=OFS="\t"}{if($6<-15){print $2}}' | \
#                     #     sed -e 's/::/\n/g;s/\b\([[:alpha:][:alnum:]]\)\([[:alpha:][:alnum:]]*\)\b/\u\1\L\2/g' | sort -u > enriched.factors_zs_n_15.txt # 82
#
#                     # for factor in $(cut -f 1 enriched.factors_zs_n_15.txt)
#                     # do
#                     #     echo -e "${factor}" >> enriched.factors_zs_n_15.ordered.txt
#                     #     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     #     do
#                     #         grep -wi "${factor}" ${group}.formated.txt | awk 'END{if(NR>0){print 1;} else{print 0;}}' >> enriched.factors_zs_n_15.existence_${group}.txt
#                     #     done # for group end
#                     # done # for factor end
#
#                     # paste enriched.factors_zs_n_15.ordered.txt enriched.factors_zs_n_15.existence_Universal.txt enriched.factors_zs_n_15.existence_EarlyEmbryoSpecific.txt enriched.factors_zs_n_15.existence_PGCSpecific.txt enriched.factors_zs_n_15.existence_SpermSpecific.txt enriched.factors_zs_n_15.existence_RetinalSpecific.txt enriched.factors_zs_n_15.existence_DCSpecific.txt > enriched.factors_zs_n_15.existence.txt
#
#                     # Rscript UpSetR_zs_n_15.r
#
#                     group(){
#                         # D: Apr-21-2022 16:59 Thu
#                         # T: executed in 122ms, finished 17:02:36 2022-04-21
#                         awk 'BEGIN{FS=OFS="\t"}{if($2==0 && $3==1 && $4==1 && $5==1 && $6==1 && $7==1){print $1;}}' enriched.factors_zs_n_15.existence.txt > enriched.factors_zs_n_15.processSpecificCommon.txt # 25
#                         awk 'BEGIN{FS=OFS="\t"}{if($2==1 && $3==1 && $4==1 && $5==1 && $6==1 && $7==1){print $1;}}' enriched.factors_zs_n_15.existence.txt > enriched.factors_zs_n_15.All.txt # 15
#                         awk 'BEGIN{FS=OFS="\t"}{if($2==1 && $3==0 && $4==0 && $5==0 && $6==0 && $7==0){print $1;}}' enriched.factors_zs_n_15.existence.txt > enriched.factors_zs_n_15.UniversalSpecific.txt # 11
#                     }
#                     # group
#
#                     pieplot(){
#                         for group in processSpecificCommon All UniversalSpecific
#                         do
#                             # echo -e "value\tgroup" > DNABindingDomain_${group}.ggplot_twoColumns.txt
#                             # awk 'BEGIN{FS=OFS="\t"}{print $2}' enriched.factors_zs_n_15.${group}.txt | \
#                             #     awk 'BEGIN{FS="\t"}{print "\""$1"\""}' | sort | uniq -c | \
#                             #     sed -e 's/^ *//;s/ /\t/' | sort -k1,1n >> DNABindingDomain_${group}.ggplot_twoColumns.txt
#
#                             Rscript ${rPATH}/ggplot_pie_sortByPercent.r \
#                                 DNABindingDomain_${group}.ggplot_twoColumns.txt \
#                                 DNABindingDomain_${group} \
#                                 T \
#                                 7.5 \
#                                 7.5
#                         done # for group end
#                     }
#                     pieplot
#                 }
#                 existence_zs_n_15
#             }
#             enrichedFactors
#         }
#         Manage_cistrome
#     }
#     # motifFinding
#
#     functions(){
#         # D: Oct-30-2022 20:28 Sun
#         # F: Potential function exploration
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions
#         DSB(){
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB
#             END_seq(){
#                 Testis(){
#                     # D: Oct-30-2022 20:34 Sun
#                     # I: Mahgoub_Elife_2020_GSE139289:https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE139289
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis
#                     download(){
#                         # D: Oct-30-2022 20:35 Sun
#                         # T: executed in 1m 40.8s, finished 20:43:24 2022-10-30
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4136nnn/GSM4136235/suppl/GSM4136235_WT_END_seq_Juvenile.bed.gz" -O Testis_Juvenile.peaks.bed.gz
#                         gunzip Testis_Juvenile.peaks.bed.gz
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4136nnn/GSM4136235/suppl/GSM4136235_WT_END_seq_Juvenile.bigwig" -O Testis_Juvenile.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4136nnn/GSM4136237/suppl/GSM4136237_WT_END_seq_Adult.bed.gz" -O Testis_Adult.peaks.bed.gz
#                         gunzip Testis_Adult.peaks.bed.gz
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4136nnn/GSM4136237/suppl/GSM4136237_WT_END_seq_Adult.bigwig" -O Testis_Adult.bw
#
#                         # D: Oct-30-2022 21:07 Sun
#                         # T: executed in 235ms, finished 21:10:43 2022-10-30
#                         sort -k1,1 -k2,2n Testis_Juvenile.peaks.bed > Testis_Juvenile.peaks.bed.tmp && mv Testis_Juvenile.peaks.bed.tmp Testis_Juvenile.peaks.bed
#                         sort -k1,1 -k2,2n Testis_Adult.peaks.bed > Testis_Adult.peaks.bed.tmp && mv Testis_Adult.peaks.bed.tmp Testis_Adult.peaks.bed
#                     }
#                     # download
#
#                     peakOverlap(){
#                         # D: Oct-30-2022 20:46 Sun
#                         # R: Few overlap
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/PeakOverlap;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/PeakOverlap
#                         echo -e "xValue\ttotal\toverlaped\tyValue\tgroup" > peakOverlap.ggplot_barplot.txt
#                         for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                         do
#                             Total=$(cat ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed | wc -l)
#                             for sample in Juvenile Adult
#                             do
#                                 Overlaped=$(intersectBed -u -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ../Testis_${sample}.peaks.bed | wc -l)
#                                 echo -e "${group}\t${Total}\t${Overlaped}\t${sample}" | awk 'BEGIN{FS=OFS="\t"}{print $1, $2, $3, $3/$2,$4;}' >> peakOverlap.ggplot_barplot.txt
#                             done # for sample end
#                         done # for group end
#                     }
#                     # peakOverlap
#
#                     peakWithin2kb(){
#                         # D: Oct-30-2022 21:02 Sun
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/PeakWithin2kb;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/PeakWithin2kb
#                         echo -e "xValue\ttotal\twithin2kb\tyValue\tgroup" > peakWithin2kb.ggplot_barplot.txt
#                         for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                         do
#                             Total=$(cat ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed | wc -l)
#                             for sample in Juvenile Adult
#                             do
#                                 Within=$(cut -f 1-3 ../Testis_${sample}.peaks.bed | \
#                                     closestBed -d -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b - | \
#                                     awk 'BEGIN{FS=OFS="\t"}{if($7<=2000){print $1, $2, $3;}}' | \
#                                     sort -u | wc -l)
#                                 echo -e "${group}\t${Total}\t${Within}\t${sample}" | awk 'BEGIN{FS=OFS="\t"}{print $1, $2, $3, $3/$2,$4;}' >> peakWithin2kb.ggplot_barplot.txt
#                             done # for sample end
#                         done # for group end
#                     }
#                     # peakWithin2kb
#
#                     distance(){
#                         # D: Oct-30-2022 21:22 Sun
#                         # F: Distance to END-seq peaks
#
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/Distance;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/Distance
#                         # echo -e "xValue\tyValue\tgroup" > distance.ggplot_basic.txt
#                         # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                         # do
#                         #     for sample in Juvenile Adult
#                         #     do
#                         #         cut -f 1-3 ../Testis_${sample}.peaks.bed | \
#                         #             closestBed -d -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b - | \
#                         #             cut -f 1,2,3,7 | sort -u | \
#                         #             awk -v XVALUE=${group} -v GROUP=${sample} 'BEGIN{FS=OFS="\t"}{print XVALUE, $4, GROUP;}' >> distance.ggplot_basic.txt
#                         #     done # for sample end
#                         # done # for group end
#
#                         boxplot(){
#                             Rscript ${rPATH}/ggplot_boxplot.r \
#                                 distance.ggplot_basic.txt \
#                                 distance.ggplot_boxplot.pdf \
#                                 distance \
#                                 "" \
#                                 "distance of stable CHMs to END-seq peaks" \
#                                 0 \
#                                 2500000 \
#                                 500000 \
#                                 "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                                 "Juvenile;Adult" \
#                                 6 \
#                                 4
#                         }
#                         # boxplot
#                     }
#                     # distance
#
#                     signalsSurrounding(){
#                         # D: Oct-30-2022 22:14 Sun
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/SignalSurrounding;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/SignalSurrounding
#                         for sample in Juvenile Adult
#                         do
#                             # bash ${shPATH}/eachProfileSurroundingPeakCenter.sh \
#                             #     ${dirPATH}/CHMOrganization/Universal_specific/ordered.bed \
#                             #     10000 \
#                             #     100 \
#                             #     ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/Testis_${sample}.bw \
#                             #     ordered.Testis_${sample}
#
#                             Rscript ${rPATH}/heatmap_mat_1.r \
#                                 "ordered.Testis_${sample}" \
#                                 "2.5" \
#                                 "10" \
#                                 "9;1" \
#                                 "0.8" \
#                                 "0" \
#                                 "0.8" \
#                                 "ordered.Testis_${sample}" \
#                                 "F" \
#                                 "$(seq 1 100)" \
#                                 "" \
#                                 "StableCHMs" \
#                                 "13287;13988;14732;15087;15686" \
#                                 "-007" \
#                                 "pdf" \
#                                 "#984EA3" \
#                                 "Reverse"
#
#                             pdftoppm -png -r 720 ordered.Testis_${sample}.pdf ordered.Testis_${sample}
#                         done # for sample end
#                     }
#                     # signalsSurrounding
#
#                     avgSignalSurrounding(){
#                         # D: Oct-30-2022 22:59 Sun
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/AvgSignalSurrounding;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/AvgSignalSurrounding
#                         for sample in Juvenile Adult
#                         do
#                             # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter enhancer nonCHM_CGIs_HMR
#                             for group in LTR LINE SINE
#                             do
#                                 bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                     50000 \
#                                     50000 \
#                                     40 \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Testis/Testis_${sample}.bw \
#                                     ${group} \
#                                     "Testis_${sample}" \
#                                     "-50kb;;50kb" \
#                                     "0;20.5;40" \
#                                     "DSB signal" \
#                                     "0.4" \
#                                     "0.9" \
#                                     "Dark2"
#                             done # for group end
#                         done # for sample end
#                     }
#                     avgSignalSurrounding
#                 }
#                 # Testis
#
#                 ESC(){
#                     # D: Oct-31-2022 00:02 Mon
#                     # T: Same to Tillo_NatComm_2021_ESC_GSE165161
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/ESC;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/ESC
#                     download(){
#                         # T:
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM5027nnn/GSM5027367/suppl/GSM5027367_ESC_DUX_Clone1_ENDseq_pos.mm10.RPKM.bw" -O ESC.rep1.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM5027nnn/GSM5027367/suppl/GSM5027367_ESC_DUX_Clone1_ENDseq_neg.mm10.RPKM.bw" -O ESC.rep1.neg.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM5027nnn/GSM5027369/suppl/GSM5027369_ESC_DUX_Clone2_ENDseq_pos.mm10.RPKM.bw" -O ESC.rep2.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM5027nnn/GSM5027369/suppl/GSM5027369_ESC_DUX_Clone2_ENDseq_neg.mm10.RPKM.bw" -O ESC.rep2.neg.bw
#                     }
#                     # download
#
#                     avgSignalSurrounding(){
#                         # D: Oct-31-2022 00:13 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/ESC/AvgSignalSurrounding;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/ESC/AvgSignalSurrounding
#                         for rep in rep1 rep2
#                         do
#                             for type in pos neg
#                             do
#                                 # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter enhancer nonCHM_CGIs_HMR
#                                 for group in nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         50000 \
#                                         50000 \
#                                         40 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/ESC/ESC.${rep}.${type}.bw \
#                                         ${group}.${type} \
#                                         "ESC.${rep}" \
#                                         "-50kb;;50kb" \
#                                         "0;20.5;40" \
#                                         "DSB signal" \
#                                         "0.05" \
#                                         "0.06" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for type end
#                         done # for rep end
#                     }
#                     avgSignalSurrounding
#                 }
#                 # ESC
#
#                 BCell(){
#                     # D: Oct-31-2022 00:36 Mon
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/BCell;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/BCell
#                     download(){
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4160nnn/GSM4160241/suppl/GSM4160241_190124_WT-BCell-NT.si.pos.bw" -O BCell.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4160nnn/GSM4160241/suppl/GSM4160241_190124_WT-BCell-NT.si.neg.bw" -O BCell.neg.bw
#                     }
#                     # download
#
#                     avgSignalSurrounding(){
#                         # D: Oct-31-2022 00:13 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/BCell/AvgSignalSurrounding;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/BCell/AvgSignalSurrounding
#                             for type in pos neg
#                             do
#                                 # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter enhancer nonCHM_CGIs_HMR
#                                 for group in nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         20000 \
#                                         20000 \
#                                         40 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/BCell/BCell.${type}.bw \
#                                         ${group}.${type} \
#                                         "BCell" \
#                                         "-20kb;;20kb" \
#                                         "0;20.5;40" \
#                                         "DSB signal" \
#                                         "-0.05" \
#                                         "0.015" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for type end
#                     }
#                     # avgSignalSurrounding
#                 }
#                 # BCell
#
#                 Tubbs_Cell_2018_B_T_cell(){
#                     # D: Nov-06-2022 11:50 Sun
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018
#                     download(){
#                         # T: executed in 14m 14s, finished 12:14:20 2022-11-06
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227944/suppl/GSM3227944_END_seq_aB_28h_HU_28h_10mM_rep1.bw" -O aB_28h_HU_28h_10mM_rep1.bw
#                         wget -c "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227945/suppl/GSM3227945_END_seq_aB_28h_HU_28h_10mM_rep2.bw" -O aB_28h_HU_28h_10mM_rep2.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227946/suppl/GSM3227946_END_seq_aB_28h_HU_6h_10mM_rep1.bw" -O aB_28h_HU_6h_10mM_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227947/suppl/GSM3227947_END_seq_aB_28h_NT_rep1.bw" -O aB_28h_NT_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227948/suppl/GSM3227948_END_seq_aB_28h_NT_rep2.bw" -O aB_28h_NT_rep2.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227949/suppl/GSM3227949_END_seq_aB_28h_HU_28h_0.5mM_rep1.bw" -O aB_28h_HU_28h_0.5mM_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227950/suppl/GSM3227950_END_seq_aT_28h_HU_28h_2mM_rep1.bw" -O aT_28h_HU_28h_2mM_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227953/suppl/GSM3227953_END_seq_aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1.bw" -O aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227954/suppl/GSM3227954_END_seq_aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1.bw" -O aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227955/suppl/GSM3227955_END_seq_aB_28h_ATRi_28h_rep1.bw" -O aB_28h_ATRi_28h_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227956/suppl/GSM3227956_END_seq_aB_28h_HU_28h_0.5mM_BL6_eij_rep1.bw" -O aB_28h_HU_28h_0.5mM_BL6_eij_rep1.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3227nnn/GSM3227957/suppl/GSM3227957_END_seq_aB_28h_HU_28h_0.5mM_CAST_eij_rep1.bw" -O aB_28h_HU_28h_0.5mM_CAST_eij_rep1.bw
#                     }
#                     # download
#
#                     avgSignalSurrounding(){
#                         # D: Nov-06-2022 12:01 Sun
#                         # T: executed in 49m 57s, finished 13:07:59 2022-11-06
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding
#                         for sample in aB_28h_HU_28h_10mM_rep1 aB_28h_HU_28h_10mM_rep2 aB_28h_HU_6h_10mM_rep1 aB_28h_NT_rep1 aB_28h_NT_rep2 aB_28h_HU_28h_0.5mM_rep1 aT_28h_HU_28h_2mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1 aB_28h_ATRi_28h_rep1 aB_28h_HU_28h_0.5mM_BL6_eij_rep1 aB_28h_HU_28h_0.5mM_CAST_eij_rep1
#                         do
#                             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter enhancer nonCHM_CGIs_HMR
#                             do
#                                 bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                     50000 \
#                                     50000 \
#                                     40 \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/${sample}.bw \
#                                     ${group} \
#                                     "${sample}" \
#                                     "-50kb;;50kb" \
#                                     "0;20.5;40" \
#                                     "DSB signal" \
#                                     "0.4" \
#                                     "0.9" \
#                                     "Dark2"
#                             done # for group end
#
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "${sample}" \
#                                 "${sample}" \
#                                 4 \
#                                 3.5 \
#                                 "-50kb;;50kb" \
#                                 "0;20.5;40" \
#                                 "DSB signal" \
#                                 "0" \
#                                 "0.5" \
#                                 "${sample}" \
#                                 "Dark2"
#                         done # for sample end
#                     }
#                     # avgSignalSurrounding
#
#                     avgSignalSurrounding_20kb_50(){
#                         # D: Nov-06-2022 14:04 Sun
#                         # T:
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding_20kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding_20kb_50
#                         for sample in aB_28h_HU_28h_10mM_rep1 aB_28h_HU_28h_10mM_rep2 aB_28h_HU_6h_10mM_rep1 aB_28h_NT_rep1 aB_28h_NT_rep2 aB_28h_HU_28h_0.5mM_rep1 aT_28h_HU_28h_2mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1 aB_28h_ATRi_28h_rep1 aB_28h_HU_28h_0.5mM_BL6_eij_rep1 aB_28h_HU_28h_0.5mM_CAST_eij_rep1
#                         do
#                             for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter enhancer nonCHM_CGIs_HMR
#                             do
#                                 bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                     20000 \
#                                     20000 \
#                                     50 \
#                                     ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/${sample}.bw \
#                                     ${group} \
#                                     "${sample}" \
#                                     "-20kb;;20kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "0.02" \
#                                     "0.5" \
#                                     "Dark2"
#                             done # for group end
#
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "${sample}" \
#                                 "${sample}" \
#                                 4 \
#                                 3.5 \
#                                 "-20kb;;20kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0" \
#                                 "0.5" \
#                                 "${sample}" \
#                                 "Dark2"
#                         done # for sample end
#                     }
#                     # avgSignalSurrounding_20kb_50
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-06-2022 19:23 Sun
#                         # T: executed in 5m 23s, finished 19:29:44 2022-11-06
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/AvgSignalSurrounding_10kb_50
#                         # for sample in aB_28h_HU_28h_10mM_rep1 aB_28h_HU_28h_10mM_rep2 aB_28h_HU_6h_10mM_rep1 aB_28h_NT_rep1 aB_28h_NT_rep2 aB_28h_HU_28h_0.5mM_rep1 aT_28h_HU_28h_2mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1 aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1 aB_28h_ATRi_28h_rep1 aB_28h_HU_28h_0.5mM_BL6_eij_rep1 aB_28h_HU_28h_0.5mM_CAST_eij_rep1
#                         # do
#                         #     # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR LTR LINE SINE
#                         #     for group in LTR LINE SINE
#                         #     do
#                         #         bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                         #             ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                         #             10000 \
#                         #             10000 \
#                         #             50 \
#                         #             ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tubbs_Cell_2018/${sample}.bw \
#                         #             ${group} \
#                         #             "${sample}" \
#                         #             "-10kb;;10kb" \
#                         #             "0;25.5;50" \
#                         #             "DSB signal" \
#                         #             "0.02" \
#                         #             "0.5" \
#                         #             "Dark2"
#                         #     done # for group end
#                         # done # for sample end
#
#                         each_plot(){
#                             # D: Nov-06-2022 19:35 Sun
#                             # aB_28h_HU_28h_10mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_28h_10mM_rep1" \
#                                 "aB_28h_HU_28h_10mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.04" \
#                                 "0.12" \
#                                 "aB_28h_HU_28h_10mM_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_HU_28h_10mM_rep2
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_28h_10mM_rep2" \
#                                 "aB_28h_HU_28h_10mM_rep2" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.04" \
#                                 "0.12" \
#                                 "aB_28h_HU_28h_10mM_rep2" \
#                                 "Dark2"
#
#                             # aB_28h_HU_6h_10mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_6h_10mM_rep1" \
#                                 "aB_28h_HU_6h_10mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.027" \
#                                 "0.056" \
#                                 "aB_28h_HU_6h_10mM_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_NT_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_NT_rep1" \
#                                 "aB_28h_NT_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.03" \
#                                 "0.09" \
#                                 "aB_28h_NT_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_NT_rep2
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_NT_rep2" \
#                                 "aB_28h_NT_rep2" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.04" \
#                                 "0.08" \
#                                 "aB_28h_NT_rep2" \
#                                 "Dark2"
#
#                             # aB_28h_HU_28h_0.5mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_28h_0.5mM_rep1" \
#                                 "aB_28h_HU_28h_0.5mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.03" \
#                                 "0.13" \
#                                 "aB_28h_HU_28h_0.5mM_rep1" \
#                                 "Dark2"
#
#                             # aT_28h_HU_28h_2mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aT_28h_HU_28h_2mM_rep1" \
#                                 "aT_28h_HU_28h_2mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.045" \
#                                 "0.065" \
#                                 "aT_28h_HU_28h_2mM_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1" \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.06" \
#                                 "0.16" \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_10mM_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1" \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.05" \
#                                 "0.15" \
#                                 "aB_28h_CDC2i_CDC7i_0.5h_HU_6h_0.5mM_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_ATRi_28h_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_ATRi_28h_rep1" \
#                                 "aB_28h_ATRi_28h_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.038" \
#                                 "0.088" \
#                                 "aB_28h_ATRi_28h_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_HU_28h_0.5mM_BL6_eij_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_28h_0.5mM_BL6_eij_rep1" \
#                                 "aB_28h_HU_28h_0.5mM_BL6_eij_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.09" \
#                                 "0.16" \
#                                 "aB_28h_HU_28h_0.5mM_BL6_eij_rep1" \
#                                 "Dark2"
#
#                             # aB_28h_HU_28h_0.5mM_CAST_eij_rep1
#                             Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                                 "aB_28h_HU_28h_0.5mM_CAST_eij_rep1" \
#                                 "aB_28h_HU_28h_0.5mM_CAST_eij_rep1" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "0.15" \
#                                 "0.25" \
#                                 "aB_28h_HU_28h_0.5mM_CAST_eij_rep1" \
#                                 "Dark2"
#                         }
#                         each_plot
#                     }
#                     # avgSignalSurrounding_10kb_50
#                 }
#                 # Tubbs_Cell_2018_B_T_cell
#
#                 Nacson_unpublished_MEF_GSE147468(){
#                     # D: Nov-06-2022 19:28 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM4431523
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468
#                     download(){
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431520/suppl/GSM4431520_WT_END-seq.pos.bw" -O MEF.WT.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431520/suppl/GSM4431520_WT_END-seq.neg.bw" -O MEF.WT.neg.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431521/suppl/GSM4431521_CC_END-seq.pos.bw" -O MEF.CC.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431521/suppl/GSM4431521_CC_END-seq.neg.bw" -O MEF.CC.neg.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431522/suppl/GSM4431522_Del11_END-seq.pos.bw" -O MEF.Del11.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431522/suppl/GSM4431522_Del11_END-seq.neg.bw" -O MEF.Del11.neg.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431523/suppl/GSM4431523_Del11_CC_END-seq.pos.bw" -O MEF.Del11_CC.pos.bw
#                         wget -c "https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4431nnn/GSM4431523/suppl/GSM4431523_Del11_CC_END-seq.neg.bw" -O MEF.Del11_CC.neg.bw
#                     }
#                     # download
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-06-2022 21:26 Sun
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in WT CC Del11 Del11_CC
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/MEF.${sample}.pos.bw \
#                                         ${group} \
#                                         "MEF.${sample}.pos" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0.02" \
#                                         "0.5" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#
#                         neg_part(){
#                             for sample in WT CC Del11 Del11_CC
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/MEF.${sample}.neg.bw \
#                                         ${group} \
#                                         "MEF.${sample}.neg" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "-0.5" \
#                                         "-0.02" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         neg_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 10:59 Mon
#                         # MEF.WT.pos
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.WT.pos" \
#                             "MEF.WT.pos" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "0.04" \
#                             "0.2" \
#                             "MEF.WT.pos" \
#                             "Dark2"
#
#                         # MEF.CC.pos
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.CC.pos" \
#                             "MEF.CC.pos" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "0.05" \
#                             "0.2" \
#                             "MEF.CC.pos" \
#                             "Dark2"
#
#                         # MEF.Del11.pos
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.Del11.pos" \
#                             "MEF.Del11.pos" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "0.06" \
#                             "0.2" \
#                             "MEF.Del11.pos" \
#                             "Dark2"
#
#                         # MEF.Del11_CC.pos
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.Del11_CC.pos" \
#                             "MEF.Del11_CC.pos" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "0.04" \
#                             "0.2" \
#                             "MEF.Del11_CC.pos" \
#                             "Dark2"
#
#                         # MEF.WT.neg
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.WT.neg" \
#                             "MEF.WT.neg" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "-0.04" \
#                             "-0.2" \
#                             "MEF.WT.neg" \
#                             "Dark2"
#
#                         # MEF.CC.neg
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.CC.neg" \
#                             "MEF.CC.neg" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "-0.05" \
#                             "-0.2" \
#                             "MEF.CC.neg" \
#                             "Dark2"
#
#                         # MEF.Del11.neg
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.Del11.neg" \
#                             "MEF.Del11.neg" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "-0.05" \
#                             "-0.2" \
#                             "MEF.Del11.neg" \
#                             "Dark2"
#
#                         # MEF.Del11_CC.neg
#                         Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                             "MEF.Del11_CC.neg" \
#                             "MEF.Del11_CC.neg" \
#                             4 \
#                             3.5 \
#                             "-10kb;;10kb" \
#                             "0;25.5;50" \
#                             "DSB signal" \
#                             "-0.04" \
#                             "-0.2" \
#                             "MEF.Del11_CC.neg" \
#                             "Dark2"
#                     }
#                     # each_plot
#
#                     each_plot_auto(){
#                         # D: Nov-07-2022 11:22 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Nacson_unpublished_MEF_GSE147468/AvgSignalSurrounding_10kb_50
#                         for sample in WT CC Del11 Del11_CC
#                         do
#                             for type in pos neg
#                             do
#                                 Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                     "MEF.${sample}.${type}" \
#                                     "MEF.${sample}.${type}" \
#                                     4 \
#                                     3.5 \
#                                     "-10kb;;10kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "MEF.${sample}.${type}" \
#                                     "Dark2"
#                             done # for type end
#                         done # for sample end
#                     }
#                     each_plot_auto
#                 }
#                 # Nacson_unpublished_MEF_GSE147468
#
#                 Sciascia_Elife_2020_BCell_GSE140372(){
#                     # D: Nov-06-2022 21:34 Sun
#                     # T: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE140372
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE140372&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 08:58 Mon
#                         # T: executed in 332ms, finished 09:12:27 2022-11-07
#                         # tar -xvf "index.html?acc=GSE140372&format=file" && mv "index.html?acc=GSE140372&format=file" GSE140372_RAW.tar
#                         mv GSM4160241_190124_WT-BCell-NT.si.neg.bw GSM4160241_WT_BCell_NT.neg.bw
#                         mv GSM4160241_190124_WT-BCell-NT.si.pos.bw GSM4160241_WT_BCell_NT.pos.bw
#                         mv GSM4160242_190124_WT-BCell-ETO.si.neg.bw GSM4160242_WT_BCell_ETO.neg.bw
#                         mv GSM4160242_190124_WT-BCell-ETO.si.pos.bw GSM4160242_WT_BCell_ETO.pos.bw
#                         mv GSM4160243_190124_WT-BCell-ETO-WO.si.neg.bw GSM4160243_WT_BCell_ETO_WO.neg.bw
#                         mv GSM4160243_190124_WT-BCell-ETO-WO.si.pos.bw GSM4160243_WT_BCell_ETO_WO.pos.bw
#                         mv GSM4160244_190124_WT-BCell-ETO-WO-2h.si.neg.bw GSM4160244_WT_BCell_ETO_WO_2h.neg.bw
#                         mv GSM4160244_190124_WT-BCell-ETO-WO-2h.si.pos.bw GSM4160244_WT_BCell_ETO_WO_2h.pos.bw
#                         mv GSM4160245_190124_WT-BCell-BTZ.si.neg.bw GSM4160245_WT_BCell_BTZ.neg.bw
#                         mv GSM4160245_190124_WT-BCell-BTZ.si.pos.bw GSM4160245_WT_BCell_BTZ.pos.bw
#                         mv GSM4160246_190124_WT-BCell-BTZ-ETO.si.neg.bw GSM4160246_WT_BCell_BTZ_ETO.neg.bw
#                         mv GSM4160246_190124_WT-BCell-BTZ-ETO.si.pos.bw GSM4160246_WT_BCell_BTZ_ETO.pos.bw
#                         mv GSM4160247_190124_WT-BCell-BTZ-ETO-WO.si.neg.bw GSM4160247_WT_BCell_BTZ_ETO_WO.neg.bw
#                         mv GSM4160247_190124_WT-BCell-BTZ-ETO-WO.si.pos.bw GSM4160247_WT_BCell_BTZ_ETO_WO.pos.bw
#                         mv GSM4160248_190124_WT-BCell-BTZ-ETO-WO-2h.si.neg.bw GSM4160248_WT_BCell_BTZ_ETO_WO_2h.neg.bw
#                         mv GSM4160248_190124_WT-BCell-BTZ-ETO-WO-2h.si.pos.bw GSM4160248_WT_BCell_BTZ_ETO_WO_2h.pos.bw
#                         mv GSM4160249_190810_WT-BCell-ETO-E7.si.neg.bw GSM4160249_WT_BCell_ETO_E7.neg.bw
#                         mv GSM4160249_190810_WT-BCell-ETO-E7.si.pos.bw GSM4160249_WT_BCell_ETO_E7.pos.bw
#                         mv GSM4160250_190810_WT-BCell-ETO-ExoT.si.neg.bw GSM4160250_WT_BCell_ETO_ExoT.neg.bw
#                         mv GSM4160250_190810_WT-BCell-ETO-ExoT.si.pos.bw GSM4160250_WT_BCell_ETO_ExoT.pos.bw
#                         mv GSM4160251_190810_WT-BCell-ETO-WO-0h-E7.si.neg.bw GSM4160251_WT_BCell_ETO_WO_0h_E7.neg.bw
#                         mv GSM4160251_190810_WT-BCell-ETO-WO-0h-E7.si.pos.bw GSM4160251_WT_BCell_ETO_WO_0h_E7.pos.bw
#                         mv GSM4160252_190810_WT-BCell-ETO-WO-0h-ExoT.si.neg.bw GSM4160252_WT_BCell_ETO_WO_0h_ExoT.neg.bw
#                         mv GSM4160252_190810_WT-BCell-ETO-WO-0h-ExoT.si.pos.bw GSM4160252_WT_BCell_ETO_WO_0h_ExoT.pos.bw
#                         mv GSM4160253_190810_WT-BCell-BTZ-ETO-E7.si.neg.bw GSM4160253_WT_BCell_BTZ_ETO_E7.neg.bw
#                         mv GSM4160253_190810_WT-BCell-BTZ-ETO-E7.si.pos.bw GSM4160253_WT_BCell_BTZ_ETO_E7.pos.bw
#                         mv GSM4160254_190810_WT-BCell-BTZ-ETO-ExoT.si.neg.bw GSM4160254_WT_BCell_BTZ_ETO_ExoT.neg.bw
#                         mv GSM4160254_190810_WT-BCell-BTZ-ETO-ExoT.si.pos.bw GSM4160254_WT_BCell_BTZ_ETO_ExoT.pos.bw
#                         mv GSM4160255_190810_WT-BCell-BTZ-ETO-WO-0h-E7.si.neg.bw GSM4160255_WT_BCell_BTZ_ETO_WO_0h_E7.neg.bw
#                         mv GSM4160255_190810_WT-BCell-BTZ-ETO-WO-0h-E7.si.pos.bw GSM4160255_WT_BCell_BTZ_ETO_WO_0h_E7.pos.bw
#                         mv GSM4160256_190810_WT-BCell-BTZ-ETO-WO-0h-ExoT.si.neg.bw GSM4160256_WT_BCell_BTZ_ETO_WO_0h_ExoT.neg.bw
#                         mv GSM4160256_190810_WT-BCell-BTZ-ETO-WO-0h-ExoT.si.pos.bw GSM4160256_WT_BCell_BTZ_ETO_WO_0h_ExoT.pos.bw
#                         mv GSM4160257_190518_WT-BCell-1h-BTZ-ETO.si.neg.bw GSM4160257_WT_BCell_1h_BTZ_ETO.neg.bw
#                         mv GSM4160257_190518_WT-BCell-1h-BTZ-ETO.si.pos.bw GSM4160257_WT_BCell_1h_BTZ_ETO.pos.bw
#                         mv GSM4160258_190518_WT-BCell-1h-BTZ-ETO-WO-2h.si.neg.bw GSM4160258_WT_BCell_1h_BTZ_ETO_WO_2h.neg.bw
#                         mv GSM4160258_190518_WT-BCell-1h-BTZ-ETO-WO-2h.si.pos.bw GSM4160258_WT_BCell_1h_BTZ_ETO_WO_2h.pos.bw
#                         mv GSM4160259_190518_WT-BCell-BTZ-ETO.si.neg.bw GSM4160259_WT_BCell_BTZ_ETO.neg.bw
#                         mv GSM4160259_190518_WT-BCell-BTZ-ETO.si.pos.bw GSM4160259_WT_BCell_BTZ_ETO.pos.bw
#                         mv GSM4160260_190518_WT-BCell-BTZ-ETO-WO-2h.si.neg.bw GSM4160260_WT_BCell_BTZ_ETO_WO_2h.neg.bw
#                         mv GSM4160260_190518_WT-BCell-BTZ-ETO-WO-2h.si.pos.bw GSM4160260_WT_BCell_BTZ_ETO_WO_2h.pos.bw
#                         mv GSM4160261_190518_WT-BCell-ETO-2h-BTZ-WO.si.neg.bw GSM4160261_WT_BCell_ETO_2h_BTZ_WO.neg.bw
#                         mv GSM4160261_190518_WT-BCell-ETO-2h-BTZ-WO.si.pos.bw GSM4160261_WT_BCell_ETO_2h_BTZ_WO.pos.bw
#                         mv GSM4160262_190518_WT-BCell-ETO.si.neg.bw GSM4160262_WT_BCell_ETO.neg.bw
#                         mv GSM4160262_190518_WT-BCell-ETO.si.pos.bw GSM4160262_WT_BCell_ETO.pos.bw
#                         mv GSM4160263_190518_WT-BCell-ETO-WO-2h.si.neg.bw GSM4160263_WT_BCell_ETO_WO_2h.neg.bw
#                         mv GSM4160263_190518_WT-BCell-ETO-WO-2h.si.pos.bw GSM4160263_WT_BCell_ETO_WO_2h.pos.bw
#                         mv GSM4160264_190816_WT-BCell-ETO-E7.si.neg.bw GSM4160264_WT_BCell_ETO_E7.neg.bw
#                         mv GSM4160264_190816_WT-BCell-ETO-E7.si.pos.bw GSM4160264_WT_BCell_ETO_E7.pos.bw
#                         mv GSM4160265_190816_RNF4-BCell-ETO-E7.si.neg.bw GSM4160265_RNF4_BCell_ETO_E7.neg.bw
#                         mv GSM4160265_190816_RNF4-BCell-ETO-E7.si.pos.bw GSM4160265_RNF4_BCell_ETO_E7.pos.bw
#                         mv GSM4160266_190816_WT-BCell-ETO-ExoT.si.neg.bw GSM4160266_WT_BCell_ETO_ExoT.neg.bw
#                         mv GSM4160266_190816_WT-BCell-ETO-ExoT.si.pos.bw GSM4160266_WT_BCell_ETO_ExoT.pos.bw
#                         mv GSM4160267_190816_RNF4-BCell-ETO-ExoT.si.neg.bw GSM4160267_RNF4_BCell_ETO_ExoT.neg.bw
#                         mv GSM4160267_190816_RNF4-BCell-ETO-ExoT.si.pos.bw GSM4160267_RNF4_BCell_ETO_ExoT.pos.bw
#                         mv GSM4207022_190503_WT-BCell-NT.si.neg.bw GSM4207022_WT_BCell_NT.neg.bw
#                         mv GSM4207022_190503_WT-BCell-NT.si.pos.bw GSM4207022_WT_BCell_NT.pos.bw
#                         mv GSM4207023_190503_WT-BCell-ETO.si.neg.bw GSM4207023_WT_BCell_ETO.neg.bw
#                         mv GSM4207023_190503_WT-BCell-ETO.si.pos.bw GSM4207023_WT_BCell_ETO.pos.bw
#                         mv GSM4207024_190503_WT-BCell-ETO-WO.si.neg.bw GSM4207024_WT_BCell_ETO_WO.neg.bw
#                         mv GSM4207024_190503_WT-BCell-ETO-WO.si.pos.bw GSM4207024_WT_BCell_ETO_WO.pos.bw
#                         mv GSM4207025_190503_WT-BCell-ETO-WO-2h.si.neg.bw GSM4207025_WT_BCell_ETO_WO_2h.neg.bw
#                         mv GSM4207025_190503_WT-BCell-ETO-WO-2h.si.pos.bw GSM4207025_WT_BCell_ETO_WO_2h.pos.bw
#                         mv GSM4207026_190503_WT-BCell-BTZ.si.neg.bw GSM4207026_WT_BCell_BTZ.neg.bw
#                         mv GSM4207026_190503_WT-BCell-BTZ.si.pos.bw GSM4207026_WT_BCell_BTZ.pos.bw
#                         mv GSM4207027_190503_WT-BCell-BTZ-ETO.si.neg.bw GSM4207027_WT_BCell_BTZ_ETO.neg.bw
#                         mv GSM4207027_190503_WT-BCell-BTZ-ETO.si.pos.bw GSM4207027_WT_BCell_BTZ_ETO.pos.bw
#                         mv GSM4207028_190503_WT-BCell-BTZ-ETO-WO.si.neg.bw GSM4207028_WT_BCell_BTZ_ETO_WO.neg.bw
#                         mv GSM4207028_190503_WT-BCell-BTZ-ETO-WO.si.pos.bw GSM4207028_WT_BCell_BTZ_ETO_WO.pos.bw
#                         mv GSM4207029_190503_WT-BCell-BTZ-ETO-WO-2h.si.neg.bw GSM4207029_WT_BCell_BTZ_ETO_WO_2h.neg.bw
#                         mv GSM4207029_190503_WT-BCell-BTZ-ETO-WO-2h.si.pos.bw GSM4207029_WT_BCell_BTZ_ETO_WO_2h.pos.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 09:13 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM4160241_WT_BCell_NT GSM4160242_WT_BCell_ETO GSM4160243_WT_BCell_ETO_WO GSM4160244_WT_BCell_ETO_WO_2h GSM4160245_WT_BCell_BTZ GSM4160246_WT_BCell_BTZ_ETO GSM4160247_WT_BCell_BTZ_ETO_WO GSM4160248_WT_BCell_BTZ_ETO_WO_2h GSM4160249_WT_BCell_ETO_E7 GSM4160250_WT_BCell_ETO_ExoT GSM4160251_WT_BCell_ETO_WO_0h_E7 GSM4160252_WT_BCell_ETO_WO_0h_ExoT GSM4160253_WT_BCell_BTZ_ETO_E7 GSM4160254_WT_BCell_BTZ_ETO_ExoT GSM4160255_WT_BCell_BTZ_ETO_WO_0h_E7 GSM4160256_WT_BCell_BTZ_ETO_WO_0h_ExoT GSM4160257_WT_BCell_1h_BTZ_ETO GSM4160258_WT_BCell_1h_BTZ_ETO_WO_2h GSM4160259_WT_BCell_BTZ_ETO GSM4160260_WT_BCell_BTZ_ETO_WO_2h GSM4160261_WT_BCell_ETO_2h_BTZ_WO GSM4160262_WT_BCell_ETO GSM4160263_WT_BCell_ETO_WO_2h GSM4160264_WT_BCell_ETO_E7 GSM4160265_RNF4_BCell_ETO_E7 GSM4160266_WT_BCell_ETO_ExoT GSM4160267_RNF4_BCell_ETO_ExoT GSM4207022_WT_BCell_NT GSM4207023_WT_BCell_ETO GSM4207024_WT_BCell_ETO_WO GSM4207025_WT_BCell_ETO_WO_2h GSM4207026_WT_BCell_BTZ GSM4207027_WT_BCell_BTZ_ETO GSM4207028_WT_BCell_BTZ_ETO_WO GSM4207029_WT_BCell_BTZ_ETO_WO_2h
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/${sample}.pos.bw \
#                                         ${group} \
#                                         "${sample}.pos" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0.02" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#
#                         neg_part(){
#                             for sample in GSM4160241_WT_BCell_NT GSM4160242_WT_BCell_ETO GSM4160243_WT_BCell_ETO_WO GSM4160244_WT_BCell_ETO_WO_2h GSM4160245_WT_BCell_BTZ GSM4160246_WT_BCell_BTZ_ETO GSM4160247_WT_BCell_BTZ_ETO_WO GSM4160248_WT_BCell_BTZ_ETO_WO_2h GSM4160249_WT_BCell_ETO_E7 GSM4160250_WT_BCell_ETO_ExoT GSM4160251_WT_BCell_ETO_WO_0h_E7 GSM4160252_WT_BCell_ETO_WO_0h_ExoT GSM4160253_WT_BCell_BTZ_ETO_E7 GSM4160254_WT_BCell_BTZ_ETO_ExoT GSM4160255_WT_BCell_BTZ_ETO_WO_0h_E7 GSM4160256_WT_BCell_BTZ_ETO_WO_0h_ExoT GSM4160257_WT_BCell_1h_BTZ_ETO GSM4160258_WT_BCell_1h_BTZ_ETO_WO_2h GSM4160259_WT_BCell_BTZ_ETO GSM4160260_WT_BCell_BTZ_ETO_WO_2h GSM4160261_WT_BCell_ETO_2h_BTZ_WO GSM4160262_WT_BCell_ETO GSM4160263_WT_BCell_ETO_WO_2h GSM4160264_WT_BCell_ETO_E7 GSM4160265_RNF4_BCell_ETO_E7 GSM4160266_WT_BCell_ETO_ExoT GSM4160267_RNF4_BCell_ETO_ExoT GSM4207022_WT_BCell_NT GSM4207023_WT_BCell_ETO GSM4207024_WT_BCell_ETO_WO GSM4207025_WT_BCell_ETO_WO_2h GSM4207026_WT_BCell_BTZ GSM4207027_WT_BCell_BTZ_ETO GSM4207028_WT_BCell_BTZ_ETO_WO GSM4207029_WT_BCell_BTZ_ETO_WO_2h
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/${sample}.neg.bw \
#                                         ${group} \
#                                         "${sample}.neg" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "-0.1" \
#                                         "-0.02" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         neg_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:09 Mon
#                         # # GSM4160241_WT_BCell_NT.pos
#                         # Rscript ${rPATH}/line_profileSurroundingPeak.r \
#                         #     "GSM4160241_WT_BCell_NT.pos" \
#                         #     "GSM4160241_WT_BCell_NT.pos" \
#                         #     4 \
#                         #     3.5 \
#                         #     "-10kb;;10kb" \
#                         #     "0;25.5;50" \
#                         #     "DSB signal" \
#                         #     "0.0009" \
#                         #     "0.0038" \
#                         #     "GSM4160241_WT_BCell_NT.pos" \
#                         #     "Dark2"
#
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Sciascia_Elife_2020_BCell_GSE140372/AvgSignalSurrounding_10kb_50
#                         for sample in GSM4160241_WT_BCell_NT GSM4160242_WT_BCell_ETO GSM4160243_WT_BCell_ETO_WO GSM4160244_WT_BCell_ETO_WO_2h GSM4160245_WT_BCell_BTZ GSM4160246_WT_BCell_BTZ_ETO GSM4160247_WT_BCell_BTZ_ETO_WO GSM4160248_WT_BCell_BTZ_ETO_WO_2h GSM4160249_WT_BCell_ETO_E7 GSM4160250_WT_BCell_ETO_ExoT GSM4160251_WT_BCell_ETO_WO_0h_E7 GSM4160252_WT_BCell_ETO_WO_0h_ExoT GSM4160253_WT_BCell_BTZ_ETO_E7 GSM4160254_WT_BCell_BTZ_ETO_ExoT GSM4160255_WT_BCell_BTZ_ETO_WO_0h_E7 GSM4160256_WT_BCell_BTZ_ETO_WO_0h_ExoT GSM4160257_WT_BCell_1h_BTZ_ETO GSM4160258_WT_BCell_1h_BTZ_ETO_WO_2h GSM4160259_WT_BCell_BTZ_ETO GSM4160260_WT_BCell_BTZ_ETO_WO_2h GSM4160261_WT_BCell_ETO_2h_BTZ_WO GSM4160262_WT_BCell_ETO GSM4160263_WT_BCell_ETO_WO_2h GSM4160264_WT_BCell_ETO_E7 GSM4160265_RNF4_BCell_ETO_E7 GSM4160266_WT_BCell_ETO_ExoT GSM4160267_RNF4_BCell_ETO_ExoT GSM4207022_WT_BCell_NT GSM4207023_WT_BCell_ETO GSM4207024_WT_BCell_ETO_WO GSM4207025_WT_BCell_ETO_WO_2h GSM4207026_WT_BCell_BTZ GSM4207027_WT_BCell_BTZ_ETO GSM4207028_WT_BCell_BTZ_ETO_WO GSM4207029_WT_BCell_BTZ_ETO_WO_2h
#                         do
#                             # for type in pos neg
#                             for type in neg
#                             do
#                                 Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                     "${sample}.${type}" \
#                                     "${sample}.${type}" \
#                                     4 \
#                                     3.5 \
#                                     "-10kb;;10kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "${sample}.${type}" \
#                                     "Dark2"
#                             done # for type end
#                         done # for sample end
#
#                     }
#                     each_plot
#                 }
#                 # Sciascia_Elife_2020_BCell_GSE140372
#
#                 Callen_MolCell_2020_MEF_GSE133806(){
#                     # D: Nov-06-2022 22:15 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE133806
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE133806&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 09:20 Mon
#                         mv GSM3927555_2018-07-06-ENDseq-AsiSI-MEFS-WT_S5_R1_001.neg.bw GSM3927555_AsiSI_MEFS_WT_S5_R1_001.neg.bw
#                         mv GSM3927555_2018-07-06-ENDseq-AsiSI-MEFS-WT_S5_R1_001.pos.bw GSM3927555_AsiSI_MEFS_WT_S5_R1_001.pos.bw
#                         mv GSM3927556_180302-53BP1-MEF-AsisI.neg.bw GSM3927556_53BP1_MEF_AsisI.neg.bw
#                         mv GSM3927556_180302-53BP1-MEF-AsisI.pos.bw GSM3927556_53BP1_MEF_AsisI.pos.bw
#                         mv GSM3927557_180302-S25A-MEF-AsisI.neg.bw GSM3927557_S25A_MEF_AsisI.neg.bw
#                         mv GSM3927557_180302-S25A-MEF-AsisI.pos.bw GSM3927557_S25A_MEF_AsisI.pos.bw
#                         mv GSM3927558_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1ko_S6_R1_001.neg.bw GSM3927558_AsiSI_MEFS_BRCA1ko_S6_R1_001.neg.bw
#                         mv GSM3927558_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1ko_S6_R1_001.pos.bw GSM3927558_AsiSI_MEFS_BRCA1ko_S6_R1_001.pos.bw
#                         mv GSM3927559_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1-53BP1-dko_S7_R1_001.neg.bw GSM3927559_AsiSI_MEFS_BRCA1_53BP1_dko_S7_R1_001.neg.bw
#                         mv GSM3927559_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1-53BP1-dko_S7_R1_001.pos.bw GSM3927559_AsiSI_MEFS_BRCA1_53BP1_dko_S7_R1_001.pos.bw
#                         mv GSM3927560_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1-S25A-dko_S8_R1_001.neg.bw GSM3927560_AsiSI_MEFS_BRCA1_S25A_dko_S8_R1_001.neg.bw
#                         mv GSM3927560_2018-07-06-ENDseq-AsiSI-MEFS-BRCA1-S25A-dko_S8_R1_001.pos.bw GSM3927560_AsiSI_MEFS_BRCA1_S25A_dko_S8_R1_001.pos.bw
#                         mv GSM3927561_181211-14223-Asis1-8hTAM.neg.bw GSM3927561_Asis1_8hTAM.neg.bw
#                         mv GSM3927561_181211-14223-Asis1-8hTAM.pos.bw GSM3927561_Asis1_8hTAM.pos.bw
#                         mv GSM3927562_181211-WTAsis1-8hTAM.neg.bw GSM3927562_WTAsis1_8hTAM.neg.bw
#                         mv GSM3927562_181211-WTAsis1-8hTAM.pos.bw GSM3927562_WTAsis1_8hTAM.pos.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 09:29 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM3927555_AsiSI_MEFS_WT_S5_R1_001 GSM3927556_53BP1_MEF_AsisI GSM3927557_S25A_MEF_AsisI GSM3927558_AsiSI_MEFS_BRCA1ko_S6_R1_001 GSM3927559_AsiSI_MEFS_BRCA1_53BP1_dko_S7_R1_001 GSM3927560_AsiSI_MEFS_BRCA1_S25A_dko_S8_R1_001 GSM3927561_Asis1_8hTAM GSM3927562_WTAsis1_8hTAM
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/${sample}.pos.bw \
#                                         ${group} \
#                                         "${sample}.pos" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#
#                         neg_part(){
#                             for sample in GSM3927555_AsiSI_MEFS_WT_S5_R1_001 GSM3927556_53BP1_MEF_AsisI GSM3927557_S25A_MEF_AsisI GSM3927558_AsiSI_MEFS_BRCA1ko_S6_R1_001 GSM3927559_AsiSI_MEFS_BRCA1_53BP1_dko_S7_R1_001 GSM3927560_AsiSI_MEFS_BRCA1_S25A_dko_S8_R1_001 GSM3927561_Asis1_8hTAM GSM3927562_WTAsis1_8hTAM
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/${sample}.neg.bw \
#                                         ${group} \
#                                         "${sample}.neg" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "-0.1" \
#                                         "0" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         neg_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:41 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Callen_MolCell_2020_MEF_GSE133806/AvgSignalSurrounding_10kb_50
#                         for sample in GSM3927555_AsiSI_MEFS_WT_S5_R1_001 GSM3927556_53BP1_MEF_AsisI GSM3927557_S25A_MEF_AsisI GSM3927558_AsiSI_MEFS_BRCA1ko_S6_R1_001 GSM3927559_AsiSI_MEFS_BRCA1_53BP1_dko_S7_R1_001 GSM3927560_AsiSI_MEFS_BRCA1_S25A_dko_S8_R1_001 GSM3927561_Asis1_8hTAM GSM3927562_WTAsis1_8hTAM
#                         do
#                             for type in pos neg
#                             do
#                                 Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                     "${sample}.${type}" \
#                                     "${sample}.${type}" \
#                                     4 \
#                                     3.5 \
#                                     "-10kb;;10kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "${sample}.${type}" \
#                                     "Dark2"
#                             done # for type end
#                         done # for sample end
#                     }
#                     each_plot
#                 }
#                 # Callen_MolCell_2020_MEF_GSE133806
#
#                 Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524(){
#                     # D: Nov-06-2022 22:18 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE129524
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE129524&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 09:31 Mon
#                         # tar -xvf "index.html?acc=GSE129524&format=file" && mv "index.html?acc=GSE129524&format=file" GSE129524_RAW.tar
#                         mv GSM3714864_END_seq_PB_LIG4_2_5h_TRANSLOCATION.bw GSM3714864_preB_LIG4_2_5h_TRANSLOCATION.bw
#                         mv GSM3714865_END_seq_PB_LIG4_AsiSI_TRANSLOCATION.bw GSM3714865_preB_LIG4_AsiSI_TRANSLOCATION.bw
#                         mv GSM3714866_END_seq_PB_LIG4_2_5h_DRB_TRX.bw GSM3714866_preB_LIG4_2_5h_DRB_TRX.bw
#                         mv GSM3714867_END_seq_ExoT_PB_LIG4_2_5h_DRB_TRX.bw GSM3714867_ExoT_preB_LIG4_2_5h_DRB_TRX.bw
#                         mv GSM3714868_END_seq_PB_LIG4_AsiSI_DRB_TRX.bw GSM3714868_preB_LIG4_AsiSI_DRB_TRX.bw
#                         mv GSM3714869_END_seq_PB_LIG4_2_5h_IFNB_TRX.bw GSM3714869_preB_LIG4_2_5h_IFNB_TRX.bw
#                         mv GSM3714870_END_seq_ExoT_PB_LIG4_2_5h_IFNB_TRX.bw GSM3714870_ExoT_preB_LIG4_2_5h_IFNB_TRX.bw
#                         mv GSM3714871_END_seq_PB_LIG4_0_5h_TIME_COURSE.bw GSM3714871_preB_LIG4_0_5h_TIME_COURSE.bw
#                         mv GSM3714872_END_seq_PB_LIG4_1h_TIME_COURSE.bw GSM3714872_preB_LIG4_1h_TIME_COURSE.bw
#                         mv GSM3714873_END_seq_PB_LIG4_2_5h_TIME_COURSE.bw GSM3714873_preB_LIG4_2_5h_TIME_COURSE.bw
#                         mv GSM3714874_END_seq_PB_LIG4_5h_TIME_COURSE.bw GSM3714874_preB_LIG4_5h_TIME_COURSE.bw
#                         mv GSM3714875_END_seq_PB_LIG4_7_5h_TIME_COURSE.bw GSM3714875_preB_LIG4_7_5h_TIME_COURSE.bw
#                         mv GSM3714876_END_seq_PB_LIG4_12_5h_TIME_COURSE.bw GSM3714876_preB_LIG4_12_5h_TIME_COURSE.bw
#                         mv GSM3714877_END_seq_ExoT_PB_LIG4_0_5h_TIME_COURSE.bw GSM3714877_ExoT_preB_LIG4_0_5h_TIME_COURSE.bw
#                         mv GSM3714878_END_seq_ExoT_PB_LIG4_1h_TIME_COURSE.bw GSM3714878_ExoT_preB_LIG4_1h_TIME_COURSE.bw
#                         mv GSM3714879_END_seq_ExoT_PB_LIG4_2_5h_TIME_COURSE.bw GSM3714879_ExoT_preB_LIG4_2_5h_TIME_COURSE.bw
#                         mv GSM3714880_END_seq_ExoT_PB_LIG4_5h_TIME_COURSE.bw GSM3714880_ExoT_preB_LIG4_5h_TIME_COURSE.bw
#                         mv GSM3714881_END_seq_ExoT_PB_LIG4_7_5h_TIME_COURSE.bw GSM3714881_ExoT_preB_LIG4_7_5h_TIME_COURSE.bw
#                         mv GSM3714882_END_seq_ExoT_PB_LIG4_12_5h_TIME_COURSE.bw GSM3714882_ExoT_preB_LIG4_12_5h_TIME_COURSE.bw
#                         mv GSM3714883_END_seq_PB_LIG4_NT.bw GSM3714883_preB_LIG4_NT.bw
#                         mv GSM3714884_END_seq_ExoT_PB_LIG4_NT.bw GSM3714884_ExoT_preB_LIG4_NT.bw
#                         mv GSM3714885_END_seq_PB_LIG4_2_5h_REVERSIBILITY.bw GSM3714885_preB_LIG4_2_5h_REVERSIBILITY.bw
#                         mv GSM3714886_END_seq_ExoT_PB_LIG4_2_5h_REVERSIBILITY.bw GSM3714886_ExoT_preB_LIG4_2_5h_REVERSIBILITY.bw
#                         mv GSM3714887_END_seq_PB_LIG4_WASH_2_5h_REVERSIBILITY.bw GSM3714887_preB_LIG4_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714888_END_seq_ExoT_PB_LIG4_WASH_2_5h_REVERSIBILITY.bw GSM3714888_ExoT_preB_LIG4_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714889_END_seq_PB_LIG4_TDP2_2_5h_REVERSIBILITY.bw GSM3714889_preB_LIG4_TDP2_2_5h_REVERSIBILITY.bw
#                         mv GSM3714890_END_seq_ExoT_PB_LIG4_TDP2_2_5h_REVERSIBILITY.bw GSM3714890_ExoT_preB_LIG4_TDP2_2_5h_REVERSIBILITY.bw
#                         mv GSM3714891_END_seq_PB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY.bw GSM3714891_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714892_END_seq_ExoT_PB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY.bw GSM3714892_ExoT_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714893_END_seq_PB_LIG4_EPOX_2_5h_REVERSIBILITY.bw GSM3714893_preB_LIG4_EPOX_2_5h_REVERSIBILITY.bw
#                         mv GSM3714894_END_seq_ExoT_PB_LIG4_EPOX_2_5h_REVERSIBILITY.bw GSM3714894_ExoT_preB_LIG4_EPOX_2_5h_REVERSIBILITY.bw
#                         mv GSM3714895_END_seq_PB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY.bw GSM3714895_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714896_END_seq_ExoT_PB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY.bw GSM3714896_ExoT_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY.bw
#                         mv GSM3714897_END_seq_PB_LIG4_WASH_0_5h_REVERSIBILITY.bw GSM3714897_preB_LIG4_WASH_0_5h_REVERSIBILITY.bw
#                         mv GSM3714898_END_seq_ExoT_PB_LIG4_WASH_0_5h_REVERSIBILITY.bw GSM3714898_ExoT_preB_LIG4_WASH_0_5h_REVERSIBILITY.bw
#                         mv GSM3714899_END_seq_MEF_Smc3_PP_0_5h.bw GSM3714899_MEF_Smc3_PP_0_5h.bw
#                         mv GSM3714900_END_seq_MEF_Smc3_FF_0_5h.bw GSM3714900_MEF_Smc3_FF_0_5h.bw
#                         mv GSM3714901_END_seq_MEF_Wapl_FF_0_5h.bw GSM3714901_MEF_Wapl_FF_0_5h.bw
#                         mv GSM3714902_END_seq_MEF_Wapl_FF_CRE_0_5h.bw GSM3714902_MEF_Wapl_FF_CRE_0_5h.bw
#                         mv GSM3714906_END_seq_aB_TOP2Bko_0_5h_rep1_2_pileup.bw GSM3714906_aB_TOP2Bko_0_5h_rep1_2_pileup.bw
#                         mv GSM3714908_END_seq_aB_WT_0_5h_rep1_2_pileup.bw GSM3714908_aB_WT_0_5h_rep1_2_pileup.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 09:41 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM3714864_preB_LIG4_2_5h_TRANSLOCATION GSM3714865_preB_LIG4_AsiSI_TRANSLOCATION GSM3714866_preB_LIG4_2_5h_DRB_TRX GSM3714867_ExoT_preB_LIG4_2_5h_DRB_TRX GSM3714868_preB_LIG4_AsiSI_DRB_TRX GSM3714869_preB_LIG4_2_5h_IFNB_TRX GSM3714870_ExoT_preB_LIG4_2_5h_IFNB_TRX GSM3714871_preB_LIG4_0_5h_TIME_COURSE GSM3714872_preB_LIG4_1h_TIME_COURSE GSM3714873_preB_LIG4_2_5h_TIME_COURSE GSM3714874_preB_LIG4_5h_TIME_COURSE GSM3714875_preB_LIG4_7_5h_TIME_COURSE GSM3714876_preB_LIG4_12_5h_TIME_COURSE GSM3714877_ExoT_preB_LIG4_0_5h_TIME_COURSE GSM3714878_ExoT_preB_LIG4_1h_TIME_COURSE GSM3714879_ExoT_preB_LIG4_2_5h_TIME_COURSE GSM3714880_ExoT_preB_LIG4_5h_TIME_COURSE GSM3714881_ExoT_preB_LIG4_7_5h_TIME_COURSE GSM3714882_ExoT_preB_LIG4_12_5h_TIME_COURSE GSM3714883_preB_LIG4_NT GSM3714884_ExoT_preB_LIG4_NT GSM3714885_preB_LIG4_2_5h_REVERSIBILITY GSM3714886_ExoT_preB_LIG4_2_5h_REVERSIBILITY GSM3714887_preB_LIG4_WASH_2_5h_REVERSIBILITY GSM3714888_ExoT_preB_LIG4_WASH_2_5h_REVERSIBILITY GSM3714889_preB_LIG4_TDP2_2_5h_REVERSIBILITY GSM3714890_ExoT_preB_LIG4_TDP2_2_5h_REVERSIBILITY GSM3714891_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY GSM3714892_ExoT_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY GSM3714893_preB_LIG4_EPOX_2_5h_REVERSIBILITY GSM3714894_ExoT_preB_LIG4_EPOX_2_5h_REVERSIBILITY GSM3714895_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY GSM3714896_ExoT_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY GSM3714897_preB_LIG4_WASH_0_5h_REVERSIBILITY GSM3714898_ExoT_preB_LIG4_WASH_0_5h_REVERSIBILITY GSM3714899_MEF_Smc3_PP_0_5h GSM3714900_MEF_Smc3_FF_0_5h GSM3714901_MEF_Wapl_FF_0_5h GSM3714902_MEF_Wapl_FF_CRE_0_5h GSM3714906_aB_TOP2Bko_0_5h_rep1_2_pileup GSM3714908_aB_WT_0_5h_rep1_2_pileup
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524/${sample}.bw \
#                                         ${group} \
#                                         "${sample}" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:43 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524/AvgSignalSurrounding_10kb_50
#                         for sample in GSM3714864_preB_LIG4_2_5h_TRANSLOCATION GSM3714865_preB_LIG4_AsiSI_TRANSLOCATION GSM3714866_preB_LIG4_2_5h_DRB_TRX GSM3714867_ExoT_preB_LIG4_2_5h_DRB_TRX GSM3714868_preB_LIG4_AsiSI_DRB_TRX GSM3714869_preB_LIG4_2_5h_IFNB_TRX GSM3714870_ExoT_preB_LIG4_2_5h_IFNB_TRX GSM3714871_preB_LIG4_0_5h_TIME_COURSE GSM3714872_preB_LIG4_1h_TIME_COURSE GSM3714873_preB_LIG4_2_5h_TIME_COURSE GSM3714874_preB_LIG4_5h_TIME_COURSE GSM3714875_preB_LIG4_7_5h_TIME_COURSE GSM3714876_preB_LIG4_12_5h_TIME_COURSE GSM3714877_ExoT_preB_LIG4_0_5h_TIME_COURSE GSM3714878_ExoT_preB_LIG4_1h_TIME_COURSE GSM3714879_ExoT_preB_LIG4_2_5h_TIME_COURSE GSM3714880_ExoT_preB_LIG4_5h_TIME_COURSE GSM3714881_ExoT_preB_LIG4_7_5h_TIME_COURSE GSM3714882_ExoT_preB_LIG4_12_5h_TIME_COURSE GSM3714883_preB_LIG4_NT GSM3714884_ExoT_preB_LIG4_NT GSM3714885_preB_LIG4_2_5h_REVERSIBILITY GSM3714886_ExoT_preB_LIG4_2_5h_REVERSIBILITY GSM3714887_preB_LIG4_WASH_2_5h_REVERSIBILITY GSM3714888_ExoT_preB_LIG4_WASH_2_5h_REVERSIBILITY GSM3714889_preB_LIG4_TDP2_2_5h_REVERSIBILITY GSM3714890_ExoT_preB_LIG4_TDP2_2_5h_REVERSIBILITY GSM3714891_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY GSM3714892_ExoT_preB_LIG4_TDP2_WASH_2_5h_REVERSIBILITY GSM3714893_preB_LIG4_EPOX_2_5h_REVERSIBILITY GSM3714894_ExoT_preB_LIG4_EPOX_2_5h_REVERSIBILITY GSM3714895_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY GSM3714896_ExoT_preB_LIG4_EPOX_WASH_2_5h_REVERSIBILITY GSM3714897_preB_LIG4_WASH_0_5h_REVERSIBILITY GSM3714898_ExoT_preB_LIG4_WASH_0_5h_REVERSIBILITY GSM3714899_MEF_Smc3_PP_0_5h GSM3714900_MEF_Smc3_FF_0_5h GSM3714901_MEF_Wapl_FF_0_5h GSM3714902_MEF_Wapl_FF_CRE_0_5h GSM3714906_aB_TOP2Bko_0_5h_rep1_2_pileup GSM3714908_aB_WT_0_5h_rep1_2_pileup
#                         do
#                             Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                 "${sample}" \
#                                 "${sample}" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "DSB signal" \
#                                 "${sample}" \
#                                 "Dark2"
#                         done # for sample end
#                     }
#                     each_plot
#                 }
#                 # Canela_MolCell_2019_B_MEF_preB_T_Neuron_GSE129524
#
#                 Tillo_NatComm_2021_ESC_GSE165161(){
#                     # D: Nov-06-2022 22:21 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE165161
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE165161&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 09:45 Mon
#                         mv GSM5027366_ESC_DUX_Clone1_DOX_16h_ENDseq_neg.mm10.RPKM.bw GSM5027366_ESC_DUX_DOX_16h.neg.bw
#                         mv GSM5027366_ESC_DUX_Clone1_DOX_16h_ENDseq_pos.mm10.RPKM.bw GSM5027366_ESC_DUX_DOX_16h.pos.bw
#                         mv GSM5027367_ESC_DUX_Clone1_ENDseq_neg.mm10.RPKM.bw GSM5027367_ESC_DUX.neg.bw
#                         mv GSM5027367_ESC_DUX_Clone1_ENDseq_pos.mm10.RPKM.bw GSM5027367_ESC_DUX.pos.bw
#                         mv GSM5027368_ESC_DUX_Clone2_DOX_16h_ENDseq_neg.mm10.RPKM.bw GSM5027368_ESC_DUX_DOX_16h.neg.bw
#                         mv GSM5027368_ESC_DUX_Clone2_DOX_16h_ENDseq_pos.mm10.RPKM.bw GSM5027368_ESC_DUX_DOX_16h.pos.bw
#                         mv GSM5027369_ESC_DUX_Clone2_ENDseq_neg.mm10.RPKM.bw GSM5027369_ESC_DUX.neg.bw
#                         mv GSM5027369_ESC_DUX_Clone2_ENDseq_pos.mm10.RPKM.bw GSM5027369_ESC_DUX.pos.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 09:46 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM5027366_ESC_DUX_DOX_16h GSM5027367_ESC_DUX GSM5027368_ESC_DUX_DOX_16h GSM5027369_ESC_DUX
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/${sample}.pos.bw \
#                                         ${group} \
#                                         "${sample}.pos" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#
#                         neg_part(){
#                             for sample in GSM5027366_ESC_DUX_DOX_16h GSM5027367_ESC_DUX GSM5027368_ESC_DUX_DOX_16h GSM5027369_ESC_DUX
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/${sample}.neg.bw \
#                                         ${group} \
#                                         "${sample}.neg" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "-0.1" \
#                                         "0" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         neg_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:45 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Tillo_NatComm_2021_ESC_GSE165161/AvgSignalSurrounding_10kb_50
#                         for sample in GSM5027366_ESC_DUX_DOX_16h GSM5027367_ESC_DUX GSM5027368_ESC_DUX_DOX_16h GSM5027369_ESC_DUX
#                         do
#                             for type in pos neg
#                             do
#                                 Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                     "${sample}.${type}" \
#                                     "${sample}.${type}" \
#                                     4 \
#                                     3.5 \
#                                     "-10kb;;10kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "${sample}.${type}" \
#                                     "Dark2"
#                             done # for type end
#                         done # for sample end
#                     }
#                     each_plot
#                 }
#                 # Tillo_NatComm_2021_ESC_GSE165161
#
#                 Fowler_Elife_2022_preB_GSE186085(){
#                     # D: Nov-06-2022 22:23 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE186085
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE186085&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 09:49 Mon
#                         # tar -xvf "index.html?acc=GSE186085&format=file" && mv "index.html?acc=GSE186085&format=file" GSE186085_RAW.tar
#                         mv GSM5631734_Abl-Lig4-G2-AsisI-DNAPKi-4h-ENDseq_rep1.neg.bw GSM5631734_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep1.neg.bw
#                         mv GSM5631734_Abl-Lig4-G2-AsisI-DNAPKi-4h-ENDseq_rep1.pos.bw GSM5631734_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep1.pos.bw
#                         mv GSM5631735_Abl-Lig4-G2-AsisI-DNAPKi-4h-ENDseq_rep2.neg.bw GSM5631735_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep2.neg.bw
#                         mv GSM5631735_Abl-Lig4-G2-AsisI-DNAPKi-4h-ENDseq_rep2.pos.bw GSM5631735_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep2.pos.bw
#                         mv GSM5631736_Abl-Lig4-G2-AsisI-DNAPKi-8h-ENDseq_rep1.neg.bw GSM5631736_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep1.neg.bw
#                         mv GSM5631736_Abl-Lig4-G2-AsisI-DNAPKi-8h-ENDseq_rep1.pos.bw GSM5631736_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep1.pos.bw
#                         mv GSM5631737_Abl-Lig4-G2-AsisI-DNAPKi-8h-ENDseq_rep2.neg.bw GSM5631737_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep2.neg.bw
#                         mv GSM5631737_Abl-Lig4-G2-AsisI-DNAPKi-8h-ENDseq_rep2.pos.bw GSM5631737_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep2.pos.bw
#                         mv GSM5631738_Abl-Lig4-G2-AsisI-NT-4h-ENDseq_rep1.neg.bw GSM5631738_Abl_Lig4_G2_AsisI_NT_4h_rep1.neg.bw
#                         mv GSM5631738_Abl-Lig4-G2-AsisI-NT-4h-ENDseq_rep1.pos.bw GSM5631738_Abl_Lig4_G2_AsisI_NT_4h_rep1.pos.bw
#                         mv GSM5631739_Abl-Lig4-G2-AsisI-NT-4h-ENDseq_rep2.neg.bw GSM5631739_Abl_Lig4_G2_AsisI_NT_4h_rep2.neg.bw
#                         mv GSM5631739_Abl-Lig4-G2-AsisI-NT-4h-ENDseq_rep2.pos.bw GSM5631739_Abl_Lig4_G2_AsisI_NT_4h_rep2.pos.bw
#                         mv GSM5631740_Abl-Lig4-G2-AsisI-NT-8h-ENDseq_rep1.neg.bw GSM5631740_Abl_Lig4_G2_AsisI_NT_8h_rep1.neg.bw
#                         mv GSM5631740_Abl-Lig4-G2-AsisI-NT-8h-ENDseq_rep1.pos.bw GSM5631740_Abl_Lig4_G2_AsisI_NT_8h_rep1.pos.bw
#                         mv GSM5631741_Abl-Lig4-G2-AsisI-NT-8h-ENDseq_rep2.neg.bw GSM5631741_Abl_Lig4_G2_AsisI_NT_8h_rep2.neg.bw
#                         mv GSM5631741_Abl-Lig4-G2-AsisI-NT-8h-ENDseq_rep2.pos.bw GSM5631741_Abl_Lig4_G2_AsisI_NT_8h_rep2.pos.bw
#                         mv GSM5631742_Abl-Lig4-STI-AsisI-DNAPKi-4h-ENDseq_rep1.neg.bw GSM5631742_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep1.neg.bw
#                         mv GSM5631742_Abl-Lig4-STI-AsisI-DNAPKi-4h-ENDseq_rep1.pos.bw GSM5631742_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep1.pos.bw
#                         mv GSM5631743_Abl-Lig4-STI-AsisI-DNAPKi-4h-ENDseq_rep2.neg.bw GSM5631743_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep2.neg.bw
#                         mv GSM5631743_Abl-Lig4-STI-AsisI-DNAPKi-4h-ENDseq_rep2.pos.bw GSM5631743_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep2.pos.bw
#                         mv GSM5631744_Abl-Lig4-STI-AsisI-DNAPKi-8h-ENDseq_rep1.neg.bw GSM5631744_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep1.neg.bw
#                         mv GSM5631744_Abl-Lig4-STI-AsisI-DNAPKi-8h-ENDseq_rep1.pos.bw GSM5631744_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep1.pos.bw
#                         mv GSM5631745_Abl-Lig4-STI-AsisI-DNAPKi-8h-ENDseq_rep2.neg.bw GSM5631745_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep2.neg.bw
#                         mv GSM5631745_Abl-Lig4-STI-AsisI-DNAPKi-8h-ENDseq_rep2.pos.bw GSM5631745_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep2.pos.bw
#                         mv GSM5631746_Abl-Lig4-STI-AsisI-NT-4h-ENDseq_rep1.neg.bw GSM5631746_Abl_Lig4_STI_AsisI_NT_4h_rep1.neg.bw
#                         mv GSM5631746_Abl-Lig4-STI-AsisI-NT-4h-ENDseq_rep1.pos.bw GSM5631746_Abl_Lig4_STI_AsisI_NT_4h_rep1.pos.bw
#                         mv GSM5631747_Abl-Lig4-STI-AsisI-NT-4h-ENDseq_rep2.neg.bw GSM5631747_Abl_Lig4_STI_AsisI_NT_4h_rep2.neg.bw
#                         mv GSM5631747_Abl-Lig4-STI-AsisI-NT-4h-ENDseq_rep2.pos.bw GSM5631747_Abl_Lig4_STI_AsisI_NT_4h_rep2.pos.bw
#                         mv GSM5631748_Abl-Lig4-STI-AsisI-NT-8h-ENDseq_rep1.neg.bw GSM5631748_Abl_Lig4_STI_AsisI_NT_8h_rep1.neg.bw
#                         mv GSM5631748_Abl-Lig4-STI-AsisI-NT-8h-ENDseq_rep1.pos.bw GSM5631748_Abl_Lig4_STI_AsisI_NT_8h_rep1.pos.bw
#                         mv GSM5631749_Abl-Lig4-STI-AsisI-NT-8h-ENDseq_rep2.neg.bw GSM5631749_Abl_Lig4_STI_AsisI_NT_8h_rep2.neg.bw
#                         mv GSM5631749_Abl-Lig4-STI-AsisI-NT-8h-ENDseq_rep2.pos.bw GSM5631749_Abl_Lig4_STI_AsisI_NT_8h_rep2.pos.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 09:54 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM5631734_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep1 GSM5631735_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep2 GSM5631736_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep1 GSM5631737_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep2 GSM5631738_Abl_Lig4_G2_AsisI_NT_4h_rep1 GSM5631739_Abl_Lig4_G2_AsisI_NT_4h_rep2 GSM5631740_Abl_Lig4_G2_AsisI_NT_8h_rep1 GSM5631741_Abl_Lig4_G2_AsisI_NT_8h_rep2 GSM5631742_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep1 GSM5631743_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep2 GSM5631744_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep1 GSM5631745_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep2 GSM5631746_Abl_Lig4_STI_AsisI_NT_4h_rep1 GSM5631747_Abl_Lig4_STI_AsisI_NT_4h_rep2 GSM5631748_Abl_Lig4_STI_AsisI_NT_8h_rep1 GSM5631749_Abl_Lig4_STI_AsisI_NT_8h_rep2
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/${sample}.pos.bw \
#                                         ${group} \
#                                         "${sample}.pos" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#
#                         neg_part(){
#                             for sample in GSM5631734_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep1 GSM5631735_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep2 GSM5631736_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep1 GSM5631737_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep2 GSM5631738_Abl_Lig4_G2_AsisI_NT_4h_rep1 GSM5631739_Abl_Lig4_G2_AsisI_NT_4h_rep2 GSM5631740_Abl_Lig4_G2_AsisI_NT_8h_rep1 GSM5631741_Abl_Lig4_G2_AsisI_NT_8h_rep2 GSM5631742_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep1 GSM5631743_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep2 GSM5631744_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep1 GSM5631745_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep2 GSM5631746_Abl_Lig4_STI_AsisI_NT_4h_rep1 GSM5631747_Abl_Lig4_STI_AsisI_NT_4h_rep2 GSM5631748_Abl_Lig4_STI_AsisI_NT_8h_rep1 GSM5631749_Abl_Lig4_STI_AsisI_NT_8h_rep2
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/${sample}.neg.bw \
#                                         ${group} \
#                                         "${sample}.neg" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "-0.1" \
#                                         "0" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         neg_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:46 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Fowler_Elife_2022_preB_GSE186085/AvgSignalSurrounding_10kb_50
#                         for sample in GSM5631734_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep1 GSM5631735_Abl_Lig4_G2_AsisI_DNAPKi_4h_rep2 GSM5631736_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep1 GSM5631737_Abl_Lig4_G2_AsisI_DNAPKi_8h_rep2 GSM5631738_Abl_Lig4_G2_AsisI_NT_4h_rep1 GSM5631739_Abl_Lig4_G2_AsisI_NT_4h_rep2 GSM5631740_Abl_Lig4_G2_AsisI_NT_8h_rep1 GSM5631741_Abl_Lig4_G2_AsisI_NT_8h_rep2 GSM5631742_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep1 GSM5631743_Abl_Lig4_STI_AsisI_DNAPKi_4h_rep2 GSM5631744_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep1 GSM5631745_Abl_Lig4_STI_AsisI_DNAPKi_8h_rep2 GSM5631746_Abl_Lig4_STI_AsisI_NT_4h_rep1 GSM5631747_Abl_Lig4_STI_AsisI_NT_4h_rep2 GSM5631748_Abl_Lig4_STI_AsisI_NT_8h_rep1 GSM5631749_Abl_Lig4_STI_AsisI_NT_8h_rep2
#                         do
#                             for type in pos neg
#                             do
#                                 Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                     "${sample}.${type}" \
#                                     "${sample}.${type}" \
#                                     4 \
#                                     3.5 \
#                                     "-10kb;;10kb" \
#                                     "0;25.5;50" \
#                                     "DSB signal" \
#                                     "${sample}.${type}" \
#                                     "Dark2"
#                             done # for type end
#                         done # for sample end
#                     }
#                     each_plot
#                 }
#                 # Fowler_Elife_2022_preB_GSE186085
#
#                 Wu_Nature_2021_Neuron_GSE167257(){
#                     # D: Nov-06-2022 22L28 Sun
#                     # I: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE167257
#                     mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257
#                     download(){
#                         wget -c "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE167257&format=file"
#                     }
#                     # download
#
#                     manage(){
#                         # D: Nov-07-2022 10:11 Mon
#                         tar -xvf "index.html?acc=GSE167257&format=file" && mv "index.html?acc=GSE167257&format=file" GSE167257_RAW.tar
#                         mv GSM5100463_pre-B_WT_AsiSI-Dox_SARseq.bw GSM5100463_preB_WT_AsiSI_Dox_SARseq.bw
#                         mv GSM5100464_pre-B_WT_AsiSI-noDox_SARseq.bw GSM5100464_preB_WT_AsiSI_noDox_SARseq.bw
#                     }
#                     # manage
#
#                     avgSignalSurrounding_10kb_50(){
#                         # D: Nov-07-2022 10:54 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257/AvgSignalSurrounding_10kb_50
#                         pos_part(){
#                             for sample in GSM5100463_preB_WT_AsiSI_Dox_SARseq GSM5100464_preB_WT_AsiSI_noDox_SARseq
#                             do
#                                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific nonCHM_CGIs promoter nonCHM_CGIs_HMR
#                                 do
#                                     bash ${shPATH}/profileSurroundingPeakCenter.sh \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed \
#                                         10000 \
#                                         10000 \
#                                         50 \
#                                         ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257/${sample}.bw \
#                                         ${group} \
#                                         "${sample}" \
#                                         "-10kb;;10kb" \
#                                         "0;25.5;50" \
#                                         "DSB signal" \
#                                         "0" \
#                                         "0.1" \
#                                         "Dark2"
#                                 done # for group end
#                             done # for sample end
#                         }
#                         pos_part
#                     }
#                     # avgSignalSurrounding_10kb_50
#
#                     each_plot(){
#                         # D: Nov-07-2022 11:47 Mon
#                         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257/AvgSignalSurrounding_10kb_50;cd ${dirPATH}/CHMOrganization/Universal_specific/Functions/DSB/Wu_Nature_2021_Neuron_GSE167257/AvgSignalSurrounding_10kb_50
#                         for sample in GSM5100463_preB_WT_AsiSI_Dox_SARseq GSM5100464_preB_WT_AsiSI_noDox_SARseq
#                         do
#                             Rscript ${rPATH}/line_profileSurroundingPeak_auto.r \
#                                 "${sample}" \
#                                 "${sample}" \
#                                 4 \
#                                 3.5 \
#                                 "-10kb;;10kb" \
#                                 "0;25.5;50" \
#                                 "SSB signal" \
#                                 "${sample}" \
#                                 "Dark2"
#                         done # for sample end
#                     }
#                     each_plot
#                 }
#                 Wu_Nature_2021_Neuron_GSE167257
#             }
#             END_seq
#         }
#         DSB
#     }
#     # functions
#
#     genomeDistribution(){
#         # D: Nov-06-2022 14:18 Sun
#         mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution
#         PAD_regulatory(){
#             # D: Nov-06-2022 14:39 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/PAD_regulatory;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/PAD_regulatory
#             # echo -e "Group\tTotal\tPAD\tEnhancer\tPromoter\tnonPAD_enhancer\tnonPAD_promoter\tPAD(%)\tEnhancer(%)\tPromoter(%)\tnonPAD_enhancer(%)\tnonPAD_promoter(%)" > PAD_regulatory.statistics.txt
#             # for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#             # do
#             #     N_TOTAL=$(cat ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed | wc -l)
#             #     N_PAD=$(intersectBed -u -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${dataPATH_pad} | wc -l)
#             #     N_ENHANCER=$(intersectBed -u -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${dataPATH_enhancer} | wc -l)
#             #     N_PROMOTER=$(intersectBed -u -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${dataPATH_promoter} | wc -l)
#             #     N_NON_PAD_ENHANCER=$(intersectBed -v -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${dataPATH_pad} | intersectBed -u -a - -b ${dataPATH_enhancer} | wc -l)
#             #     N_NON_PAD_PROMOTER=$(intersectBed -v -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${dataPATH_pad} | intersectBed -u -a - -b ${dataPATH_promoter} | wc -l)
#             #     echo -e "${group}\t${N_TOTAL}\t${N_PAD}\t${N_ENHANCER}\t${N_PROMOTER}\t${N_NON_PAD_ENHANCER}\t${N_NON_PAD_PROMOTER}" | \
#             #         awk 'BEGIN{FS=OFS="\t"}{print $1, $2, $3, $4, $5, $6, $7, $3/$2, $4/$2, $5/$2, $6/$2, $7/$2;}' >> PAD_regulatory.statistics.txt
#             # done # for group end
#
#             PAD_plot(){
#                 # D: Nov-06-2022 15:02 Sun
#                 echo -e "xValue\tyValue\tgroup" > PAD.ggplot_basic.txt
#                 tail -n +2 PAD_regulatory.statistics.txt | \
#                     awk 'BEGIN{FS=OFS="\t"}{print $1, $8*100, "PAD"}' >> PAD.ggplot_basic.txt
#                 Rscript ${rPATH}/ggplot_barplot.r \
#                     "PAD.ggplot_basic.txt" \
#                     "PAD.ggplot_barplot.pdf" \
#                     "PAD" \
#                     "" \
#                     "Percentage of CHMs located in PAD" \
#                     "0;100;20" \
#                     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                     "PAD" \
#                     "dodge" \
#                     "3" \
#                     "5" \
#                     "-007" \
#                     "F"
#             }
#             # PAD_plot
#
#             Enhancer_plot(){
#                 # D: Nov-06-2022 15:02 Sun
#                 echo -e "xValue\tyValue\tgroup" > Enhancer.ggplot_basic.txt
#                 tail -n +2 PAD_regulatory.statistics.txt | \
#                     awk 'BEGIN{FS=OFS="\t"}{print $1, $9*100, "Enhancer"}' >> Enhancer.ggplot_basic.txt
#                 Rscript ${rPATH}/ggplot_barplot.r \
#                     "Enhancer.ggplot_basic.txt" \
#                     "Enhancer.ggplot_barplot.pdf" \
#                     "Enhancer" \
#                     "" \
#                     "Percentage of CHMs located in Enhancer" \
#                     "0;100;20" \
#                     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                     "Enhancer" \
#                     "dodge" \
#                     "3" \
#                     "5" \
#                     "-007" \
#                     "F"
#             }
#             Enhancer_plot
#
#             Promoter_plot(){
#                 # D: Nov-06-2022 15:02 Sun
#                 echo -e "xValue\tyValue\tgroup" > Promoter.ggplot_basic.txt
#                 tail -n +2 PAD_regulatory.statistics.txt | \
#                     awk 'BEGIN{FS=OFS="\t"}{print $1, $10*100, "Promoter"}' >> Promoter.ggplot_basic.txt
#                 Rscript ${rPATH}/ggplot_barplot.r \
#                     "Promoter.ggplot_basic.txt" \
#                     "Promoter.ggplot_barplot.pdf" \
#                     "Promoter" \
#                     "" \
#                     "Percentage of CHMs located in Promoter" \
#                     "0;100;20" \
#                     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                     "Promoter" \
#                     "dodge" \
#                     "3" \
#                     "5" \
#                     "-007" \
#                     "F"
#             }
#             Promoter_plot
#
#             nonPAD_Enhancer_plot(){
#                 # D: Nov-06-2022 15:02 Sun
#                 echo -e "xValue\tyValue\tgroup" > nonPAD_Enhancer.ggplot_basic.txt
#                 tail -n +2 PAD_regulatory.statistics.txt | \
#                     awk 'BEGIN{FS=OFS="\t"}{print $1, $11*100, "nonPAD_Enhancer"}' >> nonPAD_Enhancer.ggplot_basic.txt
#                 Rscript ${rPATH}/ggplot_barplot.r \
#                     "nonPAD_Enhancer.ggplot_basic.txt" \
#                     "nonPAD_Enhancer.ggplot_barplot.pdf" \
#                     "nonPAD_Enhancer" \
#                     "" \
#                     "Percentage of CHMs located in nonPAD_Enhancer" \
#                     "0;100;20" \
#                     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                     "nonPAD_Enhancer" \
#                     "dodge" \
#                     "3" \
#                     "5" \
#                     "-007" \
#                     "F"
#             }
#             nonPAD_Enhancer_plot
#
#             nonPAD_Promoter_plot(){
#                 # D: Nov-06-2022 15:02 Sun
#                 echo -e "xValue\tyValue\tgroup" > nonPAD_Promoter.ggplot_basic.txt
#                 tail -n +2 PAD_regulatory.statistics.txt | \
#                     awk 'BEGIN{FS=OFS="\t"}{print $1, $12*100, "nonPAD_Promoter"}' >> nonPAD_Promoter.ggplot_basic.txt
#                 Rscript ${rPATH}/ggplot_barplot.r \
#                     "nonPAD_Promoter.ggplot_basic.txt" \
#                     "nonPAD_Promoter.ggplot_barplot.pdf" \
#                     "nonPAD_Promoter" \
#                     "" \
#                     "Percentage of CHMs located in nonPAD_Promoter" \
#                     "0;100;20" \
#                     "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                     "nonPAD_Promoter" \
#                     "dodge" \
#                     "3" \
#                     "5" \
#                     "-007" \
#                     "F"
#             }
#             nonPAD_Promoter_plot
#         }
#         # PAD_regulatory
#
#         Repeats(){
#             # D: Nov-06-2022 15:26 Sun
#             mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats
#             simpleOverlap(){
#                 # D: Nov-06-2022 16:15 Sun
#                 # R: Almost CHMs located in repeats, especially in LTR
#                 echo -e "xValue\tyValue\tgroup" > repeats.ggplot_basic.txt
#                 echo -e "xValue\tyValue\tgroup" > LINE.ggplot_basic.txt
#                 echo -e "xValue\tyValue\tgroup" > SINE.ggplot_basic.txt
#                 echo -e "xValue\tyValue\tgroup" > LTR.ggplot_basic.txt
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                     N_TOTAL=$(cat ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed | wc -l)
#                     for type in repeats LINE SINE LTR
#                     do
#                         N_TYPE=$(intersectBed -u -a ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed -b ${anPATH}/mm10/Repeats/mm10.${type}.bed | wc -l)
#                         echo -e "${group}\t${N_TOTAL}\t${N_TYPE}\t${type}" | awk 'BEGIN{FS=OFS="\t"}{print $1, $3/$2*100, $4;}' >> ${type}.ggplot_basic.txt
#                     done # for type end
#                 done # for group end
#
#                 for type in repeats LINE SINE LTR
#                 do
#                     Rscript ${rPATH}/ggplot_barplot.r \
#                         "${type}.ggplot_basic.txt" \
#                         "${type}.ggplot_barplot.pdf" \
#                         "${type}" \
#                         "" \
#                         "Percentage of CHMs located in ${type}" \
#                         "0;100;20" \
#                         "Universal;EarlyEmbryoSpecific;PGCSpecific;SpermSpecific;RetinalSpecific;DCSpecific" \
#                         "${type}" \
#                         "dodge" \
#                         "3" \
#                         "5" \
#                         "-007" \
#                         "F"
#                 done # for type end
#             }
#             # simpleOverlap
#
#             overlapDetails(){
#                 # D: Nov-06-2022 16:43 Sun
#                 mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats/OverlapDetails;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats/OverlapDetails
#                 # chr start end repeats LTR LINE SINE
#                 for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                 do
#                     # cut -f 1-3 ${dirPATH}/CHMOrganization/Universal_specific/${group}.bed > ${group}.overlapDetails.txt
#                     # intersectBed -c -a ${group}.overlapDetails.txt -b ${anPATH}/mm10/Repeats/mm10.repeats.bed | \
#                     #     awk 'BEGIN{FS=OFS="\t"}{if($4>0){print $1, $2, $3, 1;} else{print $1, $2, $3, 0;}}' > tmp && mv tmp ${group}.overlapDetails.txt
#                     # intersectBed -c -a ${group}.overlapDetails.txt -b ${anPATH}/mm10/Repeats/mm10.LTR.bed | \
#                     #     awk 'BEGIN{FS=OFS="\t"}{if($5>0){print $1, $2, $3, $4, 1;} else{print $1, $2, $3, $4, 0;}}' > tmp && mv tmp ${group}.overlapDetails.txt
#                     # intersectBed -c -a ${group}.overlapDetails.txt -b ${anPATH}/mm10/Repeats/mm10.LINE.bed | \
#                     #     awk 'BEGIN{FS=OFS="\t"}{if($6>0){print $1, $2, $3, $4, $5, 1;} else{print $1, $2, $3, $4, $5, 0;}}' > tmp && mv tmp ${group}.overlapDetails.txt
#                     # intersectBed -c -a ${group}.overlapDetails.txt -b ${anPATH}/mm10/Repeats/mm10.SINE.bed | \
#                     #     awk 'BEGIN{FS=OFS="\t"}{if($7>0){print $1, $2, $3, $4, $5, $6, 1;} else{print $1, $2, $3, $4, $5, $6, 0;}}' > tmp && mv tmp ${group}.overlapDetails.txt
#                     intersectBed -c -a ${group}.overlapDetails.txt -b ${anPATH}/mm10/Repeats/mm10.others.bed | \
#                         awk 'BEGIN{FS=OFS="\t"}{if($8>0){print $1, $2, $3, $4, $5, $6, $7, 1;} else{print $1, $2, $3, $4, $5, $6, $7, 0;}}' > tmp && mv tmp ${group}.overlapDetails.txt
#                 done # for group end
#             }
#             # overlapDetails
#
#             overlapGroups(){
#                 # D: Nov-07-2022 13:55 Mon
#                 mkdir -p ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats/OverlapDetails;cd ${dirPATH}/CHMOrganization/Universal_specific/Features/GenomeDistribution/Repeats/OverlapDetails
#                 piechart(){
#                     for group in Universal EarlyEmbryoSpecific PGCSpecific SpermSpecific RetinalSpecific DCSpecific
#                     do
#                         # echo -e "value\tgroup" > ${group}.overlapDetails.ggplot_pieplot.txt
#                         # cut -f 4- ${group}.overlapDetails.txt | sort | uniq -c | awk 'BEGIN{FS=" ";OFS="\t"}{print $1,"g_"$2$3$4$5$6}' >> ${group}.overlapDetails.ggplot_pieplot.txt
#                         Rscript ${rPATH}/ggplot_pie.r \
#                             ${group}.overlapDetails.ggplot_pieplot.txt \
#                             ${group}.overlapDetails \
#                             "g_00000;g_10001;g_10010;g_10011;g_10100;g_10101;g_10110;g_10111;g_11000;g_11001;g_11010;g_11011;g_11100;g_11101;g_11110;g_11111" \
#                             "#ffffff;#7fa718;#00007E;#0000FF;#007E00;#00FF00;#007E7E;#00FFFF;#7E0000;#FF0000;#7E007E;#FF00FF;#7E7E00;#FFFF00;#7E7E7E;#000000" \
#                             T \
#                             6 \
#                             6
#                     done # for group end
#                 }
#                 piechart
#             }
#             overlapGroups
#         }
#         Repeats
#     }
#     genomeDistribution
# }
# features
# Out:
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
